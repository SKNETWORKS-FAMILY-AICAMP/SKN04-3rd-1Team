# %%
import json

# %%
with open('./data/graph_section_10.json', 'r', encoding='utf-8') as file:
    data = json.load(file)
    books = data.get('@graph', [])

# %%
kdc_categories = {
    "00": "총류",
    "01": "도서관, 서지학",
    "02": "문헌정보학",
    "03": "백과사전",
    "04": "강연집, 수필집, 연설문집",
    "05": "일반 연속간행물",
    "06": "일반학회, 단체, 협회, 기관",
    "07": "신문, 언론, 저널리즘",
    "08": "일반전집, 총서",
    "09": "향토자료",

    "10": "철학",
    "11": "형이상학",
    "12": "인식론, 인과론, 인간학",
    "13": "철학의 체계",
    "14": "경학",
    "15": "아시아철학, 사상",
    "16": "서양철학",
    "17": "논리학",
    "18": "심리학",
    "19": "윤리학, 도덕철학",

    "20": "종교",
    "21": "비교종교",
    "22": "불교",
    "23": "기독교",
    "24": "도교",
    "25": "천도교",
    "26": "신도",
    "27": "파라문교, 인도교",
    "28": "회교(이슬람교)",
    "29": "기타 제종교",

    "30": "사회과학",
    "31": "통계학",
    "32": "경제학",
    "33": "사회학, 사회문제",
    "34": "정치학",
    "35": "행정학",
    "36": "법학",
    "37": "교육학",
    "38": "풍속, 민속학",
    "39": "국방, 군사학",

    "40": "자연과학",
    "41": "수학",
    "42": "물리학",
    "43": "화학",
    "44": "천문학",
    "45": "지학",
    "46": "광물학",
    "47": "생명과학",
    "48": "식물학",
    "49": "동물학",

    "50": "기술과학",
    "51": "의학",
    "52": "농업, 농학",
    "53": "공학, 공학일반",
    "54": "건축공학",
    "55": "기계공학",
    "56": "전기공학, 전자공학",
    "57": "화학공학",
    "58": "제조업",
    "59": "가정학 및 가정생활",

    "60": "예술",
    "61": "건축술",
    "62": "조각",
    "63": "공예, 장식미술",
    "64": "서예",
    "65": "회화, 도화",
    "66": "사진술",
    "67": "음악",
    "68": "연극",
    "69": "오락, 운동",

    "70": "언어",
    "71": "한국어",
    "72": "중국어",
    "73": "일본어",
    "74": "영어",
    "75": "독일어",
    "76": "프랑스어",
    "77": "스페인어",
    "78": "이탈리아어",
    "79": "기타제어",

    "80": "문학",
    "81": "한국문학",
    "82": "중국문학",
    "83": "일본문학",
    "84": "영미문학",
    "85": "독일문학",
    "86": "프랑스문학",
    "87": "스페인문학",
    "88": "이탈리아문학",
    "89": "기타 제문학",

    "90": "역사",
    "91": "아시아(아세아)",
    "92": "유럽(구라파)",
    "93": "아프리카",
    "94": "북아메리카(북미)",
    "95": "남아메리카(남미)",
    "96": "오세아니아(대양주)",
    "97": "양극지방",
    "98": "지리",
    "99": "전기"
}

# %%
ddc_categories = {
    "00": "총류",
    "01": "서지",
    "02": "문헌정보학",
    "03": "백과사전",
    "04": "공기호",
    "05": "잡지, 저널, 연속간행물",
    "06": "협회, 박물관학",
    "07": "뉴스 매체, 저널리즘, 출판",
    "08": "일반전집",
    "09": "필사본, 희귀서적",

    "10": "철학",
    "11": "형이상학",
    "12": "인식론",
    "13": "초상현상",
    "14": "철학파",
    "15": "심리학",
    "16": "철학 논리",
    "17": "윤리학",
    "18": "고대, 중세, 동양철학",
    "19": "현대 서양철학",

    "20": "종교",
    "21": "종교철학과 이론",
    "22": "성서",
    "23": "기독교와 기독교 신학",
    "24": "기독교 실천과 교리준수",
    "25": "기독교 목회자의 실천과 종파",
    "26": "기독교 사회 신학",
    "27": "기독교 역사",
    "28": "기독교 교파",
    "29": "기타 종교",

    "30": "사회과학",
    "31": "통계학",
    "32": "정치학",
    "33": "경제학",
    "34": "법학",
    "35": "행정학과 군사학",
    "36": "사회서비스",
    "37": "교육",
    "38": "무역 통신과 수송",
    "39": "관습, 에티켓과 민속전통",

    "40": "언어",
    "41": "언어학",
    "42": "영어와 고대언어",
    "43": "독일어 관련언어",
    "44": "프랑스 관련언어",
    "45": "이탈리아, 루마니아어",
    "46": "스페인, 포르투갈어",
    "47": "라틴과 이탤릭 언어",
    "48": "고대, 현대 그리서어",
    "49": "기타 언어",

    "50": "과학",
    "51": "수학",
    "52": "천문학",
    "53": "물리학",
    "54": "화학",
    "55": "지구과학",
    "56": "고생물학",
    "57": "생물학",
    "58": "식물학",
    "59": "동물학",

    "60": "기술",
    "61": "의학",
    "62": "공학",
    "63": "농업",
    "64": "가정, 가족경영",
    "65": "경영과 홍보",
    "66": "화학공학",
    "67": "제조",
    "68": "특별한 용도의 제조",
    "69": "건축",

    "70": "예술, 레크리에이션",
    "71": "도시계획, 조경술",
    "72": "건축학",
    "73": "조각품, 도예와 금속제품",
    "74": "인쇄예술",
    "75": "그림",
    "76": "제작술",
    "77": "사진술",
    "78": "음악",
    "79": "스포츠, 게임",

    "80": "문학",
    "81": "미국문학",
    "82": "영어, 고대영어문학",
    "83": "독일 문학",
    "84": "프랑스 문학",
    "85": "이탈리아 문학",
    "86": "스페인, 포르투갈 문학",
    "87": "라틴 문학",
    "88": "그리스 문학",
    "89": "기타 문학",

    "90": "역사, 지리",
    "91": "지리와 여행",
    "92": "전기와 계보학",
    "93": "고대 역사",
    "94": "유럽 역사",
    "95": "아시아 역사",
    "96": "아프리카 역사",
    "97": "북아메리카 역사",
    "98": "남아메리카 역사",
    "99": "기타지역 역사"
}

# %%
if not books:
    print("도서 정보를 확인할 수 없습니다.")
else:
    processed_books = []

    for book in books:
        kdc_code = book.get("kdc")
        main_kdc_code = kdc_code[:2] if kdc_code else None 
        main_kdc_description = kdc_categories.get(main_kdc_code, "상위 분류 없음")
        
        ddc_code = book.get("ddc")
        main_ddc_code = ddc_code[:2] if ddc_code else None
        main_ddc_description = ddc_categories.get(main_ddc_code, "상위 분류 없음")
        
        processed_book = {
            "title": book.get("title"),
            "creator": book.get("creator"),
            "publisher": book.get("publisher"),
            "issuedYear": book.get("issuedYear"),
            "kdc": book.get("kdc"),
            "kdcKdcDescription": main_kdc_description,
            "ddc": book.get("ddc"),
            "mainDdcDescription": main_ddc_description,
            "alternative": book.get("alternative"),
            "seeAlso": book.get("seeAlso"),
        }

        processed_books.append(processed_book)

# %%
processed_books
# Out:
# [{'title': '놓지 마 과학!',
#   'creator': '나승훈',
#   'publisher': '위즈덤하우스',
#   'issuedYear': '2016',
#   'kdc': '408',
#   'kdcKdcDescription': '자연과학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '모카노 왕국의 보물과 밀실 미스터리',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11545500'},
#  {'title': '미션 탈출 30',
#   'creator': 'Martin, Paul',
#   'publisher': '알라딘북스',
#   'issuedYear': '2016',
#   'kdc': '170',
#   'kdcKdcDescription': '논리학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Énigmes à tous les étages-tome',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10832476'},
#  {'title': '베니스의 상인',
#   'creator': '김영인',
#   'publisher': '책고래',
#   'issuedYear': '2016',
#   'kdc': '842',
#   'kdcKdcDescription': '영미문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10859272'},
#  {'title': '우등생 바이러스',
#   'creator': '정란희',
#   'publisher': '크레용하우스',
#   'issuedYear': '2016',
#   'kdc': '813.7',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10893203'},
#  {'title': '(스토리텔링과 포트폴리오를 활용한 초등학생을 위한) 자기관리 공부방법',
#   'creator': '신재한',
#   'publisher': '교육과학사',
#   'issuedYear': '2016',
#   'kdc': '373',
#   'kdcKdcDescription': '교육학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10768936'},
#  {'title': '학교가 살아 있다!',
#   'creator': 'Chabert, Jack',
#   'publisher': 'Mirae N 아이세움',
#   'issuedYear': '2016',
#   'kdc': '843',
#   'kdcKdcDescription': '영미문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'School is alive!',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10768433'},
#  {'title': '세계사 보물찾기',
#   'creator': '강경효',
#   'publisher': '미래엔',
#   'issuedYear': '2016',
#   'kdc': '909',
#   'kdcKdcDescription': '역사',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10769221'},
#  {'title': '시스루 양말과 메리야스',
#   'creator': '고용우',
#   'publisher': '창비교육',
#   'issuedYear': '2016',
#   'kdc': '810.8',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10869612'},
#  {'title': '미스터 볼의 세상에서 가장 쉬운 계획표',
#   'creator': '박수현',
#   'publisher': '푸른숲',
#   'issuedYear': '2016',
#   'kdc': '843',
#   'kdcKdcDescription': '영미문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Mr. Ball makes a to-do list',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10882164'},
#  {'title': 'Who? 최제우·최시형',
#   'creator': '권용찬',
#   'publisher': '스튜디오 다산',
#   'issuedYear': '2016',
#   'kdc': '991.1',
#   'kdcKdcDescription': '전기',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10494869'},
#  {'title': '윔피 키드',
#   'creator': '지혜연',
#   'publisher': 'Mirae N 아이세움',
#   'issuedYear': '2016',
#   'kdc': '843',
#   'kdcKdcDescription': '영미문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '18',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=12005939'},
#  {'title': 'Who? 최제우·최시형',
#   'creator': '김모락',
#   'publisher': '다산어린이',
#   'issuedYear': '2016',
#   'kdc': '991.1',
#   'kdcKdcDescription': '전기',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11102653'},
#  {'title': 'Who? 박지원',
#   'creator': '정병훈',
#   'publisher': '다산어린이',
#   'issuedYear': '2016',
#   'kdc': '991.1',
#   'kdcKdcDescription': '전기',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11102651'},
#  {'title': '(수학방의) 중등수학',
#   'creator': None,
#   'publisher': 'Pubple(퍼플)',
#   'issuedYear': '2016',
#   'kdc': '410',
#   'kdcKdcDescription': '수학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11102665'},
#  {'title': '한국과 일본 이야기',
#   'creator': '박중현',
#   'publisher': '동북아역사재단',
#   'issuedYear': '2016',
#   'kdc': '910',
#   'kdcKdcDescription': '아시아(아세아)',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '구세군',
#   'creator': 'Agger, Jens Peder',
#   'publisher': '교원',
#   'issuedYear': '1999',
#   'kdc': '990',
#   'kdcKdcDescription': '전기',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Frelsens hær',
#   'seeAlso': None},
#  {'title': '헬렌 켈러',
#   'creator': 'Macdonald, Fiona',
#   'publisher': '교원',
#   'issuedYear': '1999',
#   'kdc': '990',
#   'kdcKdcDescription': '전기',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Helen Keller',
#   'seeAlso': None},
#  {'title': '마틴 루터 킹',
#   'creator': 'Brown, Pam',
#   'publisher': '교원',
#   'issuedYear': '1999',
#   'kdc': '990',
#   'kdcKdcDescription': '전기',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Martin Luther King',
#   'seeAlso': None},
#  {'title': '에디슨',
#   'creator': 'Sproule, Anna',
#   'publisher': '교원',
#   'issuedYear': '1999',
#   'kdc': '990',
#   'kdcKdcDescription': '전기',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Thomas A. Edison',
#   'seeAlso': None},
#  {'title': '마르코니',
#   'creator': 'Birch, Beverley',
#   'publisher': '교원',
#   'issuedYear': '1999',
#   'kdc': '998.4',
#   'kdcKdcDescription': '전기',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'the story of radio and how it made the world a smaller place',
#   'seeAlso': None},
#  {'title': '와트',
#   'creator': 'Sproule, Anna',
#   'publisher': '교원',
#   'issuedYear': '1999',
#   'kdc': '990',
#   'kdcKdcDescription': '전기',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'the development of steam engines and how they created our industrial society',
#   'seeAlso': None},
#  {'title': '(2015년) 환경보전 그림그리기·글짓기 대회 작품집',
#   'creator': None,
#   'publisher': '마포구',
#   'issuedYear': '2015',
#   'kdc': '539',
#   'kdcKdcDescription': '공학, 공학일반',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '나눔이와 뽀득뽀득 손 씻고!',
#   'creator': '우금순',
#   'publisher': '평창군청',
#   'issuedYear': '2016',
#   'kdc': '517',
#   'kdcKdcDescription': '의학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '헨젤과 그레텔',
#   'creator': '신현배',
#   'publisher': '한국헤밍웨이',
#   'issuedYear': '2004',
#   'kdc': '808.3',
#   'kdcKdcDescription': '문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Hänsel und Gretel',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11102763'},
#  {'title': '갑자사화를 일으키다',
#   'creator': '정윤철',
#   'publisher': '한국헤밍웨이',
#   'issuedYear': '2006',
#   'kdc': '911.05',
#   'kdcKdcDescription': '아시아(아세아)',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11102816'},
#  {'title': '어린 왕이 삼촌에게 쫓겨나다',
#   'creator': '박영규',
#   'publisher': '한국헤밍웨이',
#   'issuedYear': '2006',
#   'kdc': '911.05',
#   'kdcKdcDescription': '아시아(아세아)',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11102796'},
#  {'title': '이괄의 삼일천하',
#   'creator': '박영규',
#   'publisher': '한국헤밍웨이',
#   'issuedYear': '2006',
#   'kdc': '911.05',
#   'kdcKdcDescription': '아시아(아세아)',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11102810'},
#  {'title': '이어지는 피바람',
#   'creator': '박영규',
#   'publisher': '한국헤밍웨이',
#   'issuedYear': '2006',
#   'kdc': '911.05',
#   'kdcKdcDescription': '아시아(아세아)',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11102808'},
#  {'title': '사람이 갈라서다',
#   'creator': '전병준',
#   'publisher': '한국헤밍웨이',
#   'issuedYear': '2006',
#   'kdc': '911.05',
#   'kdcKdcDescription': '아시아(아세아)',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11102787'},
#  {'title': '개구리 바위',
#   'creator': '이연정',
#   'publisher': '한국헤밍웨이',
#   'issuedYear': '2004',
#   'kdc': '813.5',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11102828'},
#  {'title': '(교과서와 함께하는) 길잡이 책',
#   'creator': '장혜련',
#   'publisher': '한국헤밍웨이',
#   'issuedYear': '2004',
#   'kdc': '813.5',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11102833'},
#  {'title': '백전백승의 영웅 이성계',
#   'creator': '박영규',
#   'publisher': '한국헤밍웨이',
#   'issuedYear': '2006',
#   'kdc': '911.05',
#   'kdcKdcDescription': '아시아(아세아)',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11102793'},
#  {'title': '십자군 전쟁',
#   'creator': '송낙웅',
#   'publisher': '한국헤르만헤세',
#   'issuedYear': '2008',
#   'kdc': '909',
#   'kdcKdcDescription': '역사',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=7906979'},
#  {'title': '아편 전쟁과 열강의 침략',
#   'creator': '김학섭',
#   'publisher': '한국헤르만헤세',
#   'issuedYear': '2008',
#   'kdc': '909',
#   'kdcKdcDescription': '역사',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '제국주의와 제1차 세계 대전',
#   'creator': '김학섭',
#   'publisher': '한국헤르만헤세',
#   'issuedYear': '2008',
#   'kdc': '909',
#   'kdcKdcDescription': '역사',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '제국주의와 제일차 세계 대전',
#   'seeAlso': None},
#  {'title': '곤충기',
#   'creator': 'Fabre, Jean Henri',
#   'publisher': '마당미디어',
#   'issuedYear': '1996',
#   'kdc': '808',
#   'kdcKdcDescription': '문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Souvenirs entomologiques',
#   'seeAlso': None},
#  {'title': '젊은 베르테르의 슬픔',
#   'creator': '김균희',
#   'publisher': '마당미디어',
#   'issuedYear': '1996',
#   'kdc': '852',
#   'kdcKdcDescription': '독일문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Faust',
#   'seeAlso': None},
#  {'title': '여자의 일생',
#   'creator': '배기열',
#   'publisher': '마당미디어',
#   'issuedYear': '1996',
#   'kdc': '808',
#   'kdcKdcDescription': '문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Une vie',
#   'seeAlso': None},
#  {'title': '대지',
#   'creator': '이선우',
#   'publisher': '마당미디어',
#   'issuedYear': '1996',
#   'kdc': '843',
#   'kdcKdcDescription': '영미문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Good earth',
#   'seeAlso': None},
#  {'title': '세밀화 식물도감',
#   'creator': '정민',
#   'publisher': '함께books(함께북스)',
#   'issuedYear': '2015',
#   'kdc': '480',
#   'kdcKdcDescription': '식물학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=9831878'},
#  {'title': '방귀 뀌고, 으쓱!',
#   'creator': '조은수',
#   'publisher': '웅진북클럽',
#   'issuedYear': '2016',
#   'kdc': '375.1',
#   'kdcKdcDescription': '교육학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11102624'},
#  {'title': '(Joy쌤의 누구나 쉽게 치는) 힐링피아노',
#   'creator': '조희순',
#   'publisher': 'Samhomusic(삼호뮤직)',
#   'issuedYear': '2016',
#   'kdc': '676.2',
#   'kdcKdcDescription': '음악',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '조이쌤의 누구나 쉽게 치는 힐링피아노',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10869116'},
#  {'title': '지구가 태어났어요',
#   'creator': '변혜원',
#   'publisher': '월드베스트',
#   'issuedYear': '2016',
#   'kdc': '445',
#   'kdcKdcDescription': '천문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10087636'},
#  {'title': '계산력 마스터',
#   'creator': None,
#   'publisher': '와이즈만 Books',
#   'issuedYear': '2016',
#   'kdc': '410',
#   'kdcKdcDescription': '수학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '초등 3학년 자연수의 곱셈과 나눗셈 초급',
#   'seeAlso': None},
#  {'title': '쇼팽',
#   'creator': 'Brown, Pam',
#   'publisher': '교원',
#   'issuedYear': '1999',
#   'kdc': '998.6',
#   'kdcKdcDescription': '전기',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Frederic Chopin',
#   'seeAlso': None},
#  {'title': '차이코프스키',
#   'creator': 'Pollard, Michael',
#   'publisher': '교원',
#   'issuedYear': '1999',
#   'kdc': '990',
#   'kdcKdcDescription': '전기',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Peter Ilyich Tchaikovsky',
#   'seeAlso': None},
#  {'title': '다윈',
#   'creator': 'Sproule, Anna',
#   'publisher': '교원',
#   'issuedYear': '1999',
#   'kdc': '990',
#   'kdcKdcDescription': '전기',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Charles Darwin',
#   'seeAlso': None},
#  {'title': '미드',
#   'creator': 'Pollard, Michael',
#   'publisher': '교원',
#   'issuedYear': '1999',
#   'kdc': '998.3',
#   'kdcKdcDescription': '전기',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': "the century's greatest anthropologist who has helped people to understand their differences",
#   'seeAlso': None},
#  {'title': '바웬사',
#   'creator': 'Craig, Mary',
#   'publisher': '교원',
#   'issuedYear': '1999',
#   'kdc': '990',
#   'kdcKdcDescription': '전기',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Lech Walesa',
#   'seeAlso': None},
#  {'title': '찰랑찰랑 컵',
#   'creator': '서보현',
#   'publisher': '웅진북클럽',
#   'issuedYear': '2016',
#   'kdc': '375.1',
#   'kdcKdcDescription': '교육학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '땅속 거인',
#   'creator': '서향숙',
#   'publisher': '푸른사상',
#   'issuedYear': '2016',
#   'kdc': '811.8',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10933668'},
#  {'title': '사자왕의 모험',
#   'creator': '매튜김',
#   'publisher': 'D&P(디앤피코퍼레이션)',
#   'issuedYear': '2015',
#   'kdc': '813.7',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '사랑하는 마음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11102684'},
#  {'title': '세한도',
#   'creator': '김품창',
#   'publisher': '마주보기',
#   'issuedYear': '2015',
#   'kdc': '813.6',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=7220419'},
#  {'title': '부와 바 청소 소동',
#   'creator': 'Landström, Olof',
#   'publisher': '재능교육',
#   'issuedYear': '2015',
#   'kdc': '859.7',
#   'kdcKdcDescription': '독일문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Bu och Bä i städtagen',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11102673'},
#  {'title': '코끼리가 기차 타고 뿌우 뿌우',
#   'creator': '최유진',
#   'publisher': '받침없는동화',
#   'issuedYear': '2016',
#   'kdc': '813.7',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '여우들의 히치하이킹',
#   'creator': '이시은',
#   'publisher': '동래여자중학교',
#   'issuedYear': '2016',
#   'kdc': '816.7',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11102611'},
#  {'title': '우리는 왜 여기서 살까요?',
#   'creator': 'McLaughlin, Julie',
#   'publisher': '푸른날개',
#   'issuedYear': '2016',
#   'kdc': '300',
#   'kdcKdcDescription': '사회과학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Why we live where we live',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10688828'},
#  {'title': '동그라미가 넘어졌어요',
#   'creator': '방길튼',
#   'publisher': '동남풍',
#   'issuedYear': '2016',
#   'kdc': '228',
#   'kdcKdcDescription': '불교',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '똥의 정체',
#   'creator': '다라 미미로',
#   'publisher': '미세기',
#   'issuedYear': '2016',
#   'kdc': '511',
#   'kdcKdcDescription': '의학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'ポプラサイエンスランド',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10882361'},
#  {'title': '난 믿음으로 쑥쑥 자랄래!',
#   'creator': '유외영',
#   'publisher': '언약의책',
#   'issuedYear': '2015',
#   'kdc': '235',
#   'kdcKdcDescription': '기독교',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10015421'},
#  {'title': '그리스도 예수님이 나를 살리셨어!',
#   'creator': '조은진',
#   'publisher': '언약의책',
#   'issuedYear': '2015',
#   'kdc': '235',
#   'kdcKdcDescription': '기독교',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10015421'},
#  {'title': '구원의 길 ㄱㄴㄷ',
#   'creator': '유외영',
#   'publisher': '언약의책',
#   'issuedYear': '2016',
#   'kdc': '231',
#   'kdcKdcDescription': '기독교',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10280832'},
#  {'title': '하얀 폭력 검은 저항',
#   'creator': '오찬호',
#   'publisher': '돌베개',
#   'issuedYear': '2016',
#   'kdc': '342',
#   'kdcKdcDescription': '정치학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Hayan pongnyeok geomeun jeohang',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10844237'},
#  {'title': 'Grammar wing',
#   'creator': None,
#   'publisher': 'englishwing',
#   'issuedYear': '2016',
#   'kdc': '745',
#   'kdcKdcDescription': '영어',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '그래머 윙',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11270157'},
#  {'title': '공주 아름이',
#   'creator': 'Bertrand, Philippe',
#   'publisher': '태동출판사',
#   'issuedYear': '2010',
#   'kdc': '375.1',
#   'kdcKdcDescription': '교육학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Leïla la princesse',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=9822508'},
#  {'title': '거드름쟁이 불불이',
#   'creator': 'Bertrand, Philippe',
#   'publisher': '태동출판사',
#   'issuedYear': '2010',
#   'kdc': '375.1',
#   'kdcKdcDescription': '교육학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Albert la grosse tête',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=9822504'},
#  {'title': '모차르트',
#   'creator': '신충행',
#   'publisher': '한국헤밍웨이',
#   'issuedYear': '2005',
#   'kdc': '998.6',
#   'kdcKdcDescription': '전기',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=6962449'},
#  {'title': '이순신',
#   'creator': '권성원',
#   'publisher': '꿈나라',
#   'issuedYear': '1995',
#   'kdc': '991.1',
#   'kdcKdcDescription': '전기',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '어리광쟁이 찡찡이',
#   'creator': 'Bertrand, Philippe',
#   'publisher': '태동출판사',
#   'issuedYear': '2010',
#   'kdc': '375.1',
#   'kdcKdcDescription': '교육학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Oleg le câlin',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=9822513'},
#  {'title': '투털이 투투',
#   'creator': 'Bertrand, Philippe',
#   'publisher': '태동출판사',
#   'issuedYear': '2010',
#   'kdc': '375.1',
#   'kdcKdcDescription': '교육학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Maurice le grognon',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=9822510'},
#  {'title': '맥스 크럼블리',
#   'creator': 'Russell, Rachel Renee',
#   'publisher': '미래지식',
#   'issuedYear': '2016',
#   'kdc': '843',
#   'kdcKdcDescription': '영미문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Misadventures of Max Crumbly',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=12782877'},
#  {'title': '셰익스피어는 어디에?',
#   'creator': 'Tilly',
#   'publisher': '큐리어스',
#   'issuedYear': '2016',
#   'kdc': '842',
#   'kdcKdcDescription': '영미문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'find Shakespeare hidden in his plays',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10191139'},
#  {'title': '(2016년) 최신가요 짱!',
#   'creator': '문은진',
#   'publisher': 'Dongseo music(동서음악출판사)',
#   'issuedYear': '2016',
#   'kdc': '676.2',
#   'kdcKdcDescription': '음악',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10406424'},
#  {'title': '백색 지대',
#   'creator': '김옥진',
#   'publisher': '스콜라',
#   'issuedYear': '2016',
#   'kdc': '843',
#   'kdcKdcDescription': '영미문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'White zone',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10771662'},
#  {'title': '우아, 배꼽이다',
#   'creator': '아와타 노부코',
#   'publisher': '크레용하우스',
#   'issuedYear': '2016',
#   'kdc': '833.6',
#   'kdcKdcDescription': '일본문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'へーそーなんだ',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10768447'},
#  {'title': '나는 떨리는 별',
#   'creator': '오유경',
#   'publisher': '풀빛미디어',
#   'issuedYear': '2016',
#   'kdc': '813.7',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10765351'},
#  {'title': '용도 탐낸 아름다운 여인',
#   'creator': '안재선',
#   'publisher': '소빅스',
#   'issuedYear': '2016',
#   'kdc': '911.03',
#   'kdcKdcDescription': '아시아(아세아)',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11170565'},
#  {'title': '(New) 천하무적',
#   'creator': None,
#   'publisher': 'samhomusic(삼호뮤직)',
#   'issuedYear': '2016',
#   'kdc': '671',
#   'kdcKdcDescription': '음악',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11123973'},
#  {'title': '물에서 사는 식물',
#   'creator': None,
#   'publisher': '대교',
#   'issuedYear': '2002',
#   'kdc': '472',
#   'kdcKdcDescription': '생명과학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '선인장',
#   'creator': None,
#   'publisher': '대교아인슈타인',
#   'issuedYear': '2002',
#   'kdc': '472',
#   'kdcKdcDescription': '생명과학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '기차 여행',
#   'creator': '김소연',
#   'publisher': '한국삐아제',
#   'issuedYear': '2012',
#   'kdc': '375.1',
#   'kdcKdcDescription': '교육학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'À fond de train!',
#   'seeAlso': None},
#  {'title': '왜 사람들은 금광을 찾아 서부로 갔을까요?',
#   'creator': 'Langley, Andrew',
#   'publisher': '한국삐아제',
#   'issuedYear': '2006',
#   'kdc': '942',
#   'kdcKdcDescription': '북아메리카(북미)',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '100 thing you should know about the Wild West',
#   'seeAlso': None},
#  {'title': '호호! 놀라운 세계 문화',
#   'creator': '장보람',
#   'publisher': '기탄교육',
#   'issuedYear': '2010',
#   'kdc': '380',
#   'kdcKdcDescription': '풍속, 민속학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '나도 갈래요',
#   'creator': '김소연',
#   'publisher': '한국삐아제',
#   'issuedYear': '2013',
#   'kdc': '375.1',
#   'kdcKdcDescription': '교육학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Tout le monde y va!',
#   'seeAlso': None},
#  {'title': '월트 디즈니',
#   'creator': '이주윤',
#   'publisher': '한국헤밍웨이',
#   'issuedYear': '2005',
#   'kdc': '990',
#   'kdcKdcDescription': '전기',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=8272864'},
#  {'title': '감·사과',
#   'creator': None,
#   'publisher': '대교아인슈타인',
#   'issuedYear': '2002',
#   'kdc': '472',
#   'kdcKdcDescription': '생명과학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '진달래·개나리',
#   'creator': None,
#   'publisher': '대교아인슈타인',
#   'issuedYear': '2002',
#   'kdc': '472',
#   'kdcKdcDescription': '생명과학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '옥수수·감자',
#   'creator': None,
#   'publisher': '대교아인슈타인',
#   'issuedYear': '2002',
#   'kdc': '472',
#   'kdcKdcDescription': '생명과학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '어머니를 위해 종이 될게요',
#   'creator': '이은서',
#   'publisher': 'Daekyo(대교)',
#   'issuedYear': '2016',
#   'kdc': '911.03',
#   'kdcKdcDescription': '아시아(아세아)',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '탑돌이에서 만난 호랑이 처녀',
#   'creator': '이지현',
#   'publisher': 'Daekyo(대교)',
#   'issuedYear': '2016',
#   'kdc': '911.03',
#   'kdcKdcDescription': '아시아(아세아)',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '(2017 Kclass) EBS 수능특강 변형문제',
#   'creator': '김철홍',
#   'publisher': 'Plan D. books',
#   'issuedYear': '2016',
#   'kdc': '740',
#   'kdcKdcDescription': '영어',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10485995'},
#  {'title': '한국산업기술대 전공적성평가',
#   'creator': None,
#   'publisher': '서원각',
#   'issuedYear': '2016',
#   'kdc': '370',
#   'kdcKdcDescription': '교육학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10882561'},
#  {'title': '고마워, 리을도깨비야',
#   'creator': '이지수',
#   'publisher': '한글도깨비',
#   'issuedYear': '2016',
#   'kdc': '711',
#   'kdcKdcDescription': '한국어',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '우리 엄마 뱃속',
#   'creator': '박진영',
#   'publisher': '정원지기',
#   'issuedYear': '2016',
#   'kdc': '813.7',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11037460'},
#  {'title': '(새로 믿은 청소년들을 위한) 믿음의 첫 걸음',
#   'creator': None,
#   'publisher': '한국복음서원',
#   'issuedYear': '2015',
#   'kdc': '235',
#   'kdcKdcDescription': '기독교',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '(김인숙의) song kids art',
#   'creator': '김인숙',
#   'publisher': 'SGS두뇌균형개발연구소',
#   'issuedYear': '2015',
#   'kdc': '650',
#   'kdcKdcDescription': '회화, 도화',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '김인숙의 송 키즈 아트',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10882771'},
#  {'title': '아빠, 발 씻어 드릴게요',
#   'creator': '노열',
#   'publisher': '문화방송',
#   'issuedYear': '1998',
#   'kdc': '813.6',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '효자와 죽엽주',
#   'seeAlso': None},
#  {'title': '아롱이와 다롱이',
#   'creator': '김경중',
#   'publisher': '눈열린교육',
#   'issuedYear': '1998',
#   'kdc': '813.6',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=4299910'},
#  {'title': '(소년·소녀) 세계위인전기전집',
#   'creator': '김영일',
#   'publisher': '구미서관',
#   'issuedYear': '19uu',
#   'kdc': '990',
#   'kdcKdcDescription': '전기',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '버블과 스퀵 대소동',
#   'creator': 'Pearce, Philippa',
#   'publisher': '논장',
#   'issuedYear': '2001',
#   'kdc': '843',
#   'kdcKdcDescription': '영미문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Battle of Bubble and Squeak',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=179663'},
#  {'title': '날개의 씨앗',
#   'creator': '김와곤',
#   'publisher': '오늘',
#   'issuedYear': '1996',
#   'kdc': '811.8',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1803'},
#  {'title': '모기보시',
#   'creator': '이호백',
#   'publisher': '재미마주',
#   'issuedYear': '2005',
#   'kdc': '813.6',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '할아버지의 안경',
#   'creator': '김성은',
#   'publisher': '마루벌',
#   'issuedYear': '2000',
#   'kdc': '813.7',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=182798'},
#  {'title': '(김인숙의) 그림으로 배우는 한글놀이',
#   'creator': '김인숙',
#   'publisher': 'SGS두뇌균형개발연구소',
#   'issuedYear': '2016',
#   'kdc': '710',
#   'kdcKdcDescription': '한국어',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10882729'},
#  {'title': '악기 소리가 들려요',
#   'creator': '오정택',
#   'publisher': '웅진북클럽',
#   'issuedYear': '2016',
#   'kdc': '375.1',
#   'kdcKdcDescription': '교육학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '토끼의 겨울 숲 속',
#   'creator': '나희덕',
#   'publisher': '웅진씽크빅',
#   'issuedYear': '2016',
#   'kdc': '375.1',
#   'kdcKdcDescription': '교육학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '간다, 간다 탈것책',
#   'creator': '보린',
#   'publisher': '웅진씽크빅',
#   'issuedYear': '2016',
#   'kdc': '375.1',
#   'kdcKdcDescription': '교육학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '구석구석 집책',
#   'creator': '박은정',
#   'publisher': '웅진북클럽',
#   'issuedYear': '2016',
#   'kdc': '375.1',
#   'kdcKdcDescription': '교육학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '누가 따라 하지?',
#   'creator': '김진화',
#   'publisher': '웅진북클럽',
#   'issuedYear': '2016',
#   'kdc': '375.1',
#   'kdcKdcDescription': '교육학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '베자르의 금화',
#   'creator': '박영란',
#   'publisher': '웅진씽크빅',
#   'issuedYear': '2016',
#   'kdc': '410',
#   'kdcKdcDescription': '수학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '떡갈나무 숲의 둠둠이',
#   'creator': '나은희',
#   'publisher': '웅진북클럽',
#   'issuedYear': '2016',
#   'kdc': '410',
#   'kdcKdcDescription': '수학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '난쟁이 꼬파니까를 물리쳐라!',
#   'creator': '김성희',
#   'publisher': '웅진씽크빅',
#   'issuedYear': '2016',
#   'kdc': '410',
#   'kdcKdcDescription': '수학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '왕자와 네 명의 재주꾼',
#   'creator': '김은혜',
#   'publisher': '웅진씽크빅',
#   'issuedYear': '2016',
#   'kdc': '410',
#   'kdcKdcDescription': '수학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '시계를 잘 보고 싶어요',
#   'creator': '이형진',
#   'publisher': '웅진씽크빅',
#   'issuedYear': '2016',
#   'kdc': '410',
#   'kdcKdcDescription': '수학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '수',
#   'creator': '나은희',
#   'publisher': '웅진씽크빅',
#   'issuedYear': '2016',
#   'kdc': '410',
#   'kdcKdcDescription': '수학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '(꿈의 화가) 르네 마그리트',
#   'creator': 'Verplancke, Klaas',
#   'publisher': '주니어RHK',
#   'issuedYear': '2016',
#   'kdc': '653',
#   'kdcKdcDescription': '회화, 도화',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': "Magritte's apple",
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10941812'},
#  {'title': '통합 지식 100',
#   'creator': '주영하',
#   'publisher': '알에이치코리아',
#   'issuedYear': '2016',
#   'kdc': '808.3',
#   'kdcKdcDescription': '문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '통합 지식 백',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10899250'},
#  {'title': '(집중력 폭발) 명화 수수께끼',
#   'creator': None,
#   'publisher': '알에이치코리아',
#   'issuedYear': '2016',
#   'kdc': '653',
#   'kdcKdcDescription': '회화, 도화',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10964323'},
#  {'title': '코끼리 똥 호박',
#   'creator': '고향옥',
#   'publisher': '웅진씽크빅',
#   'issuedYear': '2016',
#   'kdc': '833.6',
#   'kdcKdcDescription': '일본문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': "ぞうとかぽちゃ = (The) sweet pumpkins born from elephant's poops",
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10896643'},
#  {'title': '무지개상자 음악이론',
#   'creator': '이주연',
#   'publisher': '예솔',
#   'issuedYear': '2016',
#   'kdc': '671',
#   'kdcKdcDescription': '음악',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11068382'},
#  {'title': '재미있게 읽는 수학개념',
#   'creator': 'Pinder, Andrew',
#   'publisher': '청년사',
#   'issuedYear': '2016',
#   'kdc': '410',
#   'kdcKdcDescription': '수학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'cool maths stuff you need to know',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10235588'},
#  {'title': '윌리와 구름 한 조각',
#   'creator': '조은수',
#   'publisher': '웅진주니어',
#   'issuedYear': '2016',
#   'kdc': '843',
#   'kdcKdcDescription': '영미문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Willy and the cloud',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10710742'},
#  {'title': '가짜 일기 전쟁',
#   'creator': '전은지',
#   'publisher': '김영사',
#   'issuedYear': '2016',
#   'kdc': '813.7',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10440138'},
#  {'title': '헬로 오지니',
#   'creator': '현숙희',
#   'publisher': '주니어김영사',
#   'issuedYear': '2016',
#   'kdc': '813.7',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10651813'},
#  {'title': '막대기는 생각했지',
#   'creator': '차영미',
#   'publisher': '소야',
#   'issuedYear': '2016',
#   'kdc': '811.8',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10882073'},
#  {'title': '피었다, 활짝 피었다',
#   'creator': '신슬기',
#   'publisher': '국민서관',
#   'issuedYear': '2016',
#   'kdc': '811.8',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10897685'},
#  {'title': '안전 지킴이',
#   'creator': '궁쉰',
#   'publisher': '주니어이서원',
#   'issuedYear': '2015',
#   'kdc': '372.42',
#   'kdcKdcDescription': '교육학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '儿童安全自救手册',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=9414601'},
#  {'title': '검은고양이 하얀고양이',
#   'creator': '와카야마 시즈코',
#   'publisher': '이서원',
#   'issuedYear': '2016',
#   'kdc': '833.6',
#   'kdcKdcDescription': '일본문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'くろねこさんしろねこさん',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10167955'},
#  {'title': '물결아줌마 치맛자락',
#   'creator': '김정숙',
#   'publisher': '한그루',
#   'issuedYear': '2015',
#   'kdc': '813.7',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=9708045'},
#  {'title': '(만점을 위한 얕고 넓은) 세계사 툰',
#   'creator': None,
#   'publisher': '씽크스마트',
#   'issuedYear': '2016',
#   'kdc': '909',
#   'kdcKdcDescription': '역사',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '(무지무지 유익한) 만화세계사',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10728156'},
#  {'title': '(Disney) 정글북',
#   'creator': 'Kipling, Rudyard',
#   'publisher': '대원씨아이',
#   'issuedYear': '2016',
#   'kdc': '843',
#   'kdcKdcDescription': '영미문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Jungle book',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10627804'},
#  {'title': '(마법 고양이 쿠마오와) 깜짝 생일 파티!',
#   'creator': '매이 봄',
#   'publisher': '어썸월드',
#   'issuedYear': '2016',
#   'kdc': '813.7',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10129748'},
#  {'title': '(소문난) 학교 미스터리',
#   'creator': 'Laruha',
#   'publisher': '학산문화사',
#   'issuedYear': '2016',
#   'kdc': '001',
#   'kdcKdcDescription': '총류',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '女の子の本当にこわい恐怖のうわさ話',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10807516'},
#  {'title': '틱과 투렛 증후군이 뭔지 알려 줄게!',
#   'creator': 'Vézina, Dominique',
#   'publisher': '한울림스페셜',
#   'issuedYear': '2016',
#   'kdc': '516',
#   'kdcKdcDescription': '의학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Syndrome de Gilles de la Tourete',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10128317'},
#  {'title': '나마녀 선생 여행을 떠나다',
#   'creator': '정인',
#   'publisher': '퍼플(Pubple)',
#   'issuedYear': '2016',
#   'kdc': '813.7',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=13746720'},
#  {'title': '나마녀 선생 여행을 떠나다',
#   'creator': '정인',
#   'publisher': '퍼플(Pubple)',
#   'issuedYear': '2016',
#   'kdc': '813.7',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '제 6권 나마녀 선생, 영국에 가다',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=13746719'},
#  {'title': '나마녀 선생 이집트에 가다',
#   'creator': '정인',
#   'publisher': '퍼플(Pubple)',
#   'issuedYear': '2016',
#   'kdc': '813.7',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=13746718'},
#  {'title': '나마녀 선생 여행을 떠나다 7, 8, 9, 10권 합본',
#   'creator': '정인',
#   'publisher': '퍼플(Pubple)',
#   'issuedYear': '2016',
#   'kdc': '813.7',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '10권 나마녀 선생, 이집트에 가다',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=13746716'},
#  {'title': '(쓰고 그리고 찾으면서 머리가 좋아지는) 톡톡 창의력 미로 찾기',
#   'creator': None,
#   'publisher': '한빛에듀',
#   'issuedYear': '2016',
#   'kdc': '691',
#   'kdcKdcDescription': '오락, 운동',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '(접고 붙이고 상상하며 머리가 좋아지는) 톡톡 창의력 종이 접기',
#   'creator': None,
#   'publisher': '한빛에듀',
#   'issuedYear': '2016',
#   'kdc': '634',
#   'kdcKdcDescription': '공예, 장식미술',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10479445'},
#  {'title': '파란 집에 여름이 왔어요',
#   'creator': 'Hallensleben, Georg',
#   'publisher': '보림',
#   'issuedYear': '2016',
#   'kdc': '843',
#   'kdcKdcDescription': '영미문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Great blue house',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10932578'},
#  {'title': '심해의 무법자',
#   'creator': 'Rake, Matthew',
#   'publisher': '봄나무',
#   'issuedYear': '2016',
#   'kdc': '491',
#   'kdcKdcDescription': '동물학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Creatures of the deep',
#   'seeAlso': None},
#  {'title': '열대 우림의 무법자',
#   'creator': 'Rake, Matthew',
#   'publisher': '봄나무',
#   'issuedYear': '2016',
#   'kdc': '491',
#   'kdcKdcDescription': '동물학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Real-life monsters in the rainforest',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10900311'},
#  {'title': '눈으로 배우는 수학',
#   'creator': '도가우치, 다이시',
#   'publisher': '이너북주니어',
#   'issuedYear': '2016',
#   'kdc': '410',
#   'kdcKdcDescription': '수학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '目でみる算数の図鑑',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10911249'},
#  {'title': '(중·고등학생을 위한) 성신여자대학교 진로진학 가이드북',
#   'creator': None,
#   'publisher': '성신여자대학교 출판부',
#   'issuedYear': '2016',
#   'kdc': '372',
#   'kdcKdcDescription': '교육학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '미술대학 음악대학 융합문화예술대학 뷰티 생활산업국제대학',
#   'seeAlso': None},
#  {'title': '프레지던트 힐러리',
#   'creator': '김미선',
#   'publisher': '움직이는서재',
#   'issuedYear': '2016',
#   'kdc': '998.3',
#   'kdcKdcDescription': '전기',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'a woman living history',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10882791'},
#  {'title': '표준어 한글 완전학습',
#   'creator': '정진철',
#   'publisher': 'Pubple(퍼플)',
#   'issuedYear': '2016',
#   'kdc': '711',
#   'kdcKdcDescription': '한국어',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=13746790'},
#  {'title': '초등학교 6학년의 독서록 100편',
#   'creator': '문성환',
#   'publisher': '퍼플',
#   'issuedYear': '2016',
#   'kdc': '029',
#   'kdcKdcDescription': '문헌정보학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '초등학교 육학년의 독서록 백편',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=13746762'},
#  {'title': '중학교 필수 900 한자',
#   'creator': '이한규',
#   'publisher': 'Pubple(퍼플)',
#   'issuedYear': '2016',
#   'kdc': '711.4',
#   'kdcKdcDescription': '한국어',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '중학교 필수 구백 한자',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=13746717'},
#  {'title': '학생부종합전형에 강한 김대승 배경지식 비밀노트',
#   'creator': '김대승',
#   'publisher': 'Pubple(퍼플)',
#   'issuedYear': '2016',
#   'kdc': '001',
#   'kdcKdcDescription': '총류',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '김대승배경지식 비밀노트',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=13709476'},
#  {'title': '최고의 시험문법',
#   'creator': '황선웅',
#   'publisher': '퍼플(Pubple)',
#   'issuedYear': '2016',
#   'kdc': '745',
#   'kdcKdcDescription': '영어',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=13746792'},
#  {'title': '병아리 싸움',
#   'creator': '안선재',
#   'publisher': '바우솔',
#   'issuedYear': '2016',
#   'kdc': '811.8',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11049668'},
#  {'title': '세계사 여행',
#   'creator': '박민지',
#   'publisher': '감돌역사',
#   'issuedYear': '2013',
#   'kdc': '909',
#   'kdcKdcDescription': '역사',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '고대 2 - 통일제국의 등장 2',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=9154814'},
#  {'title': '한뼘 더!',
#   'creator': '이정우',
#   'publisher': '지혜나무',
#   'issuedYear': '2015',
#   'kdc': '816.7',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=9229971'},
#  {'title': 'Enjoy writing books',
#   'creator': '김민현',
#   'publisher': '지혜나무',
#   'issuedYear': '2015',
#   'kdc': '810.8',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '엔조이 라이팅북스',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=9229962'},
#  {'title': '거꾸로 도덕',
#   'creator': '황수현',
#   'publisher': '지혜나무',
#   'issuedYear': '2015',
#   'kdc': '810.8',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=9229974'},
#  {'title': '붉고 희고 푸른',
#   'creator': '최인경',
#   'publisher': '지혜나무',
#   'issuedYear': '2015',
#   'kdc': '813.7',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '붉은 꽃',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=9229972'},
#  {'title': '열여덟 소녀들, 전통시장을 찾다!!',
#   'creator': None,
#   'publisher': '지혜나무',
#   'issuedYear': '2015',
#   'kdc': '818',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=9229283'},
#  {'title': '너와 함께 걷는 길',
#   'creator': '김다정',
#   'publisher': '지혜나무',
#   'issuedYear': '2015',
#   'kdc': '810.8',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=9229973'},
#  {'title': '다르지만 비슷한 우리',
#   'creator': '정하연',
#   'publisher': '지혜나무',
#   'issuedYear': '2016',
#   'kdc': '818',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '궁금하고 알고 싶은 고등학생 노하우',
#   'seeAlso': None},
#  {'title': '맛있는 중학생활 레시피',
#   'creator': '손현락',
#   'publisher': '지혜나무',
#   'issuedYear': '2016',
#   'kdc': '818',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10732097'},
#  {'title': '경남아동문학 대표작선집',
#   'creator': '정이식',
#   'publisher': '경남아동문학회',
#   'issuedYear': '2016',
#   'kdc': '810.8',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11037775'},
#  {'title': '가거라 용감하게, 아들아!',
#   'creator': '박홍규',
#   'publisher': '들녘',
#   'issuedYear': '2016',
#   'kdc': '820.9',
#   'kdcKdcDescription': '중국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10980891'},
#  {'title': '최고의 독해문법',
#   'creator': '황선웅',
#   'publisher': '퍼플(puple)',
#   'issuedYear': '2016',
#   'kdc': '747',
#   'kdcKdcDescription': '영어',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '할아버지의 시계',
#   'creator': '홍성찬',
#   'publisher': '[발행처불명]',
#   'issuedYear': None,
#   'kdc': '813.7',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '나를 따라온 감자',
#   'creator': '정승희',
#   'publisher': '바람의 아이들',
#   'issuedYear': '2016',
#   'kdc': '813.7',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10882172'},
#  {'title': '동물원이 된 궁궐',
#   'creator': '김명희',
#   'publisher': '상수리',
#   'issuedYear': '2016',
#   'kdc': '911',
#   'kdcKdcDescription': '아시아(아세아)',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10844188'},
#  {'title': '사자가 공짜!',
#   'creator': 'Field, Jim',
#   'publisher': '책과콩나무',
#   'issuedYear': '2016',
#   'kdc': '843',
#   'kdcKdcDescription': '영미문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': "There's a lion in my cornflakes",
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10882163'},
#  {'title': '주빵 찐빵 병원 놀이',
#   'creator': '송언',
#   'publisher': '파랑새',
#   'issuedYear': '2016',
#   'kdc': '813.7',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10870475'},
#  {'title': '심술쟁이 친구를 만났을 때',
#   'creator': 'Butterley, Mikki',
#   'publisher': '키즈엠',
#   'issuedYear': '2016',
#   'kdc': '843',
#   'kdcKdcDescription': '영미문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'Pickle & Bree the playground meanies',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10882142'},
# ...
#   'kdcKdcDescription': '풍속, 민속학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '마음을 움직이는 음악',
#   'creator': '윤희정',
#   'publisher': 'Daekyo(대교)',
#   'issuedYear': '2016',
#   'kdc': '670',
#   'kdcKdcDescription': '음악',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '행복을 그리는 미술',
#   'creator': '전재은',
#   'publisher': '대교 소빅스',
#   'issuedYear': '2016',
#   'kdc': '650',
#   'kdcKdcDescription': '회화, 도화',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '몸으로 하는 놀이, 스포츠',
#   'creator': '김창희',
#   'publisher': '대교 소빅스',
#   'issuedYear': '2016',
#   'kdc': '692',
#   'kdcKdcDescription': '오락, 운동',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '갈릴레이의 우주 노트',
#   'creator': '최수영',
#   'publisher': 'Daekyo(대교)',
#   'issuedYear': '2016',
#   'kdc': '082',
#   'kdcKdcDescription': '일반전집, 총서',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '지구는 살아 있다',
#   'creator': '신현정',
#   'publisher': '대교 소빅스',
#   'issuedYear': '2016',
#   'kdc': '082',
#   'kdcKdcDescription': '일반전집, 총서',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '살아 숨 쉬는 생명',
#   'creator': '한영식',
#   'publisher': 'Daekyo(대교)',
#   'issuedYear': '2016',
#   'kdc': '472',
#   'kdcKdcDescription': '생명과학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '탄소 발자국을 줄이는 방법',
#   'creator': '김창희',
#   'publisher': 'Daekyo(대교)',
#   'issuedYear': '2016',
#   'kdc': '082',
#   'kdcKdcDescription': '일반전집, 총서',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '미리 만나는 미래 과학',
#   'creator': '양대승',
#   'publisher': 'Daekyo(대교)',
#   'issuedYear': '2016',
#   'kdc': '400',
#   'kdcKdcDescription': '자연과학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '그게 바로 편견이야!',
#   'creator': '한승임',
#   'publisher': '대교 소빅스',
#   'issuedYear': '2016',
#   'kdc': '330',
#   'kdcKdcDescription': '사회학, 사회문제',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '출발! 발바닥 탐험대',
#   'creator': '나은희',
#   'publisher': 'Daekyo(대교)',
#   'issuedYear': '2016',
#   'kdc': '082',
#   'kdcKdcDescription': '일반전집, 총서',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '더워요, 추워요!',
#   'creator': '김상인',
#   'publisher': '대교 소빅스',
#   'issuedYear': '2016',
#   'kdc': '453',
#   'kdcKdcDescription': '지학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '기호야, 기호야, 모여라!',
#   'creator': '신순재',
#   'publisher': 'Daekyo(대교)',
#   'issuedYear': '2016',
#   'kdc': '300',
#   'kdcKdcDescription': '사회과학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '우리는 서로 이어져 있어!',
#   'creator': '김성은',
#   'publisher': 'Daekyo(대교)',
#   'issuedYear': '2016',
#   'kdc': '082',
#   'kdcKdcDescription': '일반전집, 총서',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '이렇게 하면 어떻게 될까?',
#   'creator': '서보현',
#   'publisher': '대교 소빅스',
#   'issuedYear': '2016',
#   'kdc': '082',
#   'kdcKdcDescription': '일반전집, 총서',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '이럴 땐 이렇게 재는 거야!',
#   'creator': '정순희',
#   'publisher': 'Daekyo(대교)',
#   'issuedYear': '2016',
#   'kdc': '082',
#   'kdcKdcDescription': '일반전집, 총서',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '예술가들의 놀라운 영감 박물관',
#   'creator': '조은수',
#   'publisher': 'Daekyo(대교)',
#   'issuedYear': '2016',
#   'kdc': '600',
#   'kdcKdcDescription': '예술',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '와글와글 신나는 놀이와 축제',
#   'creator': '한성미',
#   'publisher': 'Daekyo(대교)',
#   'issuedYear': '2016',
#   'kdc': '082',
#   'kdcKdcDescription': '일반전집, 총서',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '두부 공장의 하루로 보는 시장과 경제',
#   'creator': '박영란',
#   'publisher': 'Daekyo(대교)',
#   'issuedYear': '2016',
#   'kdc': '320',
#   'kdcKdcDescription': '경제학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '문화유산으로 역사 퍼즐 맞추기',
#   'creator': '서보현',
#   'publisher': '대교 소빅스',
#   'issuedYear': '2016',
#   'kdc': '911',
#   'kdcKdcDescription': '아시아(아세아)',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '똑똑하게 싸우는 법',
#   'creator': '김영',
#   'publisher': 'Daekyo(대교)',
#   'issuedYear': '2016',
#   'kdc': '082',
#   'kdcKdcDescription': '일반전집, 총서',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '뚝딱뚝딱 어린이 건축 학교',
#   'creator': '정명순',
#   'publisher': 'Daekyo(대교)',
#   'issuedYear': '2016',
#   'kdc': '540',
#   'kdcKdcDescription': '건축공학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '좌충우돌 이야기 만들기',
#   'creator': '조미자',
#   'publisher': 'Daekyo(대교)',
#   'issuedYear': '2016',
#   'kdc': '800',
#   'kdcKdcDescription': '문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '별별 물질 탐구',
#   'creator': '영민',
#   'publisher': '대교 소빅스',
#   'issuedYear': '2016',
#   'kdc': '082',
#   'kdcKdcDescription': '일반전집, 총서',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '소리로 가득 찬 세상',
#   'creator': '임영란',
#   'publisher': 'Daekyo(대교)',
#   'issuedYear': '2016',
#   'kdc': '511',
#   'kdcKdcDescription': '의학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '힘이 불끈, 에너지가 쑥쑥!',
#   'creator': '송은영',
#   'publisher': 'Daekyo(대교)',
#   'issuedYear': '2016',
#   'kdc': '082',
#   'kdcKdcDescription': '일반전집, 총서',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '모두모두 도형이야!',
#   'creator': '강혜영',
#   'publisher': '대교 소빅스',
#   'issuedYear': '2016',
#   'kdc': '410',
#   'kdcKdcDescription': '수학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '규칙 씨의 규칙적인 하루',
#   'creator': '김창희',
#   'publisher': 'Daekyo(대교)',
#   'issuedYear': '2016',
#   'kdc': '410',
#   'kdcKdcDescription': '수학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '째깍 귀신과 함께하는 시간 탐험',
#   'creator': '박용기',
#   'publisher': '대교 소빅스',
#   'issuedYear': '2016',
#   'kdc': '410',
#   'kdcKdcDescription': '수학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '초대하지 않은 손님, 질병',
#   'creator': '조은애',
#   'publisher': '대교 소빅스',
#   'issuedYear': '2016',
#   'kdc': '517',
#   'kdcKdcDescription': '의학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '놀랍지 않니? 세상을 바꾼 기술!',
#   'creator': '안성훈',
#   'publisher': '대교 소빅스',
#   'issuedYear': '2016',
#   'kdc': '500',
#   'kdcKdcDescription': '기술과학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '동이의 미디어 정복기',
#   'creator': '이미현',
#   'publisher': '대교 소빅스',
#   'issuedYear': '2016',
#   'kdc': '082',
#   'kdcKdcDescription': '일반전집, 총서',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '이글맨의 안전 수칙 대작전',
#   'creator': '박은호',
#   'publisher': 'Daekyo(대교)',
#   'issuedYear': '2016',
#   'kdc': '082',
#   'kdcKdcDescription': '일반전집, 총서',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '궁금증 대장 찬이와 떠나는 공동체',
#   'creator': '김창희',
#   'publisher': '대교 소빅스',
#   'issuedYear': '2016',
#   'kdc': '331',
#   'kdcKdcDescription': '사회학, 사회문제',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '얘들아, 인권을 부탁해!',
#   'creator': '허은실',
#   'publisher': '대교 소빅스',
#   'issuedYear': '2016',
#   'kdc': '082',
#   'kdcKdcDescription': '일반전집, 총서',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '(공부가 즐거워지는) 교과탐구백과',
#   'creator': '이갑규',
#   'publisher': 'Daekyo(대교)',
#   'issuedYear': '2016',
#   'kdc': '082',
#   'kdcKdcDescription': '일반전집, 총서',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': None},
#  {'title': '동물 탐험 여행',
#   'creator': '고정아',
#   'publisher': '문학수첩리틀북',
#   'issuedYear': '2016',
#   'kdc': '491',
#   'kdcKdcDescription': '동물학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': 'My animal book',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11134201'},
#  {'title': '백년을 기다린 대나무꽃',
#   'creator': '이한중',
#   'publisher': '아침마중',
#   'issuedYear': '2016',
#   'kdc': '813.7',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '칠석날 밤',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11222866'},
#  {'title': '나는 거짓말쟁이가 아니에요',
#   'creator': '이규경',
#   'publisher': '아동문예',
#   'issuedYear': '2016',
#   'kdc': '813.7',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '나미는 행복해',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11197923'},
#  {'title': '볼록볼록 웃고 있어요',
#   'creator': '이한중',
#   'publisher': '아동문예',
#   'issuedYear': '2016',
#   'kdc': '811.8',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11213220'},
#  {'title': '(밑줄 쫙!) 교과서 과학실험노트',
#   'creator': None,
#   'publisher': '국민출판',
#   'issuedYear': '2016',
#   'kdc': '400',
#   'kdcKdcDescription': '자연과학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11197123'},
#  {'title': '이곳저곳 우리 동네 지도대장 나기호가 간다!',
#   'creator': '김평',
#   'publisher': '가나문화콘텐츠',
#   'issuedYear': '2016',
#   'kdc': '446',
#   'kdcKdcDescription': '천문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11196673'},
#  {'title': '새야 새야',
#   'creator': '김종상',
#   'publisher': '파란정원',
#   'issuedYear': '2016',
#   'kdc': '811.8',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11185318'},
#  {'title': '바쁜 중3을 위한 빠른 중학연산',
#   'creator': '임미연',
#   'publisher': '이지스에듀',
#   'issuedYear': '2016',
#   'kdc': '410',
#   'kdcKdcDescription': '수학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '제곱근과 실수, 인수분해 영역',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11432891'},
#  {'title': '원리를 더한 영문법',
#   'creator': None,
#   'publisher': '능률교육',
#   'issuedYear': '2016',
#   'kdc': '745',
#   'kdcKdcDescription': '영어',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '원더 영문법',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11191696'},
#  {'title': 'Grammar zone workbook',
#   'creator': None,
#   'publisher': '능률교육',
#   'issuedYear': '2016',
#   'kdc': '745',
#   'kdcKdcDescription': '영어',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '그래머 존 워크북',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11124221'},
#  {'title': 'Grammar zone workbook',
#   'creator': None,
#   'publisher': '능률교육',
#   'issuedYear': '2016',
#   'kdc': '745',
#   'kdcKdcDescription': '영어',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '그래머 존 워크북',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11124225'},
#  {'title': 'Grammar zone workbook',
#   'creator': None,
#   'publisher': '능률교육',
#   'issuedYear': '2016',
#   'kdc': '745',
#   'kdcKdcDescription': '영어',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '그래머 존 워크북',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11124227'},
#  {'title': 'Grammar zone',
#   'creator': None,
#   'publisher': '능률교육',
#   'issuedYear': '2016',
#   'kdc': '745',
#   'kdcKdcDescription': '영어',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '그래머 존',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11124218'},
#  {'title': 'Grammar zone',
#   'creator': None,
#   'publisher': '능률교육',
#   'issuedYear': '2016',
#   'kdc': '745',
#   'kdcKdcDescription': '영어',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '그래머 존',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11124223'},
#  {'title': 'Grammar zone',
#   'creator': None,
#   'publisher': '능률교육',
#   'issuedYear': '2016',
#   'kdc': '745',
#   'kdcKdcDescription': '영어',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '그래머 존',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11124226'},
#  {'title': '색시한 세상의 모든 듄(EBS)변형 수능영어',
#   'creator': '배기환',
#   'publisher': '오르비북스',
#   'issuedYear': '2016',
#   'kdc': '740',
#   'kdcKdcDescription': '영어',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '색시한 수능영어 세모변',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11172491'},
#  {'title': '독수공방 E변형',
#   'creator': '권기홍',
#   'publisher': '오르비북스',
#   'issuedYear': '2016',
#   'kdc': '740',
#   'kdcKdcDescription': '영어',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11172492'},
#  {'title': '교과서 독해',
#   'creator': '한은영',
#   'publisher': '오르비북스',
#   'issuedYear': '2016',
#   'kdc': '717',
#   'kdcKdcDescription': '한국어',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11185302'},
#  {'title': '하마가 사라졌다',
#   'creator': '이소영',
#   'publisher': '가문비',
#   'issuedYear': '2016',
#   'kdc': '813.7',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11124440'},
#  {'title': '역사 한 그릇 뚝딱',
#   'creator': '민들레',
#   'publisher': '루크하우스',
#   'issuedYear': '2016',
#   'kdc': '594',
#   'kdcKdcDescription': '가정학 및 가정생활',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11124746'},
#  {'title': '물 소중해? 물론이지!',
#   'creator': '고여주',
#   'publisher': '루크하우스',
#   'issuedYear': '2016',
#   'kdc': '458',
#   'kdcKdcDescription': '지학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11663555'},
#  {'title': '(똑똑해지는) 숨바꼭질 100',
#   'creator': '김경희',
#   'publisher': '맥스교육',
#   'issuedYear': '2016',
#   'kdc': '410',
#   'kdcKdcDescription': '수학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '숨바꼭질 백',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11140951'},
#  {'title': '소방관 고양이 초이',
#   'creator': '김유진',
#   'publisher': '머스트비',
#   'issuedYear': '2016',
#   'kdc': '813.7',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11134161'},
#  {'title': '우리 가족',
#   'creator': '하세가와 슈헤이',
#   'publisher': '문학과지성사',
#   'issuedYear': '2016',
#   'kdc': '833.6',
#   'kdcKdcDescription': '일본문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '大きな大きな船',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=11124292'},
#  {'title': '(고양이 가장의) 기묘한 돈벌이',
#   'creator': '보린',
#   'publisher': '문학동네',
#   'issuedYear': '2016',
#   'kdc': '813.7',
#   'kdcKdcDescription': '한국문학',
#   'ddc': None,
#   'mainDdcDescription': '상위 분류 없음',
#   'alternative': '황천택배 헬택배',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=12874122'},
#  ...]

# %%
with open('processed_books.json', 'w', encoding='utf-8') as file:
    json.dump(processed_books, file, ensure_ascii=False, indent=4)

# %%
import json  #json 파일 합치기
import glob

# 여러 JSON 파일을 불러와 합칠 리스트
all_data = []

# 특정 폴더에 있는 모든 JSON 파일을 불러옴 (예: 'data/' 폴더에 *.json 파일)
for file_name in glob.glob('data/*.json'):
    with open(file_name, 'r', encoding='utf-8') as file:
        data = json.load(file)
        all_data.extend(data)  # 데이터를 리스트에 추가

# 합친 데이터를 하나의 JSON 파일로 저장
with open('merged_data.json', 'w', encoding='utf-8') as output_file:
    json.dump(all_data, output_file, ensure_ascii=False, indent=4)

print("모든 파일이 merged_data.json에 성공적으로 합쳐졌습니다.")
