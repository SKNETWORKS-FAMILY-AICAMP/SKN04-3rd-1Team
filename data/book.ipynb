# %%
import json
import re

# %%
with open('./data/graph_section_59.json', 'r', encoding='utf-8') as file:
    data = json.load(file)
    books = data.get('@graph', [])

# %%
kdc_categories = {
    "00": "총류",
    "01": "도서관, 서지학",
    "02": "문헌정보학",
    "03": "백과사전",
    "04": "강연집, 수필집, 연설문집",
    "05": "일반 연속간행물",
    "06": "일반학회, 단체, 협회, 기관",
    "07": "신문, 언론, 저널리즘",
    "08": "일반전집, 총서",
    "09": "향토자료",

    "10": "철학",
    "11": "형이상학",
    "12": "인식론, 인과론, 인간학",
    "13": "철학의 체계",
    "14": "경학",
    "15": "아시아철학, 사상",
    "16": "서양철학",
    "17": "논리학",
    "18": "심리학",
    "19": "윤리학, 도덕철학",

    "20": "종교",
    "21": "비교종교",
    "22": "불교",
    "23": "기독교",
    "24": "도교",
    "25": "천도교",
    "26": "신도",
    "27": "파라문교, 인도교",
    "28": "회교(이슬람교)",
    "29": "기타 제종교",

    "30": "사회과학",
    "31": "통계학",
    "32": "경제학",
    "33": "사회학, 사회문제",
    "34": "정치학",
    "35": "행정학",
    "36": "법학",
    "37": "교육학",
    "38": "풍속, 민속학",
    "39": "국방, 군사학",

    "40": "자연과학",
    "41": "수학",
    "42": "물리학",
    "43": "화학",
    "44": "천문학",
    "45": "지학",
    "46": "광물학",
    "47": "생명과학",
    "48": "식물학",
    "49": "동물학",

    "50": "기술과학",
    "51": "의학",
    "52": "농업, 농학",
    "53": "공학, 공학일반",
    "54": "건축공학",
    "55": "기계공학",
    "56": "전기공학, 전자공학",
    "57": "화학공학",
    "58": "제조업",
    "59": "가정학 및 가정생활",

    "60": "예술",
    "61": "건축술",
    "62": "조각",
    "63": "공예, 장식미술",
    "64": "서예",
    "65": "회화, 도화",
    "66": "사진술",
    "67": "음악",
    "68": "연극",
    "69": "오락, 운동",

    "70": "언어",
    "71": "한국어",
    "72": "중국어",
    "73": "일본어",
    "74": "영어",
    "75": "독일어",
    "76": "프랑스어",
    "77": "스페인어",
    "78": "이탈리아어",
    "79": "기타제어",

    "80": "문학",
    "81": "한국문학",
    "82": "중국문학",
    "83": "일본문학",
    "84": "영미문학",
    "85": "독일문학",
    "86": "프랑스문학",
    "87": "스페인문학",
    "88": "이탈리아문학",
    "89": "기타 제문학",

    "90": "역사",
    "91": "아시아(아세아)",
    "92": "유럽(구라파)",
    "93": "아프리카",
    "94": "북아메리카(북미)",
    "95": "남아메리카(남미)",
    "96": "오세아니아(대양주)",
    "97": "양극지방",
    "98": "지리",
    "99": "전기"
}

# %%
ddc_categories = {
    "00": "총류",
    "01": "서지",
    "02": "문헌정보학",
    "03": "백과사전",
    "04": "공기호",
    "05": "잡지, 저널, 연속간행물",
    "06": "협회, 박물관학",
    "07": "뉴스 매체, 저널리즘, 출판",
    "08": "일반전집",
    "09": "필사본, 희귀서적",

    "10": "철학",
    "11": "형이상학",
    "12": "인식론",
    "13": "초상현상",
    "14": "철학파",
    "15": "심리학",
    "16": "철학 논리",
    "17": "윤리학",
    "18": "고대, 중세, 동양철학",
    "19": "현대 서양철학",

    "20": "종교",
    "21": "종교철학과 이론",
    "22": "성서",
    "23": "기독교와 기독교 신학",
    "24": "기독교 실천과 교리준수",
    "25": "기독교 목회자의 실천과 종파",
    "26": "기독교 사회 신학",
    "27": "기독교 역사",
    "28": "기독교 교파",
    "29": "기타 종교",

    "30": "사회과학",
    "31": "통계학",
    "32": "정치학",
    "33": "경제학",
    "34": "법학",
    "35": "행정학과 군사학",
    "36": "사회서비스",
    "37": "교육",
    "38": "무역 통신과 수송",
    "39": "관습, 에티켓과 민속전통",

    "40": "언어",
    "41": "언어학",
    "42": "영어와 고대언어",
    "43": "독일어 관련언어",
    "44": "프랑스 관련언어",
    "45": "이탈리아, 루마니아어",
    "46": "스페인, 포르투갈어",
    "47": "라틴과 이탤릭 언어",
    "48": "고대, 현대 그리서어",
    "49": "기타 언어",

    "50": "과학",
    "51": "수학",
    "52": "천문학",
    "53": "물리학",
    "54": "화학",
    "55": "지구과학",
    "56": "고생물학",
    "57": "생물학",
    "58": "식물학",
    "59": "동물학",

    "60": "기술",
    "61": "의학",
    "62": "공학",
    "63": "농업",
    "64": "가정, 가족경영",
    "65": "경영과 홍보",
    "66": "화학공학",
    "67": "제조",
    "68": "특별한 용도의 제조",
    "69": "건축",

    "70": "예술, 레크리에이션",
    "71": "도시계획, 조경술",
    "72": "건축학",
    "73": "조각품, 도예와 금속제품",
    "74": "인쇄예술",
    "75": "그림",
    "76": "제작술",
    "77": "사진술",
    "78": "음악",
    "79": "스포츠, 게임",

    "80": "문학",
    "81": "미국문학",
    "82": "영어, 고대영어문학",
    "83": "독일 문학",
    "84": "프랑스 문학",
    "85": "이탈리아 문학",
    "86": "스페인, 포르투갈 문학",
    "87": "라틴 문학",
    "88": "그리스 문학",
    "89": "기타 문학",

    "90": "역사, 지리",
    "91": "지리와 여행",
    "92": "전기와 계보학",
    "93": "고대 역사",
    "94": "유럽 역사",
    "95": "아시아 역사",
    "96": "아프리카 역사",
    "97": "북아메리카 역사",
    "98": "남아메리카 역사",
    "99": "기타지역 역사"
}

# %%
data
# Out:
# {'@graph': [{'@id': 'nlk:KAC201832377',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '220p.: 삽도; 23cm',
#    'audienceNote': '일반이용자',
#    'bibliography': '참고문헌: p.218-220',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '089.957',
#    'ddcn': 'http://lod.nl.go.kr/ddc/089_e21',
#    'genre': '일반도서',
#    'kdc': '041',
#    'kdcn': 'http://lod.nl.go.kr/kdc/041_e4',
#    'keyword': '세상',
#    'publicationPlace': '서울',
#    'typeOfResource': 'nlk:text',
#    'creator': '장사주',
#    'publisher': '三光出版社',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200408581',
#    'issued': '2003',
#    'title': '우주를 보고 세상을 보면',
#    'isbn': '8982531076',
#    'label': '우주를 보고 세상을 보면'},
#   {'@id': 'nlk:KAC201326851',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '275p.: 삽도; 23cm',
#    'audienceNote': '일반이용자',
#    'bibliography': '색인수록',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '901',
#    'ddcn': 'http://lod.nl.go.kr/ddc/901_e21',
#    'genre': '일반도서',
#    'kdc': '901',
#    'kdcn': 'http://lod.nl.go.kr/kdc/901_e4',
#    'keyword': 'PAST',
#    'publicationPlace': '서울',
#    'remainderOfTitle': '역사가는 과거를 어떻게 그리는가',
#    'typeOfResource': 'nlk:text',
#    'creator': 'Gaddis, John Lewis',
#    'publisher': '에코리브르',
#    'accessRights': 'nlk:license3',
#    'alternative': 'Landscape of history : how historians map the past',
#    'description': 'Gaddis, John Lewis',
#    'hasFormat': 'nlk:KMO200408603',
#    'issued': '2004',
#    'language': 'http://lod.nl.go.kr/countries/KOR',
#    'title': '역사의 풍경',
#    'isbn': '8990048273',
#    'label': '역사의 풍경',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=144891',
#    'sameAs': 'http://data.nanet.go.kr/ontology/NANET_BIB_MONO1200404154'},
#   {'@id': 'nlk:KAC200205559',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '140p.: 삽도; 20cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '843.914',
#    'ddcn': 'http://lod.nl.go.kr/ddc/843_e21',
#    'genre': '일반도서',
#    'kdc': '863',
#    'kdcn': 'http://lod.nl.go.kr/kdc/863_e4',
#    'keyword': '오스카',
#    'publicationPlace': '서울',
#    'restriction': '국립중앙도서관, 국립어린이청소년도서관, 국립세종도서관, 협력기관(공공.대학.전문/특수.해외.작은도서관) 공개',
#    'typeOfResource': 'nlk:text',
#    'creator': '이승경',
#    'publisher': '문학세계사',
#    'accessRights': 'nlk:license3',
#    'alternative': 'Oscar et la dame rose',
#    'description': 'Schmitt, Eric-Emmanuel',
#    'hasFormat': 'nlk:KMO200408605',
#    'issued': '2004',
#    'language': 'http://lod.nl.go.kr/countries/KOR',
#    'title': '오스카와 장미할머니',
#    'isbn': '897075301X',
#    'label': '오스카와 장미할머니',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=144862',
#    'sameAs': 'http://data.nanet.go.kr/ontology/NANET_BIB_MONO1200404156'},
#   {'@id': 'nlk:KAC201406979',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '390p.: 삽도; 23cm',
#    'audienceNote': '일반이용자',
#    'bibliography': '참고문헌: p.383, 색인수록',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '387.5094',
#    'ddcn': 'http://lod.nl.go.kr/ddc/387_e21',
#    'genre': '일반도서',
#    'kdc': '326.36092',
#    'kdcn': 'http://lod.nl.go.kr/kdc/326_e4',
#    'keyword': 'WORLD',
#    'publicationPlace': '서울',
#    'typeOfResource': 'nlk:text',
#    'creator': 'Fayle, Charles Ernest',
#    'publisher': '혜안',
#    'accessRights': 'nlk:license3',
#    'alternative': "Short history of the world's shipping industry",
#    'description': 'Fayle, Charles Ernest',
#    'hasFormat': 'nlk:KMO200408614',
#    'issued': '2004',
#    'language': 'http://lod.nl.go.kr/countries/KOR',
#    'title': '서양 해운사',
#    'isbn': '8984942103',
#    'label': '서양 해운사',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1216764',
#    'sameAs': 'http://data.nanet.go.kr/ontology/NANET_BIB_MONO1200405481'},
#   {'@id': 'nlk:KAB202212884',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '284p.: 삽도; 23cm+ 컴팩트 디스크 1매(12cm)',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-11T13:55:51^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '028',
#    'ddcn': 'http://lod.nl.go.kr/ddc/028_e21',
#    'genre': '일반도서',
#    'kdc': '029.4',
#    'kdcn': 'http://lod.nl.go.kr/kdc/029_e4',
#    'keyword': '디지털훈련프로그램',
#    'publicationPlace': '서울',
#    'titleOfSeries': '자기계발 신서; 1',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '자기계발 신서; 1',
#    'creator': '이윤',
#    'publisher': '골드닷컴',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200408651',
#    'issued': '2004',
#    'title': '(속독·속청으로)성적 내맘대로 올린다',
#    'isbn': '8995458704',
#    'label': '(속독·속청으로)성적 내맘대로 올린다'},
#   {'@id': 'nlk:KAC201309608',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '324p. ; 24cm',
#    'audienceNote': '일반이용자',
#    'bibliography': '참고문헌: p.311-318, 색인수록',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '371.4',
#    'ddcn': 'http://lod.nl.go.kr/ddc/371_e21',
#    'genre': '일반도서',
#    'kdc': '372.6',
#    'kdcn': 'http://lod.nl.go.kr/kdc/372_e4',
#    'keyword': '실천',
#    'publicationPlace': '서울',
#    'titleOfSeries': '나남신서; 1015',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '나남신서; 1015',
#    'creator': '홍순혜',
#    'publisher': '나남출판',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200408700',
#    'issued': '2004',
#    'title': '학교와 사회복지 실천',
#    'isbn': '8930080154',
#    'label': '학교와 사회복지 실천',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=144954',
#    'sameAs': 'http://data.nanet.go.kr/ontology/NANET_BIB_MONO1200404830'},
#   {'@id': 'nlk:KAC201814025',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '231p.: 삽도; 20cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '895.745',
#    'ddcn': 'http://lod.nl.go.kr/ddc/895_e21',
#    'genre': '일반도서',
#    'kdc': '814.6',
#    'kdcn': 'http://lod.nl.go.kr/kdc/814_e4',
#    'keyword': '대화',
#    'publicationPlace': '서울',
#    'remainderOfTitle': '정희돈 수상집',
#    'typeOfResource': 'nlk:text',
#    'creator': '정희돈',
#    'publisher': '우리출판사',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200408707',
#    'issued': '2004',
#    'title': '고지식과 외골수의 대화',
#    'isbn': '8975612066',
#    'label': '고지식과 외골수의 대화'},
#   {'@id': 'nlk:KAC201223292',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '131p.: 삽도; 32cm',
#    'audienceNote': '일반이용자',
#    'bibliography': '참고문헌: p.129, 색인수록',
#    'datePublished': '2024-10-11T15:39:40^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '303.49',
#    'ddcn': 'http://lod.nl.go.kr/ddc/303_e21',
#    'genre': '일반도서',
#    'kdc': '331.54',
#    'kdcn': 'http://lod.nl.go.kr/kdc/331_e4',
#    'keyword': '21세기',
#    'publicationPlace': '파주',
#    'typeOfResource': 'nlk:text',
#    'creator': '이인식',
#    'publisher': '김영사',
#    'accessRights': 'nlk:license3',
#    'alternative': '(The)future times',
#    'hasFormat': 'nlk:KMO200408745',
#    'issued': '2004',
#    'title': '미래신문',
#    'isbn': '8934914467',
#    'label': '미래신문',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=145227',
#    'sameAs': 'http://data.nanet.go.kr/ontology/NANET_BIB_MONO1200405695'},
#   {'@id': 'nlk:KAC201839227',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '574p.; 23cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '495.7',
#    'ddcn': 'http://lod.nl.go.kr/ddc/495_e21',
#    'genre': '일반도서',
#    'kdc': '710',
#    'kdcn': 'http://lod.nl.go.kr/kdc/710_e4',
#    'keyword': '조선어',
#    'publicationPlace': '파주',
#    'restriction': '국립중앙도서관, 국립어린이청소년도서관, 국립세종도서관, 협력기관(공공.대학.전문/특수.해외.작은도서관) 공개',
#    'typeOfResource': 'nlk:text',
#    'publisher': '집문당',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200408751',
#    'issued': '2004',
#    'language': 'http://lod.nl.go.kr/countries/KOR',
#    'title': '중국조선어연구',
#    'isbn': '8930310834',
#    'label': '중국조선어연구'},
#   {'@id': 'nlk:KAC200307597',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '238p.: 삽도; 23cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '332.024',
#    'ddcn': 'http://lod.nl.go.kr/ddc/332_e21',
#    'genre': '일반도서',
#    'kdc': '327.04',
#    'kdcn': 'http://lod.nl.go.kr/kdc/327_e4',
#    'keyword': 'ユダヤ인대부호',
#    'publicationPlace': '서울',
#    'restriction': '국립중앙도서관, 국립어린이청소년도서관, 국립세종도서관, 협력기관(공공.대학.전문/특수.해외.작은도서관) 공개',
#    'titleOfSeries': '혼다 켄 행복한 부자 시리즈; 2',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '혼다 켄 행복한 부자 시리즈; 2',
#    'creator': '혼다 겐',
#    'publisher': '더난출판',
#    'accessRights': 'nlk:license3',
#    'alternative': '행복한 부자가 되는 17가지 비결',
#    'description': "혼다 켄의 한자명은 '本田健'임",
#    'hasFormat': 'nlk:KMO200408757',
#    'issued': '2004',
#    'language': 'http://lod.nl.go.kr/countries/KOR',
#    'title': '(스무 살에 만난)유태인 대부호의 가르침',
#    'isbn': '8984052426',
#    'label': '(스무 살에 만난)유태인 대부호의 가르침',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=146506',
#    'sameAs': 'http://data.nanet.go.kr/ontology/NANET_BIB_MONO1200405169'},
#   {'@id': 'nlk:KAC201201155',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '248p.; 26cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '650.1',
#    'ddcn': 'http://lod.nl.go.kr/ddc/650_e21',
#    'genre': '일반도서',
#    'kdc': '325.04',
#    'kdcn': 'http://lod.nl.go.kr/kdc/325_e4',
#    'keyword': '성공법',
#    'publicationPlace': '서울',
#    'typeOfResource': 'nlk:text',
#    'creator': '후타미 미치오',
#    'publisher': '빛무리',
#    'accessRights': 'nlk:license3',
#    'description': "후타미 미치오의 한자명은 '二見道夫'임",
#    'hasFormat': 'nlk:KMO200408764',
#    'issued': '2004',
#    'language': 'http://lod.nl.go.kr/countries/KOR',
#    'title': '성공하는 사람은 뭔가 다르다',
#    'isbn': '8990946018',
#    'label': '성공하는 사람은 뭔가 다르다',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=143432',
#    'sameAs': 'http://data.nanet.go.kr/ontology/NANET_BIB_MONO1200405408'},
#   {'@id': 'nlk:KAC201633294',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': 'viii, 490p.: 삽도; 26cm',
#    'audienceNote': '일반이용자',
#    'bibliography': '색인수록',
#    'datePublished': '2024-10-11T13:55:51^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '530',
#    'ddcn': 'http://lod.nl.go.kr/ddc/530_e21',
#    'genre': '일반도서',
#    'kdc': '420',
#    'kdcn': 'http://lod.nl.go.kr/kdc/420_e4',
#    'keyword': '일반물리학',
#    'publicationPlace': '서울',
#    'typeOfResource': 'nlk:text',
#    'creator': '조육',
#    'publisher': '북스힐',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200408795',
#    'issued': '2004',
#    'title': '일반물리학',
#    'isbn': '8955261640',
#    'label': '일반물리학'},
#   {'@id': 'nlk:KAC201208478',
#    '@type': 'nlon:ElectronicBook',
#    'extent': 'ix, 580p.: 삽도; 26cm',
#    'audienceNote': '일반이용자',
#    'bibliography': '색인수록',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '530',
#    'ddcn': 'http://lod.nl.go.kr/ddc/530_e21',
#    'genre': '일반도서',
#    'kdc': '420',
#    'kdcn': 'http://lod.nl.go.kr/kdc/420_e4',
#    'keyword': '물리학',
#    'publicationPlace': '서울',
#    'titleOfSeries': '물리학 강의록; 2',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '물리학 강의록; 2',
#    'creator': '차동우',
#    'publisher': '북스힐',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200408811',
#    'issued': '2004',
#    'title': '교양 물리',
#    'isbn': '8955261535',
#    'label': '교양 물리'},
#   {'@id': 'nlk:KAC201826632',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '363p.: 삽도; 23cm',
#    'audienceNote': '일반이용자',
#    'bibliography': '참고문헌: p.303-312, 색인수록',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '355.00973',
#    'ddcn': 'http://lod.nl.go.kr/ddc/355_e21',
#    'genre': '일반도서',
#    'kdc': '390.942',
#    'kdcn': 'http://lod.nl.go.kr/kdc/390_e4',
#    'keyword': '미래전',
#    'publicationPlace': '서울',
#    'restriction': '국립중앙도서관, 국립어린이청소년도서관, 국립세종도서관, 협력기관(공공.대학.전문/특수.해외.작은도서관) 공개',
#    'typeOfResource': 'nlk:text',
#    'creator': 'Owens, Bill',
#    'publisher': '21세기군사연구소',
#    'accessRights': 'nlk:license3',
#    'alternative': 'Lifting the fog of war',
#    'description': "권말부록으로 '용어해설'수록",
#    'hasFormat': 'nlk:KMO200408828',
#    'issued': '2001',
#    'language': 'http://lod.nl.go.kr/countries/KOR',
#    'title': '미래전에 있어서 불확실성 제거',
#    'isbn': '8987647153',
#    'label': '미래전에 있어서 불확실성 제거',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1409231',
#    'sameAs': 'http://data.nanet.go.kr/ontology/NANET_BIB_MONO1200403270'},
#   {'@id': 'nlk:CNTS-00091458247',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '174p.; 20cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '264.36',
#    'ddcn': 'http://lod.nl.go.kr/ddc/264_e21',
#    'genre': '일반도서',
#    'kdc': '237.43',
#    'kdcn': 'http://lod.nl.go.kr/kdc/237_e4',
#    'keyword': '성찬식',
#    'publicationPlace': '서울',
#    'titleOfSeries': '김진의 영성 이야기; 4',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '김진의 영성 이야기; 4',
#    'creator': '김진',
#    'publisher': '엔크리스토',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200408847',
#    'issued': '2003',
#    'title': '성만찬의 영성',
#    'isbn': '8989437784',
#    'label': '성만찬의 영성'},
#   {'@id': 'nlk:KAC201826208',
#    '@type': 'nlon:ElectronicBook',
#    'extent': 'vii, 298p.; 23cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '330.02',
#    'ddcn': 'http://lod.nl.go.kr/ddc/330_e21',
#    'genre': '일반도서',
#    'kdc': '320.4',
#    'kdcn': 'http://lod.nl.go.kr/kdc/320_e4',
#    'keyword': '경제학',
#    'publicationPlace': '서울',
#    'typeOfResource': 'nlk:text',
#    'creator': '유광필',
#    'publisher': '교우사',
#    'accessRights': 'nlk:license3',
#    'alternative': 'Economic column',
#    'hasFormat': 'nlk:KMO200408865',
#    'issued': '2003',
#    'title': '(유광필 교수의)경제 칼럼',
#    'isbn': '8981724083',
#    'label': '(유광필 교수의)경제 칼럼',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1420884',
#    'sameAs': 'http://data.nanet.go.kr/ontology/NANET_BIB_MONO1200413912'},
#   {'@id': 'nlk:KAC201213423',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': 'vii, 315p.; 23cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '330.02',
#    'ddcn': 'http://lod.nl.go.kr/ddc/330_e21',
#    'genre': '일반도서',
#    'kdc': '320.4',
#    'kdcn': 'http://lod.nl.go.kr/kdc/320_e4',
#    'keyword': '경제',
#    'publicationPlace': '서울',
#    'typeOfResource': 'nlk:text',
#    'creator': '이덕훈',
#    'publisher': '교우사',
#    'accessRights': 'nlk:license3',
#    'alternative': '위기 극복 시대!!',
#    'hasFormat': 'nlk:KMO200408866',
#    'issued': '2003',
#    'title': '(이덕훈의)경제 이야기',
#    'isbn': '8981724091',
#    'label': '(이덕훈의)경제 이야기',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1421095',
#    'sameAs': 'http://data.nanet.go.kr/ontology/NANET_BIB_MONO1200518039'},
#   {'@id': 'nlk:KAC201229307',
#    '@type': 'nlon:ElectronicBook',
#    'extent': 'vii, 135p.; 23cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-11T22:08:05^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '512.7',
#    'ddcn': 'http://lod.nl.go.kr/ddc/512_e21',
#    'genre': '일반도서',
#    'kdc': '412.9',
#    'kdcn': 'http://lod.nl.go.kr/kdc/412_e4',
#    'keyword': '부모',
#    'publicationPlace': '서울',
#    'titleOfSeries': '교양수학 시리즈; 12',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '교양수학 시리즈; 12',
#    'creator': '한미연',
#    'publisher': '교우사',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200408867',
#    'issued': '2003',
#    'title': '(대학수능자녀를 둔 부모가 읽을)비틀즈 앤 스파이더즈 이야기',
#    'isbn': '8981724075',
#    'label': '(대학수능자녀를 둔 부모가 읽을)비틀즈 앤 스파이더즈 이야기'},
#   {'@id': 'nlk:KAC201229307',
#    '@type': 'nlon:ElectronicBook',
#    'extent': 'ix, 151p.; 23cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '512.74',
#    'ddcn': 'http://lod.nl.go.kr/ddc/512_e21',
#    'genre': '일반도서',
#    'kdc': '412.9',
#    'kdcn': 'http://lod.nl.go.kr/kdc/412_e4',
#    'keyword': '수학',
#    'publicationPlace': '서울',
#    'titleOfSeries': '교양수학 시리즈; 11',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '교양수학 시리즈; 11',
#    'creator': '한재영',
#    'publisher': '교우사',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200408868',
#    'issued': '2003',
#    'title': '(대학수능자녀를 둔 부모가 읽을)페르마의 작은 정리 이야기',
#    'isbn': '8981724067',
#    'label': '(대학수능자녀를 둔 부모가 읽을)페르마의 작은 정리 이야기',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1267418'},
#   {'@id': 'nlk:KAC201229307',
#    '@type': 'nlon:ElectronicBook',
#    'extent': 'vi, 194p.; 23cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '519.5',
#    'ddcn': 'http://lod.nl.go.kr/ddc/519_e21',
#    'genre': '일반도서',
#    'kdc': '413.8',
#    'kdcn': 'http://lod.nl.go.kr/kdc/413_e4',
#    'keyword': '통계',
#    'publicationPlace': '서울',
#    'titleOfSeries': '교양수학 시리즈; 10',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '교양수학 시리즈; 10',
#    'creator': '한재영',
#    'publisher': '교우사',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200408869',
#    'issued': '2003',
#    'title': '(대학수능자녀를 둔 부모가 읽을)확률통계 이야기',
#    'isbn': '8981724059',
#    'label': '(대학수능자녀를 둔 부모가 읽을)확률통계 이야기',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1266742'},
#   {'@id': 'nlk:KAC199617703',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '141p.; 22cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '335.8',
#    'ddcn': 'http://lod.nl.go.kr/ddc/335_e21',
#    'genre': '일반도서',
#    'kdc': '301.9',
#    'kdcn': 'http://lod.nl.go.kr/kdc/301_e4',
#    'keyword': '해방',
#    'publicationPlace': '서울',
#    'typeOfResource': 'nlk:text',
#    'creator': '마르쿠제, 헤르베르트',
#    'publisher': '울력',
#    'accessRights': 'nlk:license3',
#    'alternative': 'Essay on liberation',
#    'description': 'Marcuse, Herbert',
#    'hasFormat': 'nlk:KMO200408871',
#    'issued': '2004',
#    'language': 'http://lod.nl.go.kr/countries/KOR',
#    'title': '해방론',
#    'isbn': '8989485266',
#    'label': '해방론'},
#   {'@id': 'nlk:KAC201312085',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '240p.: 삽도; 23cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '332.7',
#    'ddcn': 'http://lod.nl.go.kr/ddc/332_e21',
#    'genre': '일반도서',
#    'kdc': '327.535',
#    'kdcn': 'http://lod.nl.go.kr/kdc/327_e4',
#    'keyword': '부자',
#    'publicationPlace': '서울',
#    'typeOfResource': 'nlk:text',
#    'creator': '김승용',
#    'publisher': '홍',
#    'accessRights': 'nlk:license3',
#    'description': "권말부록으로 '사례로 보는 금융 재테크 정보'수록",
#    'hasFormat': 'nlk:KMO200408874',
#    'issued': '2004',
#    'title': '(부자들의 절대 습관)신용관리',
#    'isbn': '8955171501',
#    'label': '(부자들의 절대 습관)신용관리'},
#   {'@id': 'nlk:KAC201229307',
#    '@type': 'nlon:ElectronicBook',
#    'extent': 'xii, 223p.; 23cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '515.43',
#    'ddcn': 'http://lod.nl.go.kr/ddc/515_e21',
#    'genre': '일반도서',
#    'kdc': '414.43',
#    'kdcn': 'http://lod.nl.go.kr/kdc/414_e4',
#    'keyword': '교양수학',
#    'publicationPlace': '서울',
#    'titleOfSeries': '교양수학 시리즈; 9',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '교양수학 시리즈; 9',
#    'creator': '한재영',
#    'publisher': '교우사',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200408880',
#    'issued': '2003',
#    'title': '(대학수능자녀를 둔 부모가 읽을)적분활용 이야기',
#    'isbn': '8981724040',
#    'label': '(대학수능자녀를 둔 부모가 읽을)적분활용 이야기'},
#   {'@id': 'nlk:KAC201229307',
#    '@type': 'nlon:ElectronicBook',
#    'extent': 'vii, 173p.; 23cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '515.7',
#    'ddcn': 'http://lod.nl.go.kr/ddc/515_e21',
#    'genre': '일반도서',
#    'kdc': '414.5',
#    'kdcn': 'http://lod.nl.go.kr/kdc/414_e4',
#    'keyword': '최대함수',
#    'publicationPlace': '서울',
#    'titleOfSeries': '교양수학 시리즈; 7',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '교양수학 시리즈; 7',
#    'creator': '한재영',
#    'publisher': '교우사',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200408881',
#    'issued': '2003',
#    'title': '(대학수능자녀를 둔 부모가 읽을)최대최소 이야기',
#    'isbn': '8981724016',
#    'label': '(대학수능자녀를 둔 부모가 읽을)최대최소 이야기',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1266739'},
#   {'@id': 'nlk:KAC201229307',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': 'vii, 176p.; 23cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '516.24',
#    'ddcn': 'http://lod.nl.go.kr/ddc/516_e21',
#    'genre': '일반도서',
#    'kdc': '417',
#    'kdcn': 'http://lod.nl.go.kr/kdc/417_e4',
#    'keyword': '대학수능자녀',
#    'publicationPlace': '서울',
#    'titleOfSeries': '교양수학 시리즈; 8',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '교양수학 시리즈; 8',
#    'creator': '한재영',
#    'publisher': '교우사',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200408882',
#    'issued': '2003',
#    'title': '(대학수능자녀를 둔 부모가 읽을)복소삼각 이야기',
#    'isbn': '8981724024',
#    'label': '(대학수능자녀를 둔 부모가 읽을)복소삼각 이야기',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1266741'},
#   {'@id': 'nlk:KAC201229307',
#    '@type': 'nlon:ElectronicBook',
#    'extent': 'vii, 154p.; 23cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '515.33',
#    'ddcn': 'http://lod.nl.go.kr/ddc/515_e21',
#    'genre': '일반도서',
#    'kdc': '414.33',
#    'kdcn': 'http://lod.nl.go.kr/kdc/414_e4',
#    'keyword': '부모',
#    'publicationPlace': '서울',
#    'titleOfSeries': '교양수학 시리즈; 6',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '교양수학 시리즈; 6',
#    'creator': '한재영',
#    'publisher': '교우사',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200408884',
#    'issued': '2003',
#    'title': '(대학수능자녀를 둔 부모가 읽을)미분연속 이야기',
#    'isbn': '8981724008',
#    'label': '(대학수능자녀를 둔 부모가 읽을)미분연속 이야기'},
#   {'@id': 'nlk:KAC201229307',
#    '@type': 'nlon:ElectronicBook',
#    'extent': 'v, 176p.; 23cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '510.2',
#    'ddcn': 'http://lod.nl.go.kr/ddc/510_e21',
#    'genre': '일반도서',
#    'kdc': '410.4',
#    'kdcn': 'http://lod.nl.go.kr/kdc/410_e4',
#    'keyword': '숫자',
#    'publicationPlace': '서울',
#    'titleOfSeries': '교양수학 시리즈; 4',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '교양수학 시리즈; 4',
#    'creator': '한지연',
#    'publisher': '교우사',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200408885',
#    'issued': '2003',
#    'title': '(대학수능자녀를 둔 부모가 읽을)초자연한 숫자 이야기',
#    'isbn': '8981724032',
#    'label': '(대학수능자녀를 둔 부모가 읽을)초자연한 숫자 이야기',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1266738'},
#   {'@id': 'nlk:KAC201416162',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '278p.: 삽도; 23cm',
#    'audienceNote': '일반이용자',
#    'bibliography': '참고문헌: p.273-274, 색인수록',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '940',
#    'ddcn': 'http://lod.nl.go.kr/ddc/940_e21',
#    'genre': '일반도서',
#    'kdc': '920',
#    'kdcn': 'http://lod.nl.go.kr/kdc/920_e4',
#    'keyword': '문화기행',
#    'publicationPlace': '대구',
#    'typeOfResource': 'nlk:text',
#    'creator': '양재열',
#    'publisher': '서림출판사',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200408932',
#    'issued': '2004',
#    'title': '서양의 역사와 문화 기행',
#    'isbn': '8990715040',
#    'label': '서양의 역사와 문화 기행',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2282254'},
#   {'@id': 'nlk:KAC201106250',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '215p.; 22cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '242',
#    'ddcn': 'http://lod.nl.go.kr/ddc/242_e21',
#    'genre': '일반도서',
#    'kdc': '234.3',
#    'kdcn': 'http://lod.nl.go.kr/kdc/234_e4',
#    'keyword': '마음공부',
#    'publicationPlace': '서울',
#    'remainderOfTitle': '누가 당신을 보잘것 없다고 그럽디까?',
#    'typeOfResource': 'nlk:text',
#    'creator': '이현주',
#    'publisher': '두레',
#    'accessRights': 'nlk:license3',
#    'description': "이현주의 필명은 '이아무개'임",
#    'hasFormat': 'nlk:KMO200409078',
#    'issued': '2003',
#    'title': '이아무개의 마음공부',
#    'isbn': '8974430576',
#    'label': '이아무개의 마음공부'},
#   {'@id': 'nlk:KAB201730867',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '143p.: 삽도; 26cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-12T02:47:28^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '745.54',
#    'ddcn': 'http://lod.nl.go.kr/ddc/745_e21',
#    'genre': '일반도서',
#    'kdc': '634.9',
#    'kdcn': 'http://lod.nl.go.kr/kdc/634_e4',
#    'keyword': 'CARD',
#    'publicationPlace': '서울',
#    'titleOfSeries': '내손으로 만드는 Card 시리즈; 7',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '내손으로 만드는 Card 시리즈; 7',
#    'publisher': '혜지원',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200409081',
#    'issued': '2003',
#    'title': '할로윈 카드 만들기',
#    'isbn': '898379299X(전8권)',
#    'label': '할로윈 카드 만들기',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=132173'},
#   {'@id': 'nlk:KAB201730867',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '135p.: 삽도; 26cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '745.54',
#    'ddcn': 'http://lod.nl.go.kr/ddc/745_e21',
#    'genre': '일반도서',
#    'kdc': '634.9',
#    'kdcn': 'http://lod.nl.go.kr/kdc/634_e4',
#    'keyword': '카드',
#    'publicationPlace': '서울',
#    'titleOfSeries': '내 손으로 만드는 Card 시리즈 ; 8',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '내 손으로 만드는 Card 시리즈 ; 8',
#    'publisher': '혜지원',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200409082',
#    'issued': '2003',
#    'title': '패션 카드 만들기',
#    'isbn': '8983793198',
#    'label': '패션 카드 만들기',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=133066'},
#   {'@id': 'nlk:KAB201730867',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '143p.: 삽도; 26cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-11T18:46:22^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '745.54',
#    'ddcn': 'http://lod.nl.go.kr/ddc/745_e21',
#    'genre': '일반도서',
#    'kdc': '634.9',
#    'kdcn': 'http://lod.nl.go.kr/kdc/634_e4',
#    'keyword': '종이공예',
#    'publicationPlace': '서울',
#    'titleOfSeries': '내손으로 만드는 Card 시리즈; 6',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '내손으로 만드는 Card 시리즈; 6',
#    'publisher': '혜지원',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200409083',
#    'issued': '2003',
#    'title': '감사 카드 만들기',
#    'isbn': '8983793147',
#    'label': '감사 카드 만들기',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=130964'},
#   {'@id': 'nlk:KAB201730867',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '141p.: 삽도; 26cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-11T20:31:46^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '738',
#    'ddcn': 'http://lod.nl.go.kr/ddc/738_e21',
#    'genre': '일반도서',
#    'kdc': '631',
#    'kdcn': 'http://lod.nl.go.kr/kdc/631_e4',
#    'keyword': '빈병만들기',
#    'publicationPlace': '서울',
#    'titleOfSeries': '재미있는 만들기 시리즈',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': 'DIY; 8',
#    'publisher': '혜지원',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200409087',
#    'issued': '2003',
#    'title': '(재미있는)빈병으로 만들기',
#    'isbn': '8983793201',
#    'label': '(재미있는)빈병으로 만들기',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=134292'},
#   {'@id': 'nlk:KAC201207336',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '228p.: 삽도; 26cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-11T10:45:02^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '641.5',
#    'ddcn': 'http://lod.nl.go.kr/ddc/641_e21',
#    'genre': '일반도서',
#    'kdc': '594.5',
#    'kdcn': 'http://lod.nl.go.kr/kdc/594_e4',
#    'keyword': '실험조리',
#    'publicationPlace': '서울',
#    'typeOfResource': 'nlk:text',
#    'creator': '현영희',
#    'publisher': '지구문화사',
#    'accessRights': 'nlk:license3',
#    'alternative': 'Experiment cooking',
#    'hasFormat': 'nlk:KMO200409099',
#    'issued': '2003',
#    'title': '영양분석 & 실험조리',
#    'isbn': '8970063293',
#    'label': '영양분석 & 실험조리'},
#   {'@id': 'nlk:KAC201231849',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '423p.; 24cm',
#    'audienceNote': '일반이용자',
#    'bibliography': '참고문헌: p.381-414, 색인수록',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '300.1',
#    'ddcn': 'http://lod.nl.go.kr/ddc/300_e21',
#    'genre': '일반도서',
#    'kdc': '300.1',
#    'kdcn': 'http://lod.nl.go.kr/kdc/300_e4',
#    'keyword': '행위',
#    'publicationPlace': '서울',
#    'remainderOfTitle': '거시적 현상의 미시적 기초를 찾아서',
#    'titleOfSeries': '나남신서; 1006',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '나남신서; 1006',
#    'creator': '김용학',
#    'publisher': '나남출판',
#    'accessRights': 'nlk:license3',
#    'alternative': 'Social structure and action in social theory',
#    'hasFormat': 'nlk:KMO200409138',
#    'issued': '2003',
#    'title': '사회구조와 행위',
#    'edition': '개정3판',
#    'isbn': '8930080014',
#    'label': '사회구조와 행위',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=138990',
#    'sameAs': 'http://data.nanet.go.kr/ontology/NANET_BIB_MONO1200401225'},
#   {'@id': 'nlk:KAC201826047',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '232p.; 21cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-11T15:39:40^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '306.87',
#    'ddcn': 'http://lod.nl.go.kr/ddc/306_e21',
#    'genre': '일반도서',
#    'kdc': '332.23',
#    'kdcn': 'http://lod.nl.go.kr/kdc/332_e4',
#    'keyword': '앞치마',
#    'publicationPlace': '서울',
#    'remainderOfTitle': '당돌한 여자, 당당한 남자',
#    'typeOfResource': 'nlk:text',
#    'creator': 'Momose, Eiko',
#    'publisher': '나노미디어',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200409147',
#    'issued': '2003',
#    'language': 'http://lod.nl.go.kr/countries/KOR',
#    'title': '앞치마를 두른 남자',
#    'isbn': '8989292093',
#    'label': '앞치마를 두른 남자',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=128369',
#    'sameAs': 'http://data.nanet.go.kr/ontology/NANET_BIB_MONO1200319687'},
#   {'@id': 'nlk:KAC201420614',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '197p.; 24cm',
#    'audienceNote': '일반이용자',
#    'bibliography': '참고문헌: p.193',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '951.901',
#    'ddcn': 'http://lod.nl.go.kr/ddc/951_e21',
#    'genre': '일반도서',
#    'kdc': '911.036',
#    'kdcn': 'http://lod.nl.go.kr/kdc/911_e4',
#    'keyword': '신라',
#    'publicationPlace': '서울',
#    'typeOfResource': 'nlk:text',
#    'creator': '박해현',
#    'publisher': '국학자료원',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200409244',
#    'issued': '2003',
#    'title': '신라중대 정치사연구',
#    'isbn': '8954101178',
#    'label': '신라중대 정치사연구',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2282330',
#    'sameAs': 'http://data.nanet.go.kr/ontology/NANET_BIB_MONO1200413859'},
#   {'@id': 'nlk:KAC201227414',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '255p.; 23cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-11T20:31:46^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '658.0092',
#    'ddcn': 'http://lod.nl.go.kr/ddc/658_e21',
#    'genre': '일반도서',
#    'kdc': '325.099',
#    'kdcn': 'http://lod.nl.go.kr/kdc/325_e4',
#    'keyword': '도요타자동차',
#    'publicationPlace': '고양',
#    'remainderOfTitle': '도요타 자동차와 함께 한 50년',
#    'typeOfResource': 'nlk:text',
#    'creator': '풍전영이',
#    'publisher': '굿모닝북스',
#    'accessRights': 'nlk:license3',
#    'description': "도요타 에이지의 한자명은 '豊田英二'임",
#    'hasFormat': 'nlk:KMO200409260',
#    'issued': '2004',
#    'language': 'http://lod.nl.go.kr/countries/KOR',
#    'title': '도요타 에이지의 결단',
#    'isbn': '8995335661',
#    'label': '도요타 에이지의 결단'},
#   {'@id': 'nlk:KAC200402377',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '263p.; 23cm',
#    'audienceNote': '일반이용자',
#    'bibliography': '참고문헌수록',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '248.844',
#    'ddcn': 'http://lod.nl.go.kr/ddc/248_e21',
#    'genre': '일반도서',
#    'kdc': '234.9',
#    'kdcn': 'http://lod.nl.go.kr/kdc/234_e4',
#    'keyword': 'LOVE',
#    'publicationPlace': '서울',
#    'typeOfResource': 'nlk:text',
#    'creator': 'Rodgers, Tom',
#    'publisher': '예영커뮤니케이션',
#    'accessRights': 'nlk:license3',
#    'alternative': 'Soul healing love',
#    'description': 'Rodgers, Beverly',
#    'hasFormat': 'nlk:KMO200409277',
#    'issued': '2004',
#    'language': 'http://lod.nl.go.kr/countries/KOR',
#    'title': '영혼을 치유하는 사랑',
#    'isbn': '8983503084',
#    'label': '영혼을 치유하는 사랑',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=146260'},
#   {'@id': 'nlk:KAC201232110',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '153p.: 삽도; 23cm',
#    'audienceNote': '일반이용자',
#    'bibliography': '참고문헌: p.150-153',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '028.5',
#    'ddcn': 'http://lod.nl.go.kr/ddc/028_e21',
#    'genre': '일반도서',
#    'kdc': '029.8',
#    'kdcn': 'http://lod.nl.go.kr/kdc/029_e4',
#    'keyword': '마음',
#    'publicationPlace': '파주',
#    'titleOfSeries': '독서치료연구시리즈; 3',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '한울아카데미; 631',
#    'creator': '김정근',
#    'publisher': '한울',
#    'accessRights': 'nlk:license3',
#    'description': '기획·감수: 김정근',
#    'hasFormat': 'nlk:KMO200409290',
#    'issued': '2004',
#    'title': '어린이의 상한 마음을 돌보기 위한 독서치료',
#    'isbn': '8946032286',
#    'label': '어린이의 상한 마음을 돌보기 위한 독서치료',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1271966',
#    'sameAs': 'http://data.nanet.go.kr/ontology/NANET_BIB_MONO1200405776'},
#   {'@id': 'nlk:KAC201232110',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '169p.; 23cm',
#    'audienceNote': '일반이용자',
#    'bibliography': '참고문헌: p.165-169',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '028',
#    'ddcn': 'http://lod.nl.go.kr/ddc/028_e21',
#    'genre': '일반도서',
#    'kdc': '029.8',
#    'kdcn': 'http://lod.nl.go.kr/kdc/029_e4',
#    'keyword': '독서치료',
#    'publicationPlace': '파주',
#    'titleOfSeries': '한울아카데미; 630',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '독서치료연구시리즈; 2',
#    'creator': '김정근',
#    'publisher': '한울',
#    'accessRights': 'nlk:license3',
#    'description': '기획·감수: 김정근',
#    'hasFormat': 'nlk:KMO200409293',
#    'issued': '2004',
#    'title': '독서치료와 공공도서관 서비스',
#    'isbn': '8946032316(세트)',
#    'label': '독서치료와 공공도서관 서비스'},
#   {'@id': 'nlk:CNTS-00091458372',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '124p.; 21cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-11T12:19:41^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '895.715',
#    'ddcn': 'http://lod.nl.go.kr/ddc/895_e21',
#    'genre': '일반도서',
#    'kdc': '811.6',
#    'kdcn': 'http://lod.nl.go.kr/kdc/811_e4',
#    'keyword': '금빛',
#    'publicationPlace': '대구',
#    'remainderOfTitle': '권국명 시집',
#    'titleOfSeries': '만인시인선; 9',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '만인시인선; 9',
#    'publisher': '만인사',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200409429',
#    'issued': '2004',
#    'title': '으능나무 금빛 몸',
#    'isbn': '8988915453',
#    'label': '으능나무 금빛 몸',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1424638'},
#   {'@id': 'nlk:KAC201304085',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '123p.; 21cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-11T22:08:05^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '895.715',
#    'ddcn': 'http://lod.nl.go.kr/ddc/895_e21',
#    'genre': '일반도서',
#    'kdc': '811.6',
#    'kdcn': 'http://lod.nl.go.kr/kdc/811_e4',
#    'keyword': '염소좌',
#    'publicationPlace': '서울',
#    'remainderOfTitle': '전명숙 시집',
#    'titleOfSeries': '시작시인선; 39',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '시작시인선; 39',
#    'creator': '전명숙',
#    'publisher': '천년의시작',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200409468',
#    'issued': '2004',
#    'title': '염소좌 아래 잠들다',
#    'isbn': '8990235383',
#    'label': '염소좌 아래 잠들다',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=145369'},
#   {'@id': 'nlk:KAC201506755',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '181p.: 삽도; 23cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-11T18:46:22^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '657',
#    'ddcn': 'http://lod.nl.go.kr/ddc/657_e21',
#    'genre': '일반도서',
#    'kdc': '325.9',
#    'kdcn': 'http://lod.nl.go.kr/kdc/325_e4',
#    'keyword': '회계',
#    'publicationPlace': '서울',
#    'typeOfResource': 'nlk:text',
#    'creator': '전정수',
#    'publisher': '청람',
#    'accessRights': 'nlk:license3',
#    'description': "권말부록으로 '사업계획서 작성사례'수록",
#    'hasFormat': 'nlk:KMO200409514',
#    'issued': '2004',
#    'title': '회계, 그게 그렇군요',
#    'isbn': '8986248573',
#    'label': '회계, 그게 그렇군요',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1270690',
#    'sameAs': 'http://data.nanet.go.kr/ontology/NANET_BIB_MONO1200403927'},
#   {'@id': 'nlk:KAC200609592',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '343 p.; 23 cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '813.54',
#    'ddcn': 'http://lod.nl.go.kr/ddc/813_e21',
#    'genre': '일반도서',
#    'kdc': '843',
#    'kdcn': 'http://lod.nl.go.kr/kdc/843_e4',
#    'keyword': '미국 현대 소설[美國現代小說]',
#    'publicationPlace': '서울',
#    'remainderOfTitle': '매디슨 데이비스 추리 소설',
#    'restriction': '국립중앙도서관, 국립어린이청소년도서관, 국립세종도서관, 협력기관(공공.대학.전문/특수.해외.작은도서관) 공개',
#    'typeOfResource': 'nlk:text',
#    'creator': 'Davis, J. Madison',
#    'publisher': '마로니에북스',
#    'accessRights': 'nlk:license3',
#    'alternative': 'Van Gogh conspiracy',
#    'description': 'Davis, Madison',
#    'hasFormat': 'nlk:KMO200644266',
#    'issued': '2006',
#    'language': 'http://lod.nl.go.kr/countries/KOR',
#    'title': '반고흐 컨스피러시',
#    'isbn': '8991449840',
#    'label': '반고흐 컨스피러시',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2521357',
#    'sameAs': 'http://data.nanet.go.kr/ontology/NANET_BIB_MONO1200629859'},
#   {'@id': 'nlk:KAC201210490',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '465 p.; 25 cm',
#    'audienceNote': '일반이용자',
#    'bibliography': '참고문헌 수록',
#    'datePublished': '2024-10-11T23:26:04^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '158.3',
#    'ddcn': 'http://lod.nl.go.kr/ddc/158_e21',
#    'genre': '일반도서',
#    'kdc': '186.3',
#    'kdcn': 'http://lod.nl.go.kr/kdc/186_e4',
#    'keyword': '집단상담프로그램',
#    'publicationPlace': '서울',
#    'remainderOfTitle': '이론과 실제',
#    'typeOfResource': 'nlk:text',
#    'creator': '장선철',
#    'publisher': '태영출판사',
#    'accessRights': 'nlk:license3',
#    'alternative': 'Group counseling',
#    'hasFormat': 'nlk:KMO200644366',
#    'issued': '2006',
#    'title': '집단상담',
#    'isbn': '8991777481',
#    'label': '집단상담'},
#   {'@id': 'nlk:KAC201308950',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '300 p.: 삽화; 23 cm',
#    'audienceNote': '일반이용자',
#    'bibliography': '참고문헌: p. 284-292, 색인수록',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '234',
#    'ddcn': 'http://lod.nl.go.kr/ddc/234_e21',
#    'genre': '일반도서',
#    'kdc': '231.4',
#    'kdcn': 'http://lod.nl.go.kr/kdc/231_e4',
#    'publicationPlace': '서울',
#    'typeOfResource': 'nlk:text',
#    'creator': '임희완',
#    'publisher': '그리심',
#    'accessRights': 'nlk:license3',
#    'alternative': 'Re-reading of Luther, Calvin, and Wesley',
#    'hasFormat': 'nlk:KMO200644369',
#    'issued': '2006',
#    'title': '루터·칼빈·웨슬리 다시읽기',
#    'isbn': '8957991611',
#    'label': '루터·칼빈·웨슬리 다시읽기',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2130328',
#    'sameAs': 'http://data.nanet.go.kr/ontology/NANET_BIB_MONO1200625748'},
#   {'@id': 'nlk:KAC201600395',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '487 p.; 22 cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '220.3',
#    'ddcn': 'http://lod.nl.go.kr/ddc/220_e21',
#    'genre': '일반도서',
#    'kdc': '230.34',
#    'kdcn': 'http://lod.nl.go.kr/kdc/230_e4',
#    'keyword': '목회용어',
#    'publicationPlace': '서울',
#    'remainderOfTitle': '한국교회 갱신을 위하여',
#    'typeOfResource': 'nlk:text',
#    'creator': '김석한',
#    'publisher': '대서',
#    'accessRights': 'nlk:license3',
#    'alternative': '바른 말 바로 쓰기·기독교연합신문 연재칼럼',
#    'hasFormat': 'nlk:KMO200644385',
#    'issued': '2006',
#    'title': '교회용어 바로쓰기',
#    'isbn': '8995628537',
#    'label': '교회용어 바로쓰기'},
#   {'@id': 'nlk:KAC200606458',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '235 p.: 도표; 23 cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '658.401',
#    'ddcn': 'http://lod.nl.go.kr/ddc/658_e21',
#    'genre': '일반도서',
#    'kdc': '325.1',
#    'kdcn': 'http://lod.nl.go.kr/kdc/325_e4',
#    'publicationPlace': '서울',
#    'remainderOfTitle': '현장 지도의 사례로 배우는 도요타 생산방식의 힘',
#    'typeOfResource': 'nlk:text',
#    'creator': '미즈시마 아이이치로',
#    'publisher': '리드리드출판',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200644423',
#    'issued': '2006',
#    'language': 'http://lod.nl.go.kr/countries/KOR',
#    'title': '도요타 배우기',
#    'isbn': '8972772402',
#    'label': '도요타 배우기'},
#   {'@id': 'nlk:KAC201008114',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '141 p.; 19 cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-11T17:14:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '895.715',
#    'ddcn': 'http://lod.nl.go.kr/ddc/895_e21',
#    'genre': '일반도서',
#    'kdc': '811.6',
#    'kdcn': 'http://lod.nl.go.kr/kdc/811_e4',
#    'publicationPlace': '서울',
#    'remainderOfTitle': '김주곤 시집',
#    'titleOfSeries': '모아드림 기획시선; 092',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '모아드림 기획시선; 092',
#    'creator': '김주곤',
#    'publisher': '모아드림',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200644452',
#    'issued': '2006',
#    'title': '소리 없는 소리',
#    'isbn': '8956640920',
#    'label': '소리 없는 소리',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2514194',
#    'sameAs': 'http://data.nanet.go.kr/ontology/NANET_BIB_MONO1200626662'},
#   {'@id': 'nlk:KAC201761304',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '124 p.; 19 cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '895.714',
#    'ddcn': 'http://lod.nl.go.kr/ddc/895_e21',
#    'genre': '일반도서',
#    'kdc': '811.6',
#    'kdcn': 'http://lod.nl.go.kr/kdc/811_e4',
#    'publicationPlace': '서울',
#    'remainderOfTitle': '이용범 시집',
#    'titleOfSeries': '모아드림 기획시선; 091',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '모아드림 기획시선; 091',
#    'creator': '이용범',
#    'publisher': '모아드림',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200644453',
#    'issued': '2006',
#    'title': '남은 사람은 떠난 사람에게',
#    'isbn': '8956640912',
#    'label': '남은 사람은 떠난 사람에게',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2494041'},
#   {'@id': 'nlk:KAC201207590',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '134 p.; 19 cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '895.714',
#    'ddcn': 'http://lod.nl.go.kr/ddc/895_e21',
#    'genre': '일반도서',
#    'kdc': '811.6',
#    'kdcn': 'http://lod.nl.go.kr/kdc/811_e4',
#    'publicationPlace': '서울',
#    'remainderOfTitle': '최성배 시집',
#    'titleOfSeries': '모아드림 기획시선; 093',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '모아드림 기획시선; 093',
#    'creator': '최성배',
#    'publisher': '모아드림',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200644455',
#    'issued': '2006',
#    'title': '뜨거운 바다',
#    'isbn': '8956640939',
#    'label': '뜨거운 바다'},
#   {'@id': 'nlk:KAC199609304',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '333 p.; 21 cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '306.43',
#    'ddcn': 'http://lod.nl.go.kr/ddc/306_e21',
#    'genre': '일반도서',
#    'kdc': '370.13',
#    'kdcn': 'http://lod.nl.go.kr/kdc/370_e4',
#    'publicationPlace': '서울',
#    'typeOfResource': 'nlk:text',
#    'creator': 'Freire, Paulo',
#    'publisher': '아침이슬',
#    'accessRights': 'nlk:license3',
#    'alternative': 'We make the road by walking',
#    'description': 'Freire, Paulo',
#    'hasFormat': 'nlk:KMO200644653',
#    'issued': '2006',
#    'language': 'http://lod.nl.go.kr/countries/KOR',
#    'title': '우리가 걸어가면 길이 됩니다',
#    'isbn': '8988996682',
#    'label': '우리가 걸어가면 길이 됩니다',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2529148',
#    'sameAs': 'http://data.nanet.go.kr/ontology/NANET_BIB_MONO1200629120'},
#   {'@id': 'nlk:KAC200108916',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '223 p. : 삽화, 초상 ; 21 cm',
#    'audienceNote': '일반이용자',
#    'bibliography': '\\"데즈카 오사무 연보\\" 수록',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '895.685',
#    'ddcn': 'http://lod.nl.go.kr/ddc/895_e21',
#    'genre': '일반도서',
#    'kdc': '838',
#    'kdcn': 'http://lod.nl.go.kr/kdc/838_e4',
#    'publicationPlace': '서울',
#    'typeOfResource': 'nlk:text',
#    'creator': '정윤아',
#    'publisher': '누림Book',
#    'accessRights': 'nlk:license3',
#    'alternative': 'ぼくのマンガ人生',
#    'description': '원저자명: 手塚治蟲',
#    'hasFormat': 'nlk:KMO200644792',
#    'issued': '2006',
#    'language': 'http://lod.nl.go.kr/countries/KOR',
#    'title': '어머니는 나에게 하고 싶은 일을 하라고 하셨다',
#    'edition': '개정판',
#    'isbn': '8980730721',
#    'label': '어머니는 나에게 하고 싶은 일을 하라고 하셨다'},
#   {'@id': 'nlk:KAC2018A7635',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '349 p.: 삽화; 25 cm',
#    'audienceNote': '일반이용자',
#    'bibliography': '참고문헌: p. 346-349',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '004',
#    'ddcn': 'http://lod.nl.go.kr/ddc/004_e21',
#    'genre': '일반도서',
#    'kdc': '004',
#    'kdcn': 'http://lod.nl.go.kr/kdc/004_e4',
#    'keyword': '유비쿼터스 컴퓨팅[ubiquitous computing]',
#    'publicationPlace': '서울',
#    'restriction': '국립중앙도서관, 국립어린이청소년도서관, 국립세종도서관, 협력기관(공공.대학.전문/특수.해외.작은도서관) 공개',
#    'typeOfResource': 'nlk:text',
#    'creator': '박석규',
#    'publisher': '태영출판사',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO200644827',
#    'issued': '2006',
#    'language': 'http://lod.nl.go.kr/countries/KOR',
#    'title': '(유비쿼터스 컴퓨팅 기술과) 정보화 교육',
#    'isbn': '8991777406',
#    'label': '(유비쿼터스 컴퓨팅 기술과) 정보화 교육'},
#   {'@id': 'nlk:KAC199636257',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '396 p.: 천연색삽화; 29 cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '228.052034',
#    'ddcn': 'http://lod.nl.go.kr/ddc/228_e21',
#    'genre': '일반도서',
#    'kdc': '233.8',
#    'kdcn': 'http://lod.nl.go.kr/kdc/233_e4',
#    'keyword': '요한 계시록[--啓示錄]',
#    'publicationPlace': '서울',
#    'restriction': '국립중앙도서관, 국립어린이청소년도서관, 국립세종도서관, 협력기관(공공.대학.전문/특수.해외.작은도서관) 공개',
#    'typeOfResource': 'nlk:text',
#    'publisher': '말씀보존학회',
#    'accessRights': 'nlk:license3',
#    'alternative': '그림으로 보는 요한계시록',
#    'description': 'Ruckman, Peter S',
#    'hasFormat': 'nlk:KMO200644842',
#    'issued': '2006',
#    'language': 'http://lod.nl.go.kr/countries/KOR',
#    'title': '(피터 럭크만의 그림으로 보는) 요한계시록',
#    'isbn': '8992164041',
#    'label': '(피터 럭크만의 그림으로 보는) 요한계시록',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2526523'},
#   {'@id': 'nlk:KAC201515527',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '504 p.; 22 cm',
#    'audienceNote': '일반이용자',
#    'bibliography': '참고문헌과 색인수록',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '230.09',
#    'ddcn': 'http://lod.nl.go.kr/ddc/230_e21',
#    'genre': '일반도서',
#    'kdc': '231.09',
#    'kdcn': 'http://lod.nl.go.kr/kdc/231_e4',
#    'publicationPlace': '서울',
#    'titleOfSeries': '교회와 신학의 역사 원전',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '교회와 신학의 역사 원전',
# ...
#    'issued': '2003',
#    'title': '작은 사랑의 기적',
#    'isbn': '8987170861',
#    'label': '작은 사랑의 기적'},
#   {'@id': 'nlk:KAC201202372',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '247 p. ; 22 cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'genre': '일반도서',
#    'kdc': '231.42',
#    'kdcn': 'http://lod.nl.go.kr/kdc/231_e6',
#    'publicationPlace': '서울',
#    'remainderOfTitle': '세파에 꺾이지 않는 진리의 매듭을 지닌 크리스천',
#    'titleOfSeries': '믿음의 글들 ; 223',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '믿음의 글들 ; 223',
#    'creator': '이재철',
#    'publisher': '홍성사',
#    'accessRights': 'nlk:license3',
#    'alternative': '믿음의 글들',
#    'hasFormat': 'nlk:KMO201610370',
#    'issued': '2005',
#    'title': '매듭짓기',
#    'isbn': '9788936502232',
#    'label': '매듭짓기',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1566123'},
#   {'@id': 'nlk:KAC201604738',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '311 p. : 천연색삽화 ; 23 cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'genre': '일반도서',
#    'kdc': '186.3',
#    'kdcn': 'http://lod.nl.go.kr/kdc/186_e6',
#    'publicationPlace': '서울',
#    'typeOfResource': 'nlk:text',
#    'creator': '안주영',
#    'publisher': '무한',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO201610404',
#    'issued': '2010',
#    'title': '살짝 미쳐가는 세상에서 완전 행복해지는 법',
#    'isbn': '9788956012742',
#    'label': '살짝 미쳐가는 세상에서 완전 행복해지는 법'},
#   {'@id': 'nlk:KAC201011188',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '94 p. ; 20 cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'genre': '일반도서',
#    'kdc': '811.7',
#    'kdcn': 'http://lod.nl.go.kr/kdc/811_e6',
#    'publicationPlace': '서울',
#    'titleOfSeries': '솟대 love poem ; 4',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '솟대 love poem ; 4',
#    'creator': '서정슬',
#    'publisher': '솟대',
#    'accessRights': 'nlk:license3',
#    'alternative': '솟대 love poem',
#    'hasFormat': 'nlk:KMO201611682',
#    'issued': '2003',
#    'title': '하늘 보며 땅 보며',
#    'isbn': '8985863185',
#    'label': '하늘 보며 땅 보며',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1417605'},
#   {'@id': 'nlk:KAC201008670',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '129 p. ; 22 cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-11T13:55:51^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'genre': '일반도서',
#    'kdc': '235.8',
#    'kdcn': 'http://lod.nl.go.kr/kdc/235_e6',
#    'publicationPlace': '서울',
#    'titleOfSeries': '두란노 글모음 시리즈 ; 14',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '두란노 글모음 시리즈 ; 14',
#    'creator': '이만재',
#    'publisher': '두란노',
#    'accessRights': 'nlk:license3',
#    'alternative': '두란노 글모음 시리즈',
#    'hasFormat': 'nlk:KMO201621336',
#    'issued': '2009',
#    'title': '막 쪄낸 찐빵',
#    'edition': '개정[판]',
#    'isbn': '8970088652',
#    'label': '막 쪄낸 찐빵'},
#   {'@id': 'nlk:KAC201106396',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '163 p. : 삽화 ; 20 cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'genre': '일반도서',
#    'kdc': '199.8',
#    'kdcn': 'http://lod.nl.go.kr/kdc/199_e6',
#    'publicationPlace': '서울',
#    'titleOfSeries': 'Bestseller worldbook ; 11',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': 'Bestseller worldbook ; 11',
#    'creator': '지브란, 칼릴',
#    'publisher': '소담출판사',
#    'accessRights': 'nlk:license3',
#    'alternative': 'Spiriual saying of Kahlil gibran',
#    'description': '원저자명: Kahlil Gibran',
#    'hasFormat': 'nlk:KMO201621376',
#    'issued': '1996',
#    'language': 'http://lod.nl.go.kr/countries/KOR',
#    'title': '아홉가지 슬픔에 관한 명상',
#    'edition': '중판',
#    'isbn': '8973810111',
#    'label': '아홉가지 슬픔에 관한 명상',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=35888'},
#   {'@id': 'nlk:KAC201317314',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '243 p. : 도표 ; 18 cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-11T10:45:02^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'genre': '일반도서',
#    'kdc': '327.04',
#    'kdcn': 'http://lod.nl.go.kr/kdc/327_e6',
#    'publicationPlace': '[서울]',
#    'remainderOfTitle': '핸디북',
#    'typeOfResource': 'nlk:text',
#    'creator': '이지연',
#    'publisher': '원앤원북스',
#    'accessRights': 'nlk:license3',
#    'description': '표제관련정보: 돈이 붙는 여자 vs 돈 꾸러다니는 여자',
#    'hasFormat': 'nlk:KMO201625193',
#    'issued': '2007',
#    'title': '20대 여자가 꼭 알아야 할 돈 관리법 41',
#    'isbn': '9788992857192',
#    'label': '20대 여자가 꼭 알아야 할 돈 관리법 41',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=10653076'},
#   {'@id': 'nlk:KAC200505691',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '55 p. ; 15 cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'genre': '일반도서',
#    'kdc': '224.3',
#    'kdcn': 'http://lod.nl.go.kr/kdc/224_e6',
#    'keyword': '불교[佛敎]',
#    'publicationPlace': '서울',
#    'restriction': '국립중앙도서관, 국립어린이청소년도서관, 국립세종도서관, 협력기관(공공.대학.전문/특수.해외.작은도서관) 공개',
#    'titleOfSeries': '보리수잎 ; 39',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '보리수잎 ; 39',
#    'creator': '전채린',
#    'publisher': '고요한 소리',
#    'accessRights': 'nlk:license3',
#    'alternative': 'Self-made private prison',
#    'description': '영어 원작을 한국어로 번역',
#    'hasFormat': 'nlk:KMO201628953',
#    'issued': '2002',
#    'language': 'http://lod.nl.go.kr/countries/KOR',
#    'title': '스스로 만든 감옥',
#    'isbn': '9788985186636',
#    'label': '스스로 만든 감옥'},
#   {'@id': 'nlk:KAC201416853',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '207 p. ; 20 cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-11T13:55:51^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'genre': '일반도서',
#    'kdc': '234.8',
#    'kdcn': 'http://lod.nl.go.kr/kdc/234_e6',
#    'publicationPlace': '서울',
#    'typeOfResource': 'nlk:text',
#    'creator': '채의숭',
#    'publisher': '제네시스21',
#    'accessRights': 'nlk:license3',
#    'alternative': 'As to the Lord',
#    'hasFormat': 'nlk:KMO201630128',
#    'issued': '2007',
#    'title': '주께 하듯 하라',
#    'isbn': '9788971542903',
#    'label': '주께 하듯 하라'},
#   {'@id': 'nlk:KAC201612695',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '294 p. : 삽화(일부천연색) ; 22 cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'genre': '일반도서',
#    'kdc': '592.0099',
#    'kdcn': 'http://lod.nl.go.kr/kdc/592_e6',
#    'publicationPlace': '서울',
#    'remainderOfTitle': '오리지날리 이신우의 패션이야기',
#    'typeOfResource': 'nlk:text',
#    'creator': '이신우',
#    'publisher': '웅진출판',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO201630131',
#    'issued': '1993',
#    'title': '8시 91분',
#    'isbn': '8901008564',
#    'label': '8시 91분'},
#   {'@id': 'nlk:CNTS-00091465327',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '245 p. : 천연색삽화 ; 21 cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-11T18:46:22^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'genre': '일반도서',
#    'kdc': '377.804',
#    'kdcn': 'http://lod.nl.go.kr/kdc/377_e6',
#    'publicationPlace': '서울',
#    'typeOfResource': 'nlk:text',
#    'creator': '이재환',
#    'publisher': '발해그후',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO201630148',
#    'issued': '2006',
#    'title': '(고1 재환이의) 무작정 떠난 미국 교환학생',
#    'isbn': '8988301595',
#    'label': '(고1 재환이의) 무작정 떠난 미국 교환학생'},
#   {'@id': 'nlk:KAC199636511',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '118p.: 삽도; 21cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'genre': '일반도서',
#    'keyword': '서풍',
#    'publicationPlace': '부산',
#    'titleOfSeries': '선영명시선; 31',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '선영명시선; 31',
#    'creator': '셸리, 퍼시 비시',
#    'publisher': '선영사',
#    'accessRights': 'nlk:license3',
#    'description': 'Shelly, Percy Bysshe',
#    'hasFormat': 'nlk:KMO199505103',
#    'issued': '1994',
#    'language': 'http://lod.nl.go.kr/countries/KOR',
#    'title': '서풍의 노래',
#    'isbn': '8975588319',
#    'label': '서풍의 노래'},
#   {'@id': 'nlk:KAC201112038',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '427p.; 24cm',
#    'audienceNote': '일반이용자',
#    'bibliography': '참고문헌: p.403-414, 색인수록',
#    'datePublished': '2024-10-11T10:45:02^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '895.714',
#    'ddcn': 'http://lod.nl.go.kr/ddc/895_e21',
#    'genre': '일반도서',
#    'kdc': '811.609',
#    'kdcn': 'http://lod.nl.go.kr/kdc/811_e4',
#    'keyword': '시론',
#    'publicationPlace': '서울',
#    'typeOfResource': 'nlk:text',
#    'creator': '오형엽',
#    'publisher': '태학사',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO199944103',
#    'issued': '1999',
#    'title': '한국 근대시와 시론의 구조적 연구',
#    'isbn': '8976264959',
#    'label': '한국 근대시와 시론의 구조적 연구',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=201009',
#    'sameAs': 'http://data.nanet.go.kr/ontology/NANET_BIB_MONO1199918183'},
#   {'@id': 'nlk:KAC201330364',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '294p.: 삽도; 23cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-11T10:45:02^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '649',
#    'ddcn': 'http://lod.nl.go.kr/ddc/649_e21',
#    'genre': '일반도서',
#    'kdc': '598',
#    'kdcn': 'http://lod.nl.go.kr/kdc/598_e4',
#    'keyword': '과학',
#    'publicationPlace': '서울',
#    'typeOfResource': 'nlk:text',
#    'creator': '박문일',
#    'publisher': '한양대학교출판부',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO199944160',
#    'issued': '1999',
#    'title': '태교는 과학이다',
#    'isbn': '8972181218',
#    'label': '태교는 과학이다'},
#   {'@id': 'nlk:KAC201946690',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '221p.; 23cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '895.714',
#    'ddcn': 'http://lod.nl.go.kr/ddc/895_e21',
#    'genre': '일반도서',
#    'kdc': '811.6',
#    'kdcn': 'http://lod.nl.go.kr/kdc/811_e4',
#    'keyword': '길',
#    'publicationPlace': '서울',
#    'typeOfResource': 'nlk:text',
#    'creator': '강승',
#    'publisher': '제3공간',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO199944252',
#    'issued': '1999',
#    'title': '사람이 가는 길이 좋습니다',
#    'isbn': '8988857003',
#    'label': '사람이 가는 길이 좋습니다',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=99928',
#    'sameAs': 'http://data.nanet.go.kr/ontology/NANET_BIB_MONO1199918816'},
#   {'@id': 'nlk:KAC201829053',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '143p.; 21cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '895.714',
#    'ddcn': 'http://lod.nl.go.kr/ddc/895_e21',
#    'genre': '일반도서',
#    'kdc': '811.6',
#    'kdcn': 'http://lod.nl.go.kr/kdc/811_e4',
#    'keyword': '노동자',
#    'publicationPlace': '서울',
#    'remainderOfTitle': '일과 시 제5집',
#    'titleOfSeries': '마이노리티시선; 3',
#    'typeOfResource': 'nlk:text',
#    'uniformTitleOfSeries': '마이노리티시선; 3',
#    'creator': '일과시',
#    'publisher': '갈무리',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO199944401',
#    'issued': '1999',
#    'title': '한 노동자가 위험하다',
#    'isbn': '8986114267(세트)',
#    'label': '한 노동자가 위험하다',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=80403'},
#   {'@id': 'nlk:KAC201817338',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '289p.; 23cm',
#    'audienceNote': '일반이용자',
#    'bibliography': '참고문헌: p.277-289',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '249',
#    'ddcn': 'http://lod.nl.go.kr/ddc/249_e21',
#    'genre': '일반도서',
#    'kdc': '234.9',
#    'kdcn': 'http://lod.nl.go.kr/kdc/234_e4',
#    'keyword': '가정환경',
#    'publicationPlace': '서울',
#    'typeOfResource': 'nlk:text',
#    'creator': '황규애',
#    'publisher': '영문',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO199944454',
#    'issued': '1999',
#    'title': '가정환경과 성격형성',
#    'isbn': '8987697754',
#    'label': '가정환경과 성격형성',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=91908'},
#   {'@id': 'nlk:KAC201226983',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '63p.: 삽도; 23cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '268.4',
#    'ddcn': 'http://lod.nl.go.kr/ddc/268_e21',
#    'genre': '일반도서',
#    'kdc': '235.74',
#    'kdcn': 'http://lod.nl.go.kr/kdc/235_e4',
#    'keyword': '교재',
#    'publicationPlace': '서울',
#    'remainderOfTitle': '새신자를 위하여',
#    'typeOfResource': 'nlk:text',
#    'creator': '김명규',
#    'publisher': '예루살렘',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO199944532',
#    'issued': '1999',
#    'title': '새신자 성장을 위한 교재',
#    'isbn': '8972102687',
#    'label': '새신자 성장을 위한 교재'},
#   {'@id': 'nlk:KAC201838120',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '441p.; 23cm',
#    'audienceNote': '일반이용자',
#    'bibliography': '참고문헌: p.423-435',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '249',
#    'ddcn': 'http://lod.nl.go.kr/ddc/249_e21',
#    'genre': '일반도서',
#    'kdc': '234.9',
#    'kdcn': 'http://lod.nl.go.kr/kdc/234_e4',
#    'keyword': 'CHURCH',
#    'publicationPlace': '인천',
#    'typeOfResource': 'nlk:text',
#    'creator': '홍원팔',
#    'publisher': '바울',
#    'accessRights': 'nlk:license3',
#    'alternative': 'Restoring the early church',
#    'description': 'Dowgiewicz, Susan',
#    'hasFormat': 'nlk:KMO199944577',
#    'issued': '1999',
#    'language': 'http://lod.nl.go.kr/countries/KOR',
#    'title': '(가정사역 중심의)새 밀레니엄 교회',
#    'isbn': '8972863254',
#    'label': '(가정사역 중심의)새 밀레니엄 교회'},
#   {'@id': 'nlk:KAC201213605',
#    '@type': 'nlon:OnlineMaterial',
#    'extent': '88p.; 19cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '361.37',
#    'ddcn': 'http://lod.nl.go.kr/ddc/361_e21',
#    'genre': '일반도서',
#    'kdc': '338.13',
#    'kdcn': 'http://lod.nl.go.kr/kdc/338_e4',
#    'keyword': '사회복지',
#    'publicationPlace': '서울',
#    'typeOfResource': 'nlk:text',
#    'creator': '김선희',
#    'publisher': '홍익재',
#    'accessRights': 'nlk:license3',
#    'description': "권말에 부록으로 '실습관련서식'수록",
#    'hasFormat': 'nlk:KMO199944829',
#    'issued': '1999',
#    'title': '사회복지실습길라잡이',
#    'isbn': '8971431148',
#    'label': '사회복지실습길라잡이',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=26141',
#    'sameAs': 'http://data.nanet.go.kr/ontology/NANET_BIB_MONO1199918952'},
#   {'@id': 'nlk:KAC201823603',
#    '@type': 'nlon:ElectronicBook',
#    'extent': 'x,332p.: 삽도; 26cm',
#    'audienceNote': '일반이용자',
#    'bibliography': '참고문헌: p.293-320',
#    'datePublished': '2024-10-10T23:37:36^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '643',
#    'ddcn': 'http://lod.nl.go.kr/ddc/643_e21',
#    'genre': '일반도서',
#    'kdc': '595',
#    'kdcn': 'http://lod.nl.go.kr/kdc/595_e4',
#    'keyword': '주택연구',
#    'publicationPlace': '서울',
#    'typeOfResource': 'nlk:text',
#    'creator': '이연숙',
#    'publisher': '태림문화사',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO199944973',
#    'issued': '1999',
#    'language': 'http://lod.nl.go.kr/countries/KOR',
#    'title': '스웨덴의 주택연구와 디자인',
#    'isbn': '8982051619',
#    'label': '스웨덴의 주택연구와 디자인',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=61523'},
#   {'@id': 'nlk:KAC201303810',
#    '@type': 'nlon:ElectronicBook',
#    'extent': '368p.; 23cm',
#    'audienceNote': '일반이용자',
#    'datePublished': '2024-10-11T20:31:46^^http://www.w3.org/2001/XMLSchema#dateTime',
#    'ddc': '226.5',
#    'ddcn': 'http://lod.nl.go.kr/ddc/226_e21',
#    'genre': '일반도서',
#    'kdc': '233.65',
#    'kdcn': 'http://lod.nl.go.kr/kdc/233_e4',
#    'keyword': '그리스도',
#    'publicationPlace': '광주',
#    'typeOfResource': 'nlk:text',
#    'creator': '이영헌',
#    'publisher': '생활성서사',
#    'accessRights': 'nlk:license3',
#    'hasFormat': 'nlk:KMO199945645',
#    'issued': '1999',
#    'title': '(요한이 전하는)하느님의 외아들 예수 그리스도',
#    'isbn': '8986156733',
#    'label': '(요한이 전하는)하느님의 외아들 예수 그리스도',
#    'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=80772'},
#   ...]}

# %%
if not books:
    print("도서 정보를 확인할 수 없습니다.")
else:
    processed_books = []
    korean_regex = re.compile("^[가-힣]")

    for book in books:
        title = book.get("title")
        # audienceNote = book.get("audienceNote")
        
        if not title or not korean_regex.match(title):
            continue
        
        # if audienceNote != "일반이용자":
        #     continue
        
        kdc_code = book.get("kdc")
        main_kdc_code = kdc_code[:2] if kdc_code else None 
        main_kdc_description = kdc_categories.get(main_kdc_code)
        
        ddc_code = book.get("ddc")
        main_ddc_code = ddc_code[:2] if ddc_code else None
        main_ddc_description = ddc_categories.get(main_ddc_code)
        
        if main_kdc_description is None and main_ddc_description is None:
            continue

        
        processed_book = {
            "title": book.get("title"),
            "creator": book.get("creator"),
            "publisher": book.get("publisher"),
            "issuedYear": book.get("issuedYear"),
            "kdc": book.get("kdc"),
            "ddc": book.get("ddc"),
            "mainCategoryDescription": main_kdc_description if main_kdc_description else main_ddc_description,
            "alternative": book.get("alternative"),
            "keyword": book.get("keyword"),
            "seeAlso": book.get("seeAlso"),
        }

        processed_books.append(processed_book)

# %%
processed_books
# Out:
# [{'title': '우주를 보고 세상을 보면',
#   'creator': '장사주',
#   'publisher': '三光出版社',
#   'issuedYear': None,
#   'kdc': '041',
#   'ddc': '089.957',
#   'mainCategoryDescription': '강연집, 수필집, 연설문집',
#   'alternative': None,
#   'keyword': '세상',
#   'seeAlso': None},
#  {'title': '역사의 풍경',
#   'creator': 'Gaddis, John Lewis',
#   'publisher': '에코리브르',
#   'issuedYear': None,
#   'kdc': '901',
#   'ddc': '901',
#   'mainCategoryDescription': '역사',
#   'alternative': 'Landscape of history : how historians map the past',
#   'keyword': 'PAST',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=144891'},
#  {'title': '오스카와 장미할머니',
#   'creator': '이승경',
#   'publisher': '문학세계사',
#   'issuedYear': None,
#   'kdc': '863',
#   'ddc': '843.914',
#   'mainCategoryDescription': '프랑스문학',
#   'alternative': 'Oscar et la dame rose',
#   'keyword': '오스카',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=144862'},
#  {'title': '서양 해운사',
#   'creator': 'Fayle, Charles Ernest',
#   'publisher': '혜안',
#   'issuedYear': None,
#   'kdc': '326.36092',
#   'ddc': '387.5094',
#   'mainCategoryDescription': '경제학',
#   'alternative': "Short history of the world's shipping industry",
#   'keyword': 'WORLD',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1216764'},
#  {'title': '학교와 사회복지 실천',
#   'creator': '홍순혜',
#   'publisher': '나남출판',
#   'issuedYear': None,
#   'kdc': '372.6',
#   'ddc': '371.4',
#   'mainCategoryDescription': '교육학',
#   'alternative': None,
#   'keyword': '실천',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=144954'},
#  {'title': '고지식과 외골수의 대화',
#   'creator': '정희돈',
#   'publisher': '우리출판사',
#   'issuedYear': None,
#   'kdc': '814.6',
#   'ddc': '895.745',
#   'mainCategoryDescription': '한국문학',
#   'alternative': None,
#   'keyword': '대화',
#   'seeAlso': None},
#  {'title': '미래신문',
#   'creator': '이인식',
#   'publisher': '김영사',
#   'issuedYear': None,
#   'kdc': '331.54',
#   'ddc': '303.49',
#   'mainCategoryDescription': '사회학, 사회문제',
#   'alternative': '(The)future times',
#   'keyword': '21세기',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=145227'},
#  {'title': '중국조선어연구',
#   'creator': None,
#   'publisher': '집문당',
#   'issuedYear': None,
#   'kdc': '710',
#   'ddc': '495.7',
#   'mainCategoryDescription': '한국어',
#   'alternative': None,
#   'keyword': '조선어',
#   'seeAlso': None},
#  {'title': '성공하는 사람은 뭔가 다르다',
#   'creator': '후타미 미치오',
#   'publisher': '빛무리',
#   'issuedYear': None,
#   'kdc': '325.04',
#   'ddc': '650.1',
#   'mainCategoryDescription': '경제학',
#   'alternative': None,
#   'keyword': '성공법',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=143432'},
#  {'title': '일반물리학',
#   'creator': '조육',
#   'publisher': '북스힐',
#   'issuedYear': None,
#   'kdc': '420',
#   'ddc': '530',
#   'mainCategoryDescription': '물리학',
#   'alternative': None,
#   'keyword': '일반물리학',
#   'seeAlso': None},
#  {'title': '교양 물리',
#   'creator': '차동우',
#   'publisher': '북스힐',
#   'issuedYear': None,
#   'kdc': '420',
#   'ddc': '530',
#   'mainCategoryDescription': '물리학',
#   'alternative': None,
#   'keyword': '물리학',
#   'seeAlso': None},
#  {'title': '미래전에 있어서 불확실성 제거',
#   'creator': 'Owens, Bill',
#   'publisher': '21세기군사연구소',
#   'issuedYear': None,
#   'kdc': '390.942',
#   'ddc': '355.00973',
#   'mainCategoryDescription': '국방, 군사학',
#   'alternative': 'Lifting the fog of war',
#   'keyword': '미래전',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1409231'},
#  {'title': '성만찬의 영성',
#   'creator': '김진',
#   'publisher': '엔크리스토',
#   'issuedYear': None,
#   'kdc': '237.43',
#   'ddc': '264.36',
#   'mainCategoryDescription': '기독교',
#   'alternative': None,
#   'keyword': '성찬식',
#   'seeAlso': None},
#  {'title': '해방론',
#   'creator': '마르쿠제, 헤르베르트',
#   'publisher': '울력',
#   'issuedYear': None,
#   'kdc': '301.9',
#   'ddc': '335.8',
#   'mainCategoryDescription': '사회과학',
#   'alternative': 'Essay on liberation',
#   'keyword': '해방',
#   'seeAlso': None},
#  {'title': '서양의 역사와 문화 기행',
#   'creator': '양재열',
#   'publisher': '서림출판사',
#   'issuedYear': None,
#   'kdc': '920',
#   'ddc': '940',
#   'mainCategoryDescription': '유럽(구라파)',
#   'alternative': None,
#   'keyword': '문화기행',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2282254'},
#  {'title': '이아무개의 마음공부',
#   'creator': '이현주',
#   'publisher': '두레',
#   'issuedYear': None,
#   'kdc': '234.3',
#   'ddc': '242',
#   'mainCategoryDescription': '기독교',
#   'alternative': None,
#   'keyword': '마음공부',
#   'seeAlso': None},
#  {'title': '할로윈 카드 만들기',
#   'creator': None,
#   'publisher': '혜지원',
#   'issuedYear': None,
#   'kdc': '634.9',
#   'ddc': '745.54',
#   'mainCategoryDescription': '공예, 장식미술',
#   'alternative': None,
#   'keyword': 'CARD',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=132173'},
#  {'title': '패션 카드 만들기',
#   'creator': None,
#   'publisher': '혜지원',
#   'issuedYear': None,
#   'kdc': '634.9',
#   'ddc': '745.54',
#   'mainCategoryDescription': '공예, 장식미술',
#   'alternative': None,
#   'keyword': '카드',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=133066'},
#  {'title': '감사 카드 만들기',
#   'creator': None,
#   'publisher': '혜지원',
#   'issuedYear': None,
#   'kdc': '634.9',
#   'ddc': '745.54',
#   'mainCategoryDescription': '공예, 장식미술',
#   'alternative': None,
#   'keyword': '종이공예',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=130964'},
#  {'title': '영양분석 & 실험조리',
#   'creator': '현영희',
#   'publisher': '지구문화사',
#   'issuedYear': None,
#   'kdc': '594.5',
#   'ddc': '641.5',
#   'mainCategoryDescription': '가정학 및 가정생활',
#   'alternative': 'Experiment cooking',
#   'keyword': '실험조리',
#   'seeAlso': None},
#  {'title': '사회구조와 행위',
#   'creator': '김용학',
#   'publisher': '나남출판',
#   'issuedYear': None,
#   'kdc': '300.1',
#   'ddc': '300.1',
#   'mainCategoryDescription': '사회과학',
#   'alternative': 'Social structure and action in social theory',
#   'keyword': '행위',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=138990'},
#  {'title': '앞치마를 두른 남자',
#   'creator': 'Momose, Eiko',
#   'publisher': '나노미디어',
#   'issuedYear': None,
#   'kdc': '332.23',
#   'ddc': '306.87',
#   'mainCategoryDescription': '사회학, 사회문제',
#   'alternative': None,
#   'keyword': '앞치마',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=128369'},
#  {'title': '신라중대 정치사연구',
#   'creator': '박해현',
#   'publisher': '국학자료원',
#   'issuedYear': None,
#   'kdc': '911.036',
#   'ddc': '951.901',
#   'mainCategoryDescription': '아시아(아세아)',
#   'alternative': None,
#   'keyword': '신라',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2282330'},
#  {'title': '도요타 에이지의 결단',
#   'creator': '풍전영이',
#   'publisher': '굿모닝북스',
#   'issuedYear': None,
#   'kdc': '325.099',
#   'ddc': '658.0092',
#   'mainCategoryDescription': '경제학',
#   'alternative': None,
#   'keyword': '도요타자동차',
#   'seeAlso': None},
#  {'title': '영혼을 치유하는 사랑',
#   'creator': 'Rodgers, Tom',
#   'publisher': '예영커뮤니케이션',
#   'issuedYear': None,
#   'kdc': '234.9',
#   'ddc': '248.844',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Soul healing love',
#   'keyword': 'LOVE',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=146260'},
#  {'title': '어린이의 상한 마음을 돌보기 위한 독서치료',
#   'creator': '김정근',
#   'publisher': '한울',
#   'issuedYear': None,
#   'kdc': '029.8',
#   'ddc': '028.5',
#   'mainCategoryDescription': '문헌정보학',
#   'alternative': None,
#   'keyword': '마음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1271966'},
#  {'title': '독서치료와 공공도서관 서비스',
#   'creator': '김정근',
#   'publisher': '한울',
#   'issuedYear': None,
#   'kdc': '029.8',
#   'ddc': '028',
#   'mainCategoryDescription': '문헌정보학',
#   'alternative': None,
#   'keyword': '독서치료',
#   'seeAlso': None},
#  {'title': '으능나무 금빛 몸',
#   'creator': None,
#   'publisher': '만인사',
#   'issuedYear': None,
#   'kdc': '811.6',
#   'ddc': '895.715',
#   'mainCategoryDescription': '한국문학',
#   'alternative': None,
#   'keyword': '금빛',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1424638'},
#  {'title': '염소좌 아래 잠들다',
#   'creator': '전명숙',
#   'publisher': '천년의시작',
#   'issuedYear': None,
#   'kdc': '811.6',
#   'ddc': '895.715',
#   'mainCategoryDescription': '한국문학',
#   'alternative': None,
#   'keyword': '염소좌',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=145369'},
#  {'title': '회계, 그게 그렇군요',
#   'creator': '전정수',
#   'publisher': '청람',
#   'issuedYear': None,
#   'kdc': '325.9',
#   'ddc': '657',
#   'mainCategoryDescription': '경제학',
#   'alternative': None,
#   'keyword': '회계',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1270690'},
#  {'title': '반고흐 컨스피러시',
#   'creator': 'Davis, J. Madison',
#   'publisher': '마로니에북스',
#   'issuedYear': None,
#   'kdc': '843',
#   'ddc': '813.54',
#   'mainCategoryDescription': '영미문학',
#   'alternative': 'Van Gogh conspiracy',
#   'keyword': '미국 현대 소설[美國現代小說]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2521357'},
#  {'title': '집단상담',
#   'creator': '장선철',
#   'publisher': '태영출판사',
#   'issuedYear': None,
#   'kdc': '186.3',
#   'ddc': '158.3',
#   'mainCategoryDescription': '심리학',
#   'alternative': 'Group counseling',
#   'keyword': '집단상담프로그램',
#   'seeAlso': None},
#  {'title': '루터·칼빈·웨슬리 다시읽기',
#   'creator': '임희완',
#   'publisher': '그리심',
#   'issuedYear': None,
#   'kdc': '231.4',
#   'ddc': '234',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Re-reading of Luther, Calvin, and Wesley',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2130328'},
#  {'title': '교회용어 바로쓰기',
#   'creator': '김석한',
#   'publisher': '대서',
#   'issuedYear': None,
#   'kdc': '230.34',
#   'ddc': '220.3',
#   'mainCategoryDescription': '기독교',
#   'alternative': '바른 말 바로 쓰기·기독교연합신문 연재칼럼',
#   'keyword': '목회용어',
#   'seeAlso': None},
#  {'title': '도요타 배우기',
#   'creator': '미즈시마 아이이치로',
#   'publisher': '리드리드출판',
#   'issuedYear': None,
#   'kdc': '325.1',
#   'ddc': '658.401',
#   'mainCategoryDescription': '경제학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '소리 없는 소리',
#   'creator': '김주곤',
#   'publisher': '모아드림',
#   'issuedYear': None,
#   'kdc': '811.6',
#   'ddc': '895.715',
#   'mainCategoryDescription': '한국문학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2514194'},
#  {'title': '남은 사람은 떠난 사람에게',
#   'creator': '이용범',
#   'publisher': '모아드림',
#   'issuedYear': None,
#   'kdc': '811.6',
#   'ddc': '895.714',
#   'mainCategoryDescription': '한국문학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2494041'},
#  {'title': '뜨거운 바다',
#   'creator': '최성배',
#   'publisher': '모아드림',
#   'issuedYear': None,
#   'kdc': '811.6',
#   'ddc': '895.714',
#   'mainCategoryDescription': '한국문학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '우리가 걸어가면 길이 됩니다',
#   'creator': 'Freire, Paulo',
#   'publisher': '아침이슬',
#   'issuedYear': None,
#   'kdc': '370.13',
#   'ddc': '306.43',
#   'mainCategoryDescription': '교육학',
#   'alternative': 'We make the road by walking',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2529148'},
#  {'title': '어머니는 나에게 하고 싶은 일을 하라고 하셨다',
#   'creator': '정윤아',
#   'publisher': '누림Book',
#   'issuedYear': None,
#   'kdc': '838',
#   'ddc': '895.685',
#   'mainCategoryDescription': '일본문학',
#   'alternative': 'ぼくのマンガ人生',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '고대교회',
#   'creator': 'Ritter, Adolf Martin',
#   'publisher': '한국신학연구소',
#   'issuedYear': None,
#   'kdc': '231.09',
#   'ddc': '230.09',
#   'mainCategoryDescription': '기독교',
#   'alternative': '교회와 신학의 역사 원전',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2531960'},
#  {'title': '스님 마음이 불편해요',
#   'creator': '법륜',
#   'publisher': '정토출판',
#   'issuedYear': None,
#   'kdc': '224.2',
#   'ddc': '294.34',
#   'mainCategoryDescription': '불교',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '소나무와 한국인',
#   'creator': None,
#   'publisher': '통천문화사',
#   'issuedYear': None,
#   'kdc': '606.3',
#   'ddc': '707.4',
#   'mainCategoryDescription': '예술',
#   'alternative': '(The)pine tree and Korean : special exhibition',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2508049'},
#  {'title': '따뜻한 적막',
#   'creator': '김명인',
#   'publisher': '문학과지성사',
#   'issuedYear': None,
#   'kdc': '811.6',
#   'ddc': '895.715',
#   'mainCategoryDescription': '한국문학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2529942'},
#  {'title': '태도가 이끄는 성공',
#   'creator': 'Colan, Lee J',
#   'publisher': '한언',
#   'issuedYear': None,
#   'kdc': '325.04',
#   'ddc': '650.1',
#   'mainCategoryDescription': '경제학',
#   'alternative': 'Orchestrating attitude',
#   'keyword': '성공 전략[成功戰略]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2511904'},
#  {'title': '열정이 이끄는 성공',
#   'creator': '리 J., 콜란',
#   'publisher': '한언',
#   'issuedYear': None,
#   'kdc': '325.04',
#   'ddc': '650.1',
#   'mainCategoryDescription': '경제학',
#   'alternative': 'Passionate performance',
#   'keyword': '리더십',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2511905'},
#  {'title': '어두워질 때까지',
#   'creator': '한미성',
#   'publisher': '서정시학',
#   'issuedYear': None,
#   'kdc': '811.6',
#   'ddc': '895.715',
#   'mainCategoryDescription': '한국문학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2531331'},
#  {'title': '눈사람이 눈사람이 되는 동안',
#   'creator': '이태선',
#   'publisher': '서정시학',
#   'issuedYear': None,
#   'kdc': '811.6',
#   'ddc': '895.715',
#   'mainCategoryDescription': '한국문학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2531334'},
#  {'title': '야오네 집',
#   'creator': '이지현',
#   'publisher': '행복한만화가게',
#   'issuedYear': None,
#   'kdc': '598.1',
#   'ddc': '649.1',
#   'mainCategoryDescription': '가정학 및 가정생활',
#   'alternative': '한 아기의 눈물겨운 체험담',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2532308'},
#  {'title': '그에게로 가는 나 나에게로 오는 그',
#   'creator': '박지애',
#   'publisher': '문학바탕',
#   'issuedYear': None,
#   'kdc': '811.6',
#   'ddc': '895.715',
#   'mainCategoryDescription': '한국문학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2533736'},
#  {'title': '러브',
#   'creator': '지오커뮤니케이션즈',
#   'publisher': '오늘',
#   'issuedYear': None,
#   'kdc': '181.71',
#   'ddc': '152.4',
#   'mainCategoryDescription': '심리학',
#   'alternative': '일곱 가지 아주 특별한 사랑',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2527435'},
#  {'title': '머리가 좋아지는 사소한 습관',
#   'creator': '간바 와타루',
#   'publisher': '스타북스',
#   'issuedYear': None,
#   'kdc': '181.4',
#   'ddc': '153.1',
#   'mainCategoryDescription': '심리학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '부드럽게 말하고 강력하게 행동하라',
#   'creator': '스트록, 제임스 M',
#   'publisher': '비즈앤북',
#   'issuedYear': None,
#   'kdc': '325.04',
#   'ddc': '650.1',
#   'mainCategoryDescription': '경제학',
#   'alternative': 'Theodore Roosevelt on leadership : executive lessons from the bully pulpit',
#   'keyword': '리더십[leadership]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1565326'},
#  {'title': '논술공부 99%는 잘못됐다',
#   'creator': '이상수',
#   'publisher': '황금부엉이',
#   'issuedYear': None,
#   'kdc': '802',
#   'ddc': '808',
#   'mainCategoryDescription': '문학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2529934'},
#  {'title': '노신의 문화사상과 외국문학',
#   'creator': '엄영욱',
#   'publisher': '전남대학교출판부',
#   'issuedYear': None,
#   'kdc': '820.907',
#   'ddc': '895.10951',
#   'mainCategoryDescription': '중국문학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '시간횡단',
#   'creator': '박길룡',
#   'publisher': '국민대학교 출판부',
#   'issuedYear': None,
#   'kdc': '610.9187',
#   'ddc': '720.9561',
#   'mainCategoryDescription': '건축술',
#   'alternative': 'Across time',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2924822'},
#  {'title': '선유암시',
#   'creator': '박종혁',
#   'publisher': '국민대학교 출판부',
#   'issuedYear': None,
#   'kdc': '811.9',
#   'ddc': '895.712',
#   'mainCategoryDescription': '한국문학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2537853'},
#  {'title': '상상놀이로 쑥쑥 크는 2세아',
#   'creator': '중앙청사어린이집',
#   'publisher': '정민사',
#   'issuedYear': None,
#   'kdc': '375.1',
#   'ddc': '372.21',
#   'mainCategoryDescription': '교육학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '반도체 물성 공학',
#   'creator': '이현용',
#   'publisher': '전남대학교출판부',
#   'issuedYear': None,
#   'kdc': '427.62',
#   'ddc': '537.622',
#   'mainCategoryDescription': '물리학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '당국사보',
#   'creator': '이상천',
#   'publisher': '학고방',
#   'issuedYear': None,
#   'kdc': '824.4',
#   'ddc': '895.144',
#   'mainCategoryDescription': '중국문학',
#   'alternative': '唐國史補',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2533678'},
#  {'title': '일제가 강점한「조선」',
#   'creator': '이민원',
#   'publisher': '한국영상문화사',
#   'issuedYear': None,
#   'kdc': '911.059',
#   'ddc': '951.902',
#   'mainCategoryDescription': '아시아(아세아)',
#   'alternative': '日本之朝鮮',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '꿈꾸는 달팽이',
#   'creator': '권오길',
#   'publisher': '지성사',
#   'issuedYear': None,
#   'kdc': '470.4',
#   'ddc': '570.2',
#   'mainCategoryDescription': '생명과학',
#   'alternative': '과학 속에서 삶의 진리 깨우치는 권오길 교수의 생물학 강의',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '양주 소놀이굿',
#   'creator': '김헌선',
#   'publisher': '월인',
#   'issuedYear': None,
#   'kdc': '388.2',
#   'ddc': '398.41',
#   'mainCategoryDescription': '풍속, 민속학',
#   'alternative': '무형문화재 원형보존을 위한 자료집',
#   'keyword': '제석굿',
#   'seeAlso': None},
#  {'title': '이 책을 먹으라',
#   'creator': '양혜원',
#   'publisher': '한국기독학생회출판부',
#   'issuedYear': None,
#   'kdc': '233.007',
#   'ddc': '220.071',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Eat this book : a conversation in the art of spiritual reading',
#   'keyword': '성경 공부[聖經工夫]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2522625'},
#  {'title': '주택·아파트·인테리어 풍수와의 만남',
#   'creator': '정판성',
#   'publisher': '태웅출판사',
#   'issuedYear': None,
#   'kdc': '188.4',
#   'ddc': '133.333',
#   'mainCategoryDescription': '심리학',
#   'alternative': '삶의 질을 업그레이드시키는 양택·생활 풍수의 모든 것',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2536123'},
#  {'title': '시가 여는 마음의 풍경',
#   'creator': '김천봉',
#   'publisher': '뿌리출판사',
#   'issuedYear': None,
#   'kdc': '809.1',
#   'ddc': '809.1',
#   'mainCategoryDescription': '문학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2535273'},
#  {'title': '중국의 문화변동과 현대문학',
#   'creator': '김상원',
#   'publisher': '학고방',
#   'issuedYear': None,
#   'kdc': '820.907',
#   'ddc': '895.109',
#   'mainCategoryDescription': '중국문학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2533679'},
#  {'title': '세상을 움직이는 힘',
#   'creator': '박동운',
#   'publisher': '三英社',
#   'issuedYear': None,
#   'kdc': '320.4',
#   'ddc': '330.02',
#   'mainCategoryDescription': '경제학',
#   'alternative': '시장경제와 사람 사는 이야기',
#   'keyword': '경제이야기',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2538973'},
#  {'title': '건축에게 시대를 묻다',
#   'creator': '민현식',
#   'publisher': '돌베개',
#   'issuedYear': None,
#   'kdc': '610.911',
#   'ddc': '720.9519',
#   'mainCategoryDescription': '건축술',
#   'alternative': '한국 현대건축 읽기',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2538858'},
#  {'title': '명성황후, 제국을 일으키다',
#   'creator': '한영우',
#   'publisher': '효형출판',
#   'issuedYear': None,
#   'kdc': '911.059',
#   'ddc': '951.902',
#   'mainCategoryDescription': '아시아(아세아)',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2539283'},
#  {'title': '사이와 사이에서',
#   'creator': '이재정',
#   'publisher': '다산글방',
#   'issuedYear': None,
#   'kdc': '041',
#   'ddc': '089.957',
#   'mainCategoryDescription': '강연집, 수필집, 연설문집',
#   'alternative': '이재정 산문집',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=71649'},
#  {'title': '치유와 선교',
#   'creator': None,
#   'publisher': '다산글방',
#   'issuedYear': None,
#   'kdc': '235.6',
#   'ddc': '266',
#   'mainCategoryDescription': '기독교',
#   'alternative': None,
#   'keyword': '선교(종교)[宣敎]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=71648'},
#  {'title': '새로운 시인을 기다리며',
#   'creator': '윤석산',
#   'publisher': '태학사',
#   'issuedYear': None,
#   'kdc': '802.1',
#   'ddc': '808.1',
#   'mainCategoryDescription': '문학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2535279'},
#  {'title': '백제의 신화와 제의',
#   'creator': '최광식',
#   'publisher': '주류성',
#   'issuedYear': None,
#   'kdc': '911.033',
#   'ddc': '951.901',
#   'mainCategoryDescription': '아시아(아세아)',
#   'alternative': None,
#   'keyword': '제사',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2532824'},
#  {'title': '백제토기 탐구',
#   'creator': '박순발',
#   'publisher': '주류성',
#   'issuedYear': None,
#   'kdc': '911.033',
#   'ddc': '951.901',
#   'mainCategoryDescription': '아시아(아세아)',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2532823'},
#  {'title': '이단연구',
#   'creator': '이대복',
#   'publisher': '큰샘출판',
#   'issuedYear': None,
#   'kdc': '238.99',
#   'ddc': '289.9',
#   'mainCategoryDescription': '기독교',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1913098'},
#  {'title': '당신에게로 가는 마음',
#   'creator': '변정현',
#   'publisher': '베스트셀러출판사',
#   'issuedYear': None,
#   'kdc': '811.6',
#   'ddc': '895.715',
#   'mainCategoryDescription': '한국문학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2535212'},
#  {'title': '고요에 기대어',
#   'creator': '김초혜',
#   'publisher': '문학동네',
#   'issuedYear': None,
#   'kdc': '811.6',
#   'ddc': '895.715',
#   'mainCategoryDescription': '한국문학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2536638'},
#  {'title': '커뮤니케이션 에세이',
#   'creator': '이영권',
#   'publisher': '아름다운사회',
#   'issuedYear': None,
#   'kdc': '325.04',
#   'ddc': '650.13',
#   'mainCategoryDescription': '경제학',
#   'alternative': 'Communication essay',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '한국현대소설과 주체의 호명',
#   'creator': '김정숙',
#   'publisher': '역락',
#   'issuedYear': None,
#   'kdc': '813.609',
#   'ddc': '895.734',
#   'mainCategoryDescription': '한국문학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '단백질의 일생',
#   'creator': '길전현우',
#   'publisher': '월드사이언스',
#   'issuedYear': None,
#   'kdc': '439.75',
#   'ddc': '547.75',
#   'mainCategoryDescription': '화학',
#   'alternative': '細胞におはる蛋白質の一生 : 生成, 成熟, 輸送, 管理, 分解, 病態',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '인간 생존 확률 50:50',
#   'creator': 'Rees, Martin',
#   'publisher': '소소',
#   'issuedYear': None,
#   'kdc': '331.54',
#   'ddc': '303.490905',
#   'mainCategoryDescription': '사회학, 사회문제',
#   'alternative': '인간은 21세기의 지뢰밭을 무사히 건너갈 수 있을까?',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '하나님의 심정',
#   'creator': 'Fénelon, François de Salignac de la Mothe',
#   'publisher': '순전한 나드',
#   'issuedYear': None,
#   'kdc': '234.3',
#   'ddc': '242',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Meditations on the heart God',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2486389'},
#  {'title': '여행생각',
#   'creator': '우남일',
#   'publisher': '계간문예',
#   'issuedYear': None,
#   'kdc': '818',
#   'ddc': '895.785',
#   'mainCategoryDescription': '한국문학',
#   'alternative': None,
#   'keyword': '스페인',
#   'seeAlso': None},
#  {'title': '난, 디카 사진으로 영화같은 애니메이션을 만든다!',
#   'creator': '황현숙',
#   'publisher': 'PCBOOK',
#   'issuedYear': None,
#   'kdc': '004.76',
#   'ddc': '006.6869',
#   'mainCategoryDescription': '총류',
#   'alternative': None,
#   'keyword': '포토샵',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1528122'},
#  {'title': '자본주의란 무엇인가?',
#   'creator': 'Jalée, Pierre',
#   'publisher': '책갈피',
#   'issuedYear': None,
#   'kdc': '320.17',
#   'ddc': '335.412',
#   'mainCategoryDescription': '경제학',
#   'alternative': 'How capitalism works',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2513177'},
#  {'title': '일과 인생의 균형감각',
#   'creator': '재등무태',
#   'publisher': '사과나무',
#   'issuedYear': None,
#   'kdc': '325.04',
#   'ddc': '650.1',
#   'mainCategoryDescription': '경제학',
#   'alternative': 'Work life balance',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '애니메이션 경제학 2004',
#   'creator': '한창완',
#   'publisher': '커뮤니케이션북스',
#   'issuedYear': None,
#   'kdc': '331.541',
#   'ddc': '302.23',
#   'mainCategoryDescription': '사회학, 사회문제',
#   'alternative': None,
#   'keyword': '애니메이션비즈니스',
#   'seeAlso': None},
#  {'title': '예이츠와 모드 곤',
#   'creator': 'Brady, Margery',
#   'publisher': '이화여자대학교출판부',
#   'issuedYear': None,
#   'kdc': '841.099',
#   'ddc': '821.092',
#   'mainCategoryDescription': '영미문학',
#   'alternative': 'Love story of W.B. Yeats and Maud Gonne',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2529165'},
#  {'title': '행복이 찾아오면 의자를 내주세요',
#   'creator': 'Pressler, Mirjam',
#   'publisher': '사계절',
#   'issuedYear': None,
#   'kdc': '853',
#   'ddc': '833.92',
#   'mainCategoryDescription': '독일문학',
#   'alternative': 'Wenn das Glück kommt, muss man ihm einen Stuhl hinstellen',
#   'keyword': '사계절',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2533464'},
#  {'title': '인생',
#   'creator': '그레이엄, 빌리',
#   'publisher': '청림출판',
#   'issuedYear': None,
#   'kdc': '234.8',
#   'ddc': '248.4',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Journey : living by faith in an uncertain world',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2533202'},
#  {'title': '동과 서는 어디서 만날까',
#   'creator': '서상록',
#   'publisher': '가톨릭출판사',
#   'issuedYear': None,
#   'kdc': '041',
#   'ddc': '089.957',
#   'mainCategoryDescription': '강연집, 수필집, 연설문집',
#   'alternative': '서양의 지식과 동양의 철학의 어우러짐',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '사무엘 루터포드',
#   'creator': '렌델, 킹슬리',
#   'publisher': '지평서원',
#   'issuedYear': None,
#   'kdc': '230.99',
#   'ddc': '230.092',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Samuel Rutherford : a new biography of the man & his ministry',
#   'keyword': '기독교인[基督敎人]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2539714'},
#  {'title': '십계명강해',
#   'creator': '홍정길',
#   'publisher': '크리스챤서적',
#   'issuedYear': None,
#   'kdc': '233.216',
#   'ddc': '222.16',
#   'mainCategoryDescription': '기독교',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '그리울수록 사랑이 그립습니다',
#   'creator': '탁용준',
#   'publisher': '예스북',
#   'issuedYear': None,
#   'kdc': '811.6',
#   'ddc': '895.715',
#   'mainCategoryDescription': '한국문학',
#   'alternative': '용혜원 시화선집',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '한국 근대성 연구의 길을 묻다',
#   'creator': '신동원',
#   'publisher': '돌베개',
#   'issuedYear': None,
#   'kdc': '911.06',
#   'ddc': '951.903',
#   'mainCategoryDescription': '아시아(아세아)',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2530072'},
#  {'title': '일본 탐구',
#   'creator': '오태헌',
#   'publisher': '석필',
#   'issuedYear': None,
#   'kdc': '913',
#   'ddc': '952',
#   'mainCategoryDescription': '아시아(아세아)',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '구름위의 돌베개',
#   'creator': '이철건',
#   'publisher': '창조문예사',
#   'issuedYear': None,
#   'kdc': '811.6',
#   'ddc': '895.715',
#   'mainCategoryDescription': '한국문학',
#   'alternative': None,
#   'keyword': '한국 현대시[韓國現代詩]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2536173'},
#  {'title': '고난의 의미를 찾아서',
#   'creator': '신성종',
#   'publisher': '크리스챤서적',
#   'issuedYear': None,
#   'kdc': '234.81',
#   'ddc': '248.4',
#   'mainCategoryDescription': '기독교',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2537980'},
#  {'title': '교육은 자기교육이다',
#   'creator': '조희조',
#   'publisher': '쿰란출판사',
#   'issuedYear': None,
#   'kdc': '235.7',
#   'ddc': '268',
#   'mainCategoryDescription': '기독교',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2538606'},
#  {'title': '전도 특공대 만들기',
#   'creator': '현영일',
#   'publisher': '쿰란출판사',
#   'issuedYear': None,
#   'kdc': '235.4',
#   'ddc': '266',
#   'mainCategoryDescription': '기독교',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2526218'},
#  {'title': '이승에서 영원을 사는 섬들 남해의 섬들',
#   'creator': '박희진',
#   'publisher': '시와 진실',
#   'issuedYear': None,
#   'kdc': '811.6',
#   'ddc': '895.715',
#   'mainCategoryDescription': '한국문학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2539383'},
#  {'title': '섬들은 외롭지 않다 동해와 서해의 섬들',
#   'creator': '박희진',
#   'publisher': '시와 진실',
#   'issuedYear': None,
#   'kdc': '811.6',
#   'ddc': '895.715',
#   'mainCategoryDescription': '한국문학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2539776'},
#  {'title': '무영검',
#   'creator': '김태관',
#   'publisher': '집사재',
#   'issuedYear': None,
#   'kdc': '813.6',
#   'ddc': '895.735',
#   'mainCategoryDescription': '한국문학',
#   'alternative': '김태관 장편소설',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '조선통신사와 치요조의 하이쿠',
#   'creator': '손순옥',
#   'publisher': '한누리미디어',
#   'issuedYear': None,
#   'kdc': '831.09',
#   'ddc': '895.613',
#   'mainCategoryDescription': '일본문학',
#   'alternative': '朝鮮通信使と千代女の俳句',
#   'keyword': '천대녀',
#   'seeAlso': None},
#  {'title': '하늘·땅·사람',
#   'creator': '박희진',
#   'publisher': '秀文出版社',
#   'issuedYear': None,
#   'kdc': '811.6',
#   'ddc': '895.715',
#   'mainCategoryDescription': '한국문학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=32708'},
#  {'title': '역사란 무엇인가',
#   'creator': '박성수',
#   'publisher': '민지사',
#   'issuedYear': None,
#   'kdc': '901',
#   'ddc': '901',
#   'mainCategoryDescription': '역사',
#   'alternative': 'What is history?',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1910288'},
#  {'title': '산업조직경제학 입문',
#   'creator': '박종수',
#   'publisher': '경상대학교 출판부',
#   'issuedYear': None,
#   'kdc': '320',
#   'ddc': '330',
#   'mainCategoryDescription': '경제학',
#   'alternative': 'Economics of industrial organization',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1903137'},
#  {'title': '매스미디어와 정보사회',
#   'creator': '류춘렬',
#   'publisher': '커뮤니케이션북스',
#   'issuedYear': None,
#   'kdc': '331.541',
#   'ddc': '302.23',
#   'mainCategoryDescription': '사회학, 사회문제',
#   'alternative': 'Mass media and information society',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1467375'},
#  {'title': '나만의 성취지도를 가져라',
#   'creator': '김경모',
#   'publisher': '아이디북',
#   'issuedYear': None,
#   'kdc': '325.04',
#   'ddc': '650.1',
#   'mainCategoryDescription': '경제학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '뿌리깊은 지명이야기',
#   'creator': '위정훈',
#   'publisher': '파피에',
#   'issuedYear': None,
#   'kdc': '920',
#   'ddc': '940',
#   'mainCategoryDescription': '유럽(구라파)',
#   'alternative': '신화와 전설, 역사가 새긴 지명으로 읽는 유럽 문화사',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2511158'},
#  {'title': '비주얼베이직',
#   'creator': '김희철',
#   'publisher': '오성미디어',
#   'issuedYear': None,
#   'kdc': '005.26',
#   'ddc': '005.268',
#   'mainCategoryDescription': '총류',
#   'alternative': 'Visual basic',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '사월일기',
#   'creator': '김동식',
#   'publisher': '다지리',
#   'issuedYear': None,
#   'kdc': '811.6',
#   'ddc': '895.715',
#   'mainCategoryDescription': '한국문학',
#   'alternative': '김동식 시집',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2616556'},
#  {'title': '한국전통문화론',
#   'creator': '김기덕',
#   'publisher': '북코리아',
#   'issuedYear': None,
#   'kdc': '380.911',
#   'ddc': '390.09519',
#   'mainCategoryDescription': '풍속, 민속학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '주님과 거닐다',
#   'creator': '양혜원',
#   'publisher': '한국기독학생회출판부',
#   'issuedYear': None,
#   'kdc': '234.8',
#   'ddc': '248.4',
#   'mainCategoryDescription': '기독교',
#   'alternative': '하나님과 참된 사귐을 나누는 영성 훈련',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '아이속의 화가는 기다림 속에서 자란다',
#   'creator': '홍승윤',
#   'publisher': '아이북',
#   'issuedYear': None,
#   'kdc': '650.7',
#   'ddc': '750.7',
#   'mainCategoryDescription': '회화, 도화',
#   'alternative': '아트디렉터 홍동원의 그림교육 이야기',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '셰익스피어 비극의 재발견',
#   'creator': '최경란',
#   'publisher': '단국대학교출판부',
#   'issuedYear': None,
#   'kdc': '842.09',
#   'ddc': '822.33',
#   'mainCategoryDescription': '영미문학',
#   'alternative': '타이터스 앤드로니커스',
#   'keyword': '세익스피어',
#   'seeAlso': None},
#  {'title': '내 안의 사막, 고비를 건너다',
#   'creator': 'Messner, Reinhold',
#   'publisher': '황금나침반',
#   'issuedYear': None,
#   'kdc': '856',
#   'ddc': '838.92',
#   'mainCategoryDescription': '독일문학',
#   'alternative': 'Gobi',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2610752'},
#  {'title': '성령의 권능은 믿음으로 역사합니다',
#   'creator': '듀엘, 데이브',
#   'publisher': 'Grace 은혜출판사',
#   'issuedYear': None,
#   'kdc': '235.3',
#   'ddc': '253',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Faith : believe it...or not',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '니치 마켓 리치 비즈니스',
#   'creator': '샌더, 제니퍼 베이시',
#   'publisher': '비비컴',
#   'issuedYear': None,
#   'kdc': '325.1',
#   'ddc': '658.11',
#   'mainCategoryDescription': '경제학',
#   'alternative': 'Niche and grow rich : practical ways to turn your ideas into a business',
#   'keyword': '창업[創業]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2417422'},
#  {'title': '나는 서울이 맛있다',
#   'creator': '강지영',
#   'publisher': '베스트홈',
#   'issuedYear': None,
#   'kdc': '594.019',
#   'ddc': '641.013',
#   'mainCategoryDescription': '가정학 및 가정생활',
#   'alternative': '서울 생활 10년, Andy와 Jinny의 깐깐한 맛집 탐험기',
#   'keyword': '맛집',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=108027'},
#  {'title': '진영과 찬문',
#   'creator': '신대현',
#   'publisher': '혜안',
#   'issuedYear': None,
#   'kdc': '220',
#   'ddc': '755.943',
#   'mainCategoryDescription': '불교',
#   'alternative': 'Portraits of buddhist monks and eulogies of the portraits : the world of untrue truth : Korean buddhist culture seen through the portraits of buddhist monks',
#   'keyword': '초상화',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2619048'},
#  {'title': '키움과 나눔을 넘어서',
#   'creator': '정덕구',
#   'publisher': '북이십일',
#   'issuedYear': None,
#   'kdc': '320.911',
#   'ddc': '330.9519',
#   'mainCategoryDescription': '경제학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2611584'},
#  {'title': '최초의 세계 제국, 미국',
#   'creator': 'Gervais, Pierre',
#   'publisher': '부키',
#   'issuedYear': None,
#   'kdc': '942',
#   'ddc': '973',
#   'mainCategoryDescription': '북아메리카(북미)',
#   'alternative': "L'avènement d' une superpuissance : le siècle de l'Amérique",
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2629336'},
#  {'title': '대화기술',
#   'creator': '서은미',
#   'publisher': '청림출판',
#   'issuedYear': None,
#   'kdc': '802.54',
#   'ddc': '808.56',
#   'mainCategoryDescription': '문학',
#   'alternative': 'Etwas gelassenere Art, sich durchzusetzen',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '설득기술',
#   'creator': '복전건',
#   'publisher': '청림출판',
#   'issuedYear': None,
#   'kdc': '802.5',
#   'ddc': '808.5',
#   'mainCategoryDescription': '문학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2671458'},
#  {'title': '시대의 증언자 쁘리모 레비를 찾아서',
#   'creator': '박광현',
#   'publisher': '창비',
#   'issuedYear': None,
#   'kdc': '880.9',
#   'ddc': '850.9',
#   'mainCategoryDescription': '이탈리아문학',
#   'alternative': 'プリーモ·レーヴイヘの旅',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2615128'},
#  {'title': '심정에 날개를 달고',
#   'creator': '신두호',
#   'publisher': '미래문화사',
#   'issuedYear': None,
#   'kdc': '811.6',
#   'ddc': '895.714',
#   'mainCategoryDescription': '한국문학',
#   'alternative': '신두호의 세계 선교 간증 제2시집',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '문화기술지에 대한 언어적 고찰',
#   'creator': '애거, 마이클 H',
#   'publisher': '군자출판사',
#   'issuedYear': None,
#   'kdc': '389',
#   'ddc': '306',
#   'mainCategoryDescription': '풍속, 민속학',
#   'alternative': 'Speaking of ethnography',
#   'keyword': '질적 연구[質的硏究]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2687433'},
#  {'title': '불안의 심리학',
#   'creator': '휘터, 게랄트',
#   'publisher': '궁리출판',
#   'issuedYear': None,
#   'kdc': '181.71',
#   'ddc': '152.46',
#   'mainCategoryDescription': '심리학',
#   'alternative': 'Biologie der Angst : Wie aus Streß Gefühle werden',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '이구아나',
#   'creator': '김태수',
#   'publisher': '연극과인간',
#   'issuedYear': None,
#   'kdc': '812.6',
#   'ddc': '895.725',
#   'mainCategoryDescription': '한국문학',
#   'alternative': '효녀무사 바리',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2612757'},
#  {'title': '내 노래는 아무도 모를 거예요',
#   'creator': '윤연모',
#   'publisher': '신아출판사',
#   'issuedYear': None,
#   'kdc': '814.6',
#   'ddc': '895.745',
#   'mainCategoryDescription': '한국문학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2528184'},
#  {'title': '나 당신에게 할 말이 있습니다',
#   'creator': '김금숙',
#   'publisher': '시선사',
#   'issuedYear': None,
#   'kdc': '811.6',
#   'ddc': '895.715',
#   'mainCategoryDescription': '한국문학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3076300'},
#  {'title': '일제하 만경강 유역의 사회사',
#   'creator': '이준식',
#   'publisher': '혜안',
#   'issuedYear': None,
#   'kdc': '911.06',
#   'ddc': '951.903',
#   'mainCategoryDescription': '아시아(아세아)',
#   'alternative': 'Social history of the Mangyeong river valley in colonial Korea : irrigation, landlords, and local politics',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2628644'},
#  {'title': '컴퓨터와 정보기술',
#   'creator': '황준하',
#   'publisher': 'Infinity books',
#   'issuedYear': None,
#   'kdc': '004',
#   'ddc': '004',
#   'mainCategoryDescription': '총류',
#   'alternative': 'Computers & information technology',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2959377'},
#  {'title': '시 속의 그림, 그림 속의 시',
#   'creator': '김현권',
#   'publisher': '보림출판사',
#   'issuedYear': None,
#   'kdc': '654.4',
#   'ddc': '758.1',
#   'mainCategoryDescription': '회화, 도화',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=4898675'},
#  {'title': '과학기술과 법',
#   'creator': '정상기',
#   'publisher': '한남대학교출판부',
#   'issuedYear': None,
#   'kdc': '502.3',
#   'ddc': '602.6',
#   'mainCategoryDescription': '기술과학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '예술가들이 주조한 근대와 현대',
#   'creator': 'Simmel, Georg',
#   'publisher': '길',
#   'issuedYear': None,
#   'kdc': '600.1',
#   'ddc': '700.1',
#   'mainCategoryDescription': '예술',
#   'alternative': 'Rodins Plasrik und die Geistesrichtung der Gegenwart',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '운영체제',
#   'creator': '박종선',
#   'publisher': '기한재',
#   'issuedYear': None,
#   'kdc': '005.43',
#   'ddc': '005.43',
#   'mainCategoryDescription': '총류',
#   'alternative': 'Operating system',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3018200'},
#  {'title': '미용실 경영학',
#   'creator': '이한웅',
#   'publisher': '대한미용사회중앙회',
#   'issuedYear': None,
#   'kdc': '593.2',
#   'ddc': '646.72',
#   'mainCategoryDescription': '가정학 및 가정생활',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '이상과 열정, 조선역사',
#   'creator': '이범직',
#   'publisher': '쿠북',
#   'issuedYear': None,
#   'kdc': '911.05',
#   'ddc': '951.902',
#   'mainCategoryDescription': '아시아(아세아)',
#   'alternative': 'Idea and passion, history of the Chosun dynasty',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3041314'},
#  {'title': '행복오네',
#   'creator': '권태진',
#   'publisher': '성빛',
#   'issuedYear': None,
#   'kdc': '234.8',
#   'ddc': '248.4',
#   'mainCategoryDescription': '기독교',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3105196'},
#  {'title': '책 만들며 크는 아이',
#   'creator': '김정연',
#   'publisher': '즐거운상상',
#   'issuedYear': None,
#   'kdc': '012.47',
#   'ddc': '741.64',
#   'mainCategoryDescription': '도서관, 서지학',
#   'alternative': '재미난 엄마의 소문난 육아 노하우',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '능력의 영을 받는 법',
#   'creator': 'Johnson, Bill',
#   'publisher': '규장',
#   'issuedYear': None,
#   'kdc': '234.8',
#   'ddc': '248.4',
#   'mainCategoryDescription': '기독교',
#   'alternative': '하늘을 끌어당기는 믿음의 힘',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3027299'},
#  {'title': '전란의 소용돌이 속에서',
#   'creator': '권칙',
#   'publisher': '돌베개',
#   'issuedYear': None,
#   'kdc': '813.5',
#   'ddc': '895.732',
#   'mainCategoryDescription': '한국문학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '행복한 부자로 만드는 황금열쇠',
#   'creator': '김진혁',
#   'publisher': '리더스하이',
#   'issuedYear': None,
#   'kdc': '327.04',
#   'ddc': '332.024',
#   'mainCategoryDescription': '경제학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '독도는 알고있다',
#   'creator': '최진규',
#   'publisher': '데일리줌신문사',
#   'issuedYear': None,
#   'kdc': '911.829',
#   'ddc': '951.9',
#   'mainCategoryDescription': '아시아(아세아)',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2121462'},
#  {'title': '소를 때려야 하는가 수레를 때려야 하는가',
#   'creator': '무비',
#   'publisher': '불광출판사',
#   'issuedYear': None,
#   'kdc': '224.2',
#   'ddc': '294.34',
#   'mainCategoryDescription': '불교',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3122561'},
#  {'title': '중국문물전',
#   'creator': None,
#   'publisher': '亞州文物學會',
#   'issuedYear': None,
#   'kdc': '606.3',
#   'ddc': '709.51',
#   'mainCategoryDescription': '예술',
#   'alternative': 'Chinese civilization',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '카피 커피 구피',
#   'creator': '맹명관',
#   'publisher': '가이드포스트',
#   'issuedYear': None,
#   'kdc': '230.4',
#   'ddc': '230.002',
#   'mainCategoryDescription': '기독교',
#   'alternative': '마흔 아홉해 살아온 삶의 흔적들',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=6315959'},
#  {'title': '십계명',
#   'creator': 'Willimon, William H',
#   'publisher': '복있는 사람',
#   'issuedYear': None,
#   'kdc': '233.216',
#   'ddc': '222.16',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Truth about God',
#   'keyword': '십계명[十誡命]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3291497'},
#  {'title': '진실한 여정',
#   'creator': 'Kieschnick, Gerald B',
#   'publisher': '한국루터란아워',
#   'issuedYear': None,
#   'kdc': '234.3',
#   'ddc': '242',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Reality journey : advent to ephiphany',
#   'keyword': '묵상집[默想集]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=136680'},
#  {'title': '갈등과 공존',
#   'creator': '최문형',
#   'publisher': '경인문화사',
#   'issuedYear': None,
#   'kdc': '331.1',
#   'ddc': '303.372',
#   'mainCategoryDescription': '사회학, 사회문제',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3082631'},
#  {'title': '고난 당한 것이 내게 유익이라',
#   'creator': '이안재',
#   'publisher': '쿰란출판사',
#   'issuedYear': None,
#   'kdc': '234.82',
#   'ddc': '248.2',
#   'mainCategoryDescription': '기독교',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '백세까지 걷자',
#   'creator': '다나카 나오키',
#   'publisher': '루비박스',
#   'issuedYear': None,
#   'kdc': '593.5',
#   'ddc': '646.75',
#   'mainCategoryDescription': '가정학 및 가정생활',
#   'alternative': '30대부터 준비하는 평생 걷기 운동법',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '요시노가리',
#   'creator': None,
#   'publisher': '그라픽네트',
#   'issuedYear': None,
#   'kdc': '606.3',
#   'ddc': '707.4',
#   'mainCategoryDescription': '예술',
#   'alternative': '일본 속의 고대 한국',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3697062'},
#  {'title': '하서 김인후와 필암서원',
#   'creator': None,
#   'publisher': '그라픽네트',
#   'issuedYear': None,
#   'kdc': '606.3',
#   'ddc': '707.4',
#   'mainCategoryDescription': '예술',
#   'alternative': 'Ha seo the hermit comes into the light',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '크투빔',
#   'creator': '김영진',
#   'publisher': '한들출판사',
#   'issuedYear': None,
#   'kdc': '233.1',
#   'ddc': '221',
#   'mainCategoryDescription': '기독교',
#   'alternative': '성문서 연구',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '호라이즌 채플 이야기',
#   'creator': '위트, 셔우트 엘리어트',
#   'publisher': '지혜문학',
#   'issuedYear': None,
#   'kdc': '230.99',
#   'ddc': '230.092',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Horizon Chapel story',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '그렇게 말을 걸어올 때까지',
#   'creator': '하삼두',
#   'publisher': '은영',
#   'issuedYear': None,
#   'kdc': '234.3',
#   'ddc': '895.785',
#   'mainCategoryDescription': '기독교',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=4305827'},
#  {'title': '실험예술, 어떻게 볼 것인가',
#   'creator': 'KoPAS',
#   'publisher': '한국실험예술정신',
#   'issuedYear': None,
#   'kdc': '600.13',
#   'ddc': '700.103',
#   'mainCategoryDescription': '예술',
#   'alternative': '2006 한국실험예술제',
#   'keyword': '실험예술',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2926693'},
#  {'title': '야고보서',
#   'creator': None,
#   'publisher': '프리셉트',
#   'issuedYear': None,
#   'kdc': '235.74',
#   'ddc': '227.91',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'James : precept upon precept',
#   'keyword': '야고보서[--書]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3696734'},
#  {'title': '디도·빌레몬·유다서',
#   'creator': None,
#   'publisher': '프리셉트',
#   'issuedYear': None,
#   'kdc': '235.74',
#   'ddc': '227',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Titus·Philemon·Jude',
#   'keyword': '기독교 교육 교재[基督敎敎育敎材]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2957072'},
#  {'title': '성공의 삶을 디자인하라!',
#   'creator': 'Hirsch, Peter',
#   'publisher': '프리셉트',
#   'issuedYear': None,
#   'kdc': '234.8',
#   'ddc': '248.4',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Success by design',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2898086'},
#  {'title': '진랍풍토기',
#   'creator': '저우다관',
#   'publisher': '백산자료원',
#   'issuedYear': None,
#   'kdc': '914.3',
#   'ddc': '959.603',
#   'mainCategoryDescription': '아시아(아세아)',
#   'alternative': '眞臘風土記',
#   'keyword': '캄보디아(국명)[Cambodia]',
#   'seeAlso': None},
#  {'title': '강 건너 봄이 오듯',
#   'creator': '송길자',
#   'publisher': '시문학사',
#   'issuedYear': None,
#   'kdc': '811.36',
#   'ddc': '895.714',
#   'mainCategoryDescription': '한국문학',
#   'alternative': None,
#   'keyword': '현대시조',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3311949'},
#  {'title': '여성 멘토링의 영적 비밀',
#   'creator': '이지혜',
#   'publisher': '사랑플러스',
#   'issuedYear': None,
#   'kdc': '234.8',
#   'ddc': '248.843',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Divine secrets of mentoring : spiritual growth through friendship',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2926548'},
#  {'title': '새 생명을 위하여',
#   'creator': '이동원',
#   'publisher': '에이스',
#   'issuedYear': None,
#   'kdc': '235.74',
#   'ddc': '268.4',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'For new life',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=4305763'},
#  {'title': '보령 경주김씨 기탁전적',
#   'creator': None,
#   'publisher': '한국학중앙연구원',
#   'issuedYear': None,
#   'kdc': '911.0091',
#   'ddc': '951.9002',
#   'mainCategoryDescription': '아시아(아세아)',
#   'alternative': '保寧 慶州金氏 寄託典籍',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=4305770'},
#  {'title': '다시 만날 때 까지',
#   'creator': '시바사키 토모카',
#   'publisher': '랜덤하우스코리아',
#   'issuedYear': None,
#   'kdc': '833.6',
#   'ddc': '895.636',
#   'mainCategoryDescription': '일본문학',
#   'alternative': 'また會う日まで',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3309476'},
#  {'title': '아름다운 성숙',
#   'creator': '안병만',
#   'publisher': '프리칭아카데미',
#   'issuedYear': None,
#   'kdc': '235.74',
#   'ddc': '268.4',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Bible study for maturity',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2521130'},
#  {'title': '풍경과 마음',
#   'creator': '김우창',
#   'publisher': '생각의나무',
#   'issuedYear': None,
#   'kdc': '650.4',
#   'ddc': '750.2',
#   'mainCategoryDescription': '회화, 도화',
# ...
#  {'title': '유대식 사고방식',
#   'creator': '이하연',
#   'publisher': '한글',
#   'issuedYear': None,
#   'kdc': '182.67974',
#   'ddc': '155.895694',
#   'mainCategoryDescription': '심리학',
#   'alternative': None,
#   'keyword': '사고방식',
#   'seeAlso': None},
#  {'title': '유대인과 일본인',
#   'creator': '최한구',
#   'publisher': '한글',
#   'issuedYear': None,
#   'kdc': '182.67',
#   'ddc': '155.89',
#   'mainCategoryDescription': '심리학',
#   'alternative': None,
#   'keyword': '유대인',
#   'seeAlso': None},
#  {'title': '순발력 화술',
#   'creator': 'Poehm, Matthias',
#   'publisher': '글담',
#   'issuedYear': None,
#   'kdc': '802.5',
#   'ddc': '808.5',
#   'mainCategoryDescription': '문학',
#   'alternative': 'Vergessen Sie alles ¨uber Rhetorik',
#   'keyword': '순발력화술',
#   'seeAlso': None},
#  {'title': '영적 침체에서 벗어나는 길',
#   'creator': 'Beeke, Joel R',
#   'publisher': '부흥과개혁사',
#   'issuedYear': None,
#   'kdc': '234.8',
#   'ddc': '248.4',
#   'mainCategoryDescription': '기독교',
#   'alternative': '영적 침체라는 무서운 질병에 대한 하나님의 치유',
#   'keyword': '영성 생활[靈性生活]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=158497'},
#  {'title': '내 한쪽 가슴의 꽃밭',
#   'creator': '이정연',
#   'publisher': '창조문예사',
#   'issuedYear': None,
#   'kdc': '814.6',
#   'ddc': '895.745',
#   'mainCategoryDescription': '한국문학',
#   'alternative': None,
#   'keyword': '한국수필',
#   'seeAlso': None},
#  {'title': '비즈니스 글쓰기의 기술',
#   'creator': '김익수',
#   'publisher': '하이파이브',
#   'issuedYear': None,
#   'kdc': '325.484',
#   'ddc': '651.74',
#   'mainCategoryDescription': '경제학',
#   'alternative': 'Biz writing',
#   'keyword': '문서작성',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1453365'},
#  {'title': '사랑받는 여자의 조금 다른 습관',
#   'creator': '가모시타 이치로',
#   'publisher': '청어람',
#   'issuedYear': None,
#   'kdc': '337.04',
#   'ddc': '305.4',
#   'mainCategoryDescription': '사회학, 사회문제',
#   'alternative': None,
#   'keyword': '여성',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=156023'},
#  {'title': '나 자신을 뒤집어라',
#   'creator': '장석주',
#   'publisher': '청어람',
#   'issuedYear': None,
#   'kdc': '199.1',
#   'ddc': '179.7',
#   'mainCategoryDescription': '윤리학, 도덕철학',
#   'alternative': '다장르 작가 4인의 인생 역전 지침서',
#   'keyword': '다장르',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=158263'},
#  {'title': '너희가 카투사를 아느냐',
#   'creator': '이우일',
#   'publisher': '리수',
#   'issuedYear': None,
#   'kdc': '390.4',
#   'ddc': '355.002',
#   'mainCategoryDescription': '국방, 군사학',
#   'alternative': None,
#   'keyword': '이방인',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=130396'},
#  {'title': '덕분에',
#   'creator': '아이다 미쓰오',
#   'publisher': '리수',
#   'issuedYear': None,
#   'kdc': '838',
#   'ddc': '895.686',
#   'mainCategoryDescription': '일본문학',
#   'alternative': '비틀거리고 넘어지고 한 덕분에 조금씩이나마 나 자신을 알게 되었습니다',
#   'keyword': '덕분에',
#   'seeAlso': None},
#  {'title': '헨리 제임스 단편집',
#   'creator': 'James, Henry',
#   'publisher': '우리책',
#   'issuedYear': None,
#   'kdc': '843',
#   'ddc': '813.4',
#   'mainCategoryDescription': '영미문학',
#   'alternative': '브룩스미스',
#   'keyword': '사자들',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=152710'},
#  {'title': '인재구축과 지식경영',
#   'creator': '권상술',
#   'publisher': '한언',
#   'issuedYear': None,
#   'kdc': '325.3',
#   'ddc': '658.3',
#   'mainCategoryDescription': '경제학',
#   'alternative': 'Human resource mangement in the knowledge economy : new challenges, new roles, nes capabilities',
#   'keyword': 'CHALLENGE',
#   'seeAlso': None},
#  {'title': '러시아를 알면 세계가 보인다',
#   'creator': '장연수',
#   'publisher': '바보새',
#   'issuedYear': None,
#   'kdc': '309.129',
#   'ddc': '947.0853',
#   'mainCategoryDescription': '사회과학',
#   'alternative': None,
#   'keyword': '러시아',
#   'seeAlso': None},
#  {'title': '자본을 넘어선 자본',
#   'creator': '이진경',
#   'publisher': '그린비',
#   'issuedYear': None,
#   'kdc': '320.17',
#   'ddc': '335.4',
#   'mainCategoryDescription': '경제학',
#   'alternative': None,
#   'keyword': '자본',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=148713'},
#  {'title': '새로운 나여, 안녕',
#   'creator': 'Walker, Alice',
#   'publisher': '마음산책',
#   'issuedYear': None,
#   'kdc': '843',
#   'ddc': '813.6',
#   'mainCategoryDescription': '영미문학',
#   'alternative': 'Now is the time to open your heart',
#   'keyword': 'TIME',
#   'seeAlso': None},
#  {'title': '동제의 상징과 의미전달체계',
#   'creator': '이기태',
#   'publisher': '민속원',
#   'issuedYear': None,
#   'kdc': '388.2',
#   'ddc': '398.41',
#   'mainCategoryDescription': '풍속, 민속학',
#   'alternative': None,
#   'keyword': '제의',
#   'seeAlso': None},
#  {'title': '민속과 정치',
#   'creator': None,
#   'publisher': '民俗苑',
#   'issuedYear': None,
#   'kdc': '380.911',
#   'ddc': '390.09519',
#   'mainCategoryDescription': '풍속, 민속학',
#   'alternative': None,
#   'keyword': '가면극',
#   'seeAlso': None},
#  {'title': '서울 진오기굿',
#   'creator': '홍태한',
#   'publisher': '민속원',
#   'issuedYear': None,
#   'kdc': '388.2',
#   'ddc': '398.41',
#   'mainCategoryDescription': '풍속, 민속학',
#   'alternative': None,
#   'keyword': '묵은진오기굿',
#   'seeAlso': None},
#  {'title': '제가문서의 수집과 정리',
#   'creator': '기옥현',
#   'publisher': '한울',
#   'issuedYear': None,
#   'kdc': '026.99',
#   'ddc': '027.552',
#   'mainCategoryDescription': '문헌정보학',
#   'alternative': '地域文書館の設立に向けて : 諸家文書の收集と整理',
#   'keyword': '행정문서',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1459496'},
#  {'title': '건축의 향성과 흐름',
#   'creator': '김원갑',
#   'publisher': '시공문화사',
#   'issuedYear': None,
#   'kdc': '610.1',
#   'ddc': '720.1',
#   'mainCategoryDescription': '건축술',
#   'alternative': 'Tropisms : metaphoric animation and architecture',
#   'keyword': 'METAPHORIC',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1516932'},
#  {'title': '가난하다고 실망하는 아이는 없다',
#   'creator': '신규진',
#   'publisher': '푸른나무',
#   'issuedYear': None,
#   'kdc': '378.9',
#   'ddc': '649',
#   'mainCategoryDescription': '교육학',
#   'alternative': '자녀들이 부모에게 실망하는 7가지 이유',
#   'keyword': '부모교육',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1477574'},
#  {'title': '돈과 명예를 한꺼번에 잡는 관상학',
#   'creator': '유화정',
#   'publisher': '예가',
#   'issuedYear': None,
#   'kdc': '188.1',
#   'ddc': '138',
#   'mainCategoryDescription': '심리학',
#   'alternative': '관상학은 역술가의 전용물이 아니다',
#   'keyword': '얼굴',
#   'seeAlso': None},
#  {'title': '낯선 외출',
#   'creator': '문복선',
#   'publisher': '푸른사상사',
#   'issuedYear': None,
#   'kdc': '811.36',
#   'ddc': '895.715',
#   'mainCategoryDescription': '한국문학',
#   'alternative': None,
#   'keyword': '외출',
#   'seeAlso': None},
#  {'title': '초등학교 교사',
#   'creator': None,
#   'publisher': '양서원',
#   'issuedYear': None,
#   'kdc': '371.31',
#   'ddc': '371.1',
#   'mainCategoryDescription': '교육학',
#   'alternative': None,
#   'keyword': '여교사',
#   'seeAlso': None},
#  {'title': '질적 연구',
#   'creator': '이효선',
#   'publisher': '학현사',
#   'issuedYear': None,
#   'kdc': '307.3',
#   'ddc': '300.72',
#   'mainCategoryDescription': '사회과학',
#   'alternative': 'Qualitative research : interpretation and understanding',
#   'keyword': '사회과학연구방법',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1530531'},
#  {'title': '소프트웨어로 승부하자',
#   'creator': '험프리, 와츠 S',
#   'publisher': '學現社',
#   'issuedYear': None,
#   'kdc': '005.1',
#   'ddc': '005.1',
#   'mainCategoryDescription': '총류',
#   'alternative': 'Winning with software : an executive strategy',
#   'keyword': '소프트웨어비즈니스',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1354233'},
#  {'title': '놀이와 유아발달',
#   'creator': '최석란',
#   'publisher': '양서원',
#   'issuedYear': None,
#   'kdc': '375.1',
#   'ddc': '372.21',
#   'mainCategoryDescription': '교육학',
#   'alternative': None,
#   'keyword': '영아발달',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1533091'},
#  {'title': '선생님 바탕 칠해요?',
#   'creator': '김충식',
#   'publisher': '양서원',
#   'issuedYear': None,
#   'kdc': '375.465',
#   'ddc': '372.5',
#   'mainCategoryDescription': '교육학',
#   'alternative': None,
#   'keyword': '감상',
#   'seeAlso': None},
#  {'title': '사회복지사를 위한 통계',
#   'creator': '그린넬, 리차드 M',
#   'publisher': '양서원',
#   'issuedYear': None,
#   'kdc': '338.1',
#   'ddc': '519.5',
#   'mainCategoryDescription': '사회학, 사회문제',
#   'alternative': 'Statistics for social workers',
#   'keyword': '사회복지조사방법',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1500497'},
#  {'title': '초급재무회계',
#   'creator': '윤석곤',
#   'publisher': '학현사',
#   'issuedYear': None,
#   'kdc': '325.93',
#   'ddc': '657.48',
#   'mainCategoryDescription': '경제학',
#   'alternative': 'Financial accounting',
#   'keyword': '당좌자산',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1518323'},
#  {'title': '열린 통상대국',
#   'creator': '안세영',
#   'publisher': '나남출판',
#   'issuedYear': None,
#   'kdc': '326.21',
#   'ddc': '382.3',
#   'mainCategoryDescription': '경제학',
#   'alternative': 'Open and globalizing economy',
#   'keyword': '한국경제',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=204257'},
#  {'title': '한국 경제의 인프라와 산업별 경쟁력',
#   'creator': '이근',
#   'publisher': '나남출판',
#   'issuedYear': None,
#   'kdc': '322.11',
#   'ddc': '338.9519',
#   'mainCategoryDescription': '경제학',
#   'alternative': '(The)infrastructure and industrial competitiveness in the Korean economy',
#   'keyword': '한국경제',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=204257'},
#  {'title': '이혼가정 자녀를 위한 심리치료',
#   'creator': '석말숙',
#   'publisher': '양서원',
#   'issuedYear': None,
#   'kdc': '186.5',
#   'ddc': '618.928914',
#   'mainCategoryDescription': '심리학',
#   'alternative': 'Psychotherapy with children of divorce',
#   'keyword': '아동(어린이)[兒童]',
#   'seeAlso': None},
#  {'title': '당신이 솔로일 수밖에 없는 생물학적 이유',
#   'creator': '장속천진이자',
#   'publisher': '뿌리와이파리',
#   'issuedYear': None,
#   'kdc': '491.36',
#   'ddc': '591.562',
#   'mainCategoryDescription': '동물학',
#   'alternative': '雄と雌の數をめぐる不思議',
#   'keyword': '수컷',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=148717'},
#  {'title': '술 보약인가 독약인가',
#   'creator': '인성경',
#   'publisher': '엘맨출판사',
#   'issuedYear': None,
#   'kdc': '573.1',
#   'ddc': '663.1',
#   'mainCategoryDescription': '화학공학',
#   'alternative': None,
#   'keyword': '보약',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1267251'},
#  {'title': '언어와 논리',
#   'creator': '이윤복',
#   'publisher': '정림사',
#   'issuedYear': None,
#   'kdc': '170',
#   'ddc': '160',
#   'mainCategoryDescription': '논리학',
#   'alternative': None,
#   'keyword': '논리',
#   'seeAlso': None},
#  {'title': '도서관·정보센터의 고객만족경영',
#   'creator': '오동근',
#   'publisher': '태일사',
#   'issuedYear': None,
#   'kdc': '025',
#   'ddc': '025.5',
#   'mainCategoryDescription': '문헌정보학',
#   'alternative': 'Delivering satisfaction and service quality : a customer-based approach for libraries',
#   'keyword': '정보센터',
#   'seeAlso': None},
#  {'title': '구름과 무지개',
#   'creator': 'Ashi Dorji Wangmo Wangchuck',
#   'publisher': '민속원',
#   'issuedYear': None,
#   'kdc': '915.83099',
#   'ddc': '954.98',
#   'mainCategoryDescription': '아시아(아세아)',
#   'alternative': '부탄왕국 왕비 아쉬 도르지 왕모 왕축에게 들려준 얍 우겐 도르지의 생애',
#   'keyword': 'BHUTAN',
#   'seeAlso': None},
#  {'title': '김유신전 연구',
#   'creator': '안영훈',
#   'publisher': '민속원',
#   'issuedYear': None,
#   'kdc': '810.903',
#   'ddc': '895.709',
#   'mainCategoryDescription': '한국문학',
#   'alternative': None,
#   'keyword': '고대소설',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1484031'},
#  {'title': '공부습관 3주 만에 바뀐다',
#   'creator': '이호선',
#   'publisher': '북하우스',
#   'issuedYear': None,
#   'kdc': '373.4',
#   'ddc': '371.3',
#   'mainCategoryDescription': '교육학',
#   'alternative': '습관이 바뀌면 성적이 오른다',
#   'keyword': '공부습관',
#   'seeAlso': None},
#  {'title': '해토무렵',
#   'creator': '김재석',
#   'publisher': '연극과인간',
#   'issuedYear': None,
#   'kdc': '812.6',
#   'ddc': '895.724',
#   'mainCategoryDescription': '한국문학',
#   'alternative': '3호쓰레기구역',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '장백의 아들',
#   'creator': '박응조',
#   'publisher': '연극과인간',
#   'issuedYear': None,
#   'kdc': '812.6',
#   'ddc': '895.724',
#   'mainCategoryDescription': '한국문학',
#   'alternative': '귀환병',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '성공한 사람들은 어떻게 실패를 극복했을까?',
#   'creator': 'Gilbert, Randy',
#   'publisher': '가야넷',
#   'issuedYear': None,
#   'kdc': '325.04',
#   'ddc': '650.1',
#   'mainCategoryDescription': '경제학',
#   'alternative': 'Success bound',
#   'keyword': '실패학',
#   'seeAlso': None},
#  {'title': '세상사는 동안에 확실하게 꼭 알아야 할 51가지',
#   'creator': '이철한',
#   'publisher': '포스트 인 하우스',
#   'issuedYear': None,
#   'kdc': '194.2',
#   'ddc': '177',
#   'mainCategoryDescription': '윤리학, 도덕철학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1916436'},
#  {'title': '역사 에세이',
#   'creator': '장수한',
#   'publisher': '동녘',
#   'issuedYear': None,
#   'kdc': '904',
#   'ddc': '902',
#   'mainCategoryDescription': '역사',
#   'alternative': None,
#   'keyword': '역사수필',
#   'seeAlso': None},
#  {'title': '새롭게 하소서',
#   'creator': None,
#   'publisher': '규장',
#   'issuedYear': None,
#   'kdc': '234.82',
#   'ddc': '248.5',
#   'mainCategoryDescription': '기독교',
#   'alternative': None,
#   'keyword': '간증(종교)[干證]',
#   'seeAlso': None},
#  {'title': '꿈을 품고 사는 사람',
#   'creator': '조용기',
#   'publisher': '신앙계',
#   'issuedYear': None,
#   'kdc': '234.3',
#   'ddc': '242',
#   'mainCategoryDescription': '기독교',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '중론, 논리로부터의 해탈 논리에 의한 해탈',
#   'creator': '김성철',
#   'publisher': '불교시대사',
#   'issuedYear': None,
#   'kdc': '223.85',
#   'ddc': '294.382',
#   'mainCategoryDescription': '불교',
#   'alternative': '108게송으로 새롭게 중론 읽기',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '상생의 문화를 여는 길',
#   'creator': '안운산',
#   'publisher': '대원출판',
#   'issuedYear': None,
#   'kdc': '291.12',
#   'ddc': '299.57',
#   'mainCategoryDescription': '기타 제종교',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '히말라야, 신의 마을을 가다',
#   'creator': '이대일',
#   'publisher': '정신세계사',
#   'issuedYear': None,
#   'kdc': '816.6',
#   'ddc': '895.785',
#   'mainCategoryDescription': '한국문학',
#   'alternative': '티벳 오지를 찾아 떠나는, 아주 특별한 풍경여행',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1990847'},
#  {'title': '소설과 디지털콘텐츠의 창작방법',
#   'creator': '최수웅',
#   'publisher': '청동거울',
#   'issuedYear': None,
#   'kdc': '802.3',
#   'ddc': '808.3',
#   'mainCategoryDescription': '문학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '참된 미덕의 본질',
#   'creator': 'Edwards, Jonathan',
#   'publisher': '부흥과개혁사',
#   'issuedYear': None,
#   'kdc': '234.1',
#   'ddc': '241',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Nature of true virtue',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1988514'},
#  {'title': '예배의 감격에 빠져라',
#   'creator': '김남준',
#   'publisher': '규장문화사',
#   'issuedYear': None,
#   'kdc': '237',
#   'ddc': '264',
#   'mainCategoryDescription': '기독교',
#   'alternative': '(A)biblical worship',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=21622'},
#  {'title': '기독교 희곡의 이해',
#   'creator': '최종수',
#   'publisher': '크리스챤다이제스트',
#   'issuedYear': None,
#   'kdc': '809.2',
#   'ddc': '809.2',
#   'mainCategoryDescription': '문학',
#   'alternative': 'Understanding Christian drama',
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1973482'},
#  {'title': '나는 인도를 보았는가',
#   'creator': '이호신',
#   'publisher': '종이거울',
#   'issuedYear': None,
#   'kdc': '653.11',
#   'ddc': '951.404',
#   'mainCategoryDescription': '회화, 도화',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '음주의 유혹 금주의 미혹',
#   'creator': '남태우',
#   'publisher': '태일사',
#   'issuedYear': None,
#   'kdc': '381.75',
#   'ddc': '394.13',
#   'mainCategoryDescription': '풍속, 민속학',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '색인사연구',
#   'creator': '박준식',
#   'publisher': '태일사',
#   'issuedYear': None,
#   'kdc': '024.45',
#   'ddc': '025.49',
#   'mainCategoryDescription': '문헌정보학',
#   'alternative': 'History of indexes',
#   'keyword': None,
#   'seeAlso': None},
#  {'title': '사람을 움직이는 비장의 카드',
#   'creator': '박혜정',
#   'publisher': '시간과공간사',
#   'issuedYear': None,
#   'kdc': '325.04',
#   'ddc': '650.1',
#   'mainCategoryDescription': '경제학',
#   'alternative': None,
#   'keyword': '리더십[leadership]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=141434'},
#  {'title': '제주건축의 맥',
#   'creator': '김태일',
#   'publisher': '제주대학교 출판부',
#   'issuedYear': None,
#   'kdc': '610.911',
#   'ddc': '720.9519',
#   'mainCategoryDescription': '건축술',
#   'alternative': None,
#   'keyword': None,
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1997409'},
#  ...]

# %%
with open('processed_books.json', 'w', encoding='utf-8') as file:
    json.dump(processed_books, file, ensure_ascii=False, indent=4)

# %%
import json  #json 파일 합치기
import glob

# 여러 JSON 파일을 불러와 합칠 리스트
all_data = []

# 특정 폴더에 있는 모든 JSON 파일을 불러옴 (예: 'data/' 폴더에 *.json 파일)
for file_name in glob.glob('data/*.json'):
    with open(file_name, 'r', encoding='utf-8') as file:
        data = json.load(file)
        all_data.extend(data)  # 데이터를 리스트에 추가

# 합친 데이터를 하나의 JSON 파일로 저장
with open('merged_data.json', 'w', encoding='utf-8') as output_file:
    json.dump(all_data, output_file, ensure_ascii=False, indent=4)

print("모든 파일이 merged_data.json에 성공적으로 합쳐졌습니다.")
