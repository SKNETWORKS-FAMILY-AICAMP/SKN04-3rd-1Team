# %%
import json
import re

# %%
kdc_categories = {
    "00": "총류",
    "01": "도서관, 서지학",
    "02": "문헌정보학",
    "03": "백과사전",
    "04": "강연집, 수필집, 연설문집",
    "05": "일반 연속간행물",
    "06": "일반학회, 단체, 협회, 기관",
    "07": "신문, 언론, 저널리즘",
    "08": "일반전집, 총서",
    "09": "향토자료",

    "10": "철학",
    "11": "형이상학",
    "12": "인식론, 인과론, 인간학",
    "13": "철학의 체계",
    "14": "경학",
    "15": "아시아철학, 사상",
    "16": "서양철학",
    "17": "논리학",
    "18": "심리학",
    "19": "윤리학, 도덕철학",

    "20": "종교",
    "21": "비교종교",
    "22": "불교",
    "23": "기독교",
    "24": "도교",
    "25": "천도교",
    "26": "신도",
    "27": "파라문교, 인도교",
    "28": "회교(이슬람교)",
    "29": "기타 제종교",

    "30": "사회과학",
    "31": "통계학",
    "32": "경제학",
    "33": "사회학, 사회문제",
    "34": "정치학",
    "35": "행정학",
    "36": "법학",
    "37": "교육학",
    "38": "풍속, 민속학",
    "39": "국방, 군사학",

    "40": "자연과학",
    "41": "수학",
    "42": "물리학",
    "43": "화학",
    "44": "천문학",
    "45": "지학",
    "46": "광물학",
    "47": "생명과학",
    "48": "식물학",
    "49": "동물학",

    "50": "기술과학",
    "51": "의학",
    "52": "농업, 농학",
    "53": "공학, 공학일반",
    "54": "건축공학",
    "55": "기계공학",
    "56": "전기공학, 전자공학",
    "57": "화학공학",
    "58": "제조업",
    "59": "가정학 및 가정생활",

    "60": "예술",
    "61": "건축술",
    "62": "조각",
    "63": "공예, 장식미술",
    "64": "서예",
    "65": "회화, 도화",
    "66": "사진술",
    "67": "음악",
    "68": "연극",
    "69": "오락, 운동",

    "70": "언어",
    "71": "한국어",
    "72": "중국어",
    "73": "일본어",
    "74": "영어",
    "75": "독일어",
    "76": "프랑스어",
    "77": "스페인어",
    "78": "이탈리아어",
    "79": "기타제어",

    "80": "문학",
    "81": "한국문학",
    "82": "중국문학",
    "83": "일본문학",
    "84": "영미문학",
    "85": "독일문학",
    "86": "프랑스문학",
    "87": "스페인문학",
    "88": "이탈리아문학",
    "89": "기타 제문학",

    "90": "역사",
    "91": "아시아(아세아)",
    "92": "유럽(구라파)",
    "93": "아프리카",
    "94": "북아메리카(북미)",
    "95": "남아메리카(남미)",
    "96": "오세아니아(대양주)",
    "97": "양극지방",
    "98": "지리",
    "99": "전기"
}

# %%
ddc_categories = {
    "00": "총류",
    "01": "서지",
    "02": "문헌정보학",
    "03": "백과사전",
    "04": "공기호",
    "05": "잡지, 저널, 연속간행물",
    "06": "협회, 박물관학",
    "07": "뉴스 매체, 저널리즘, 출판",
    "08": "일반전집",
    "09": "필사본, 희귀서적",

    "10": "철학",
    "11": "형이상학",
    "12": "인식론",
    "13": "초상현상",
    "14": "철학파",
    "15": "심리학",
    "16": "철학 논리",
    "17": "윤리학",
    "18": "고대, 중세, 동양철학",
    "19": "현대 서양철학",

    "20": "종교",
    "21": "종교철학과 이론",
    "22": "성서",
    "23": "기독교와 기독교 신학",
    "24": "기독교 실천과 교리준수",
    "25": "기독교 목회자의 실천과 종파",
    "26": "기독교 사회 신학",
    "27": "기독교 역사",
    "28": "기독교 교파",
    "29": "기타 종교",

    "30": "사회과학",
    "31": "통계학",
    "32": "정치학",
    "33": "경제학",
    "34": "법학",
    "35": "행정학과 군사학",
    "36": "사회서비스",
    "37": "교육",
    "38": "무역 통신과 수송",
    "39": "관습, 에티켓과 민속전통",

    "40": "언어",
    "41": "언어학",
    "42": "영어와 고대언어",
    "43": "독일어 관련언어",
    "44": "프랑스 관련언어",
    "45": "이탈리아, 루마니아어",
    "46": "스페인, 포르투갈어",
    "47": "라틴과 이탤릭 언어",
    "48": "고대, 현대 그리서어",
    "49": "기타 언어",

    "50": "과학",
    "51": "수학",
    "52": "천문학",
    "53": "물리학",
    "54": "화학",
    "55": "지구과학",
    "56": "고생물학",
    "57": "생물학",
    "58": "식물학",
    "59": "동물학",

    "60": "기술",
    "61": "의학",
    "62": "공학",
    "63": "농업",
    "64": "가정, 가족경영",
    "65": "경영과 홍보",
    "66": "화학공학",
    "67": "제조",
    "68": "특별한 용도의 제조",
    "69": "건축",

    "70": "예술, 레크리에이션",
    "71": "도시계획, 조경술",
    "72": "건축학",
    "73": "조각품, 도예와 금속제품",
    "74": "인쇄예술",
    "75": "그림",
    "76": "제작술",
    "77": "사진술",
    "78": "음악",
    "79": "스포츠, 게임",

    "80": "문학",
    "81": "미국문학",
    "82": "영어, 고대영어문학",
    "83": "독일 문학",
    "84": "프랑스 문학",
    "85": "이탈리아 문학",
    "86": "스페인, 포르투갈 문학",
    "87": "라틴 문학",
    "88": "그리스 문학",
    "89": "기타 문학",

    "90": "역사, 지리",
    "91": "지리와 여행",
    "92": "전기와 계보학",
    "93": "고대 역사",
    "94": "유럽 역사",
    "95": "아시아 역사",
    "96": "아프리카 역사",
    "97": "북아메리카 역사",
    "98": "남아메리카 역사",
    "99": "기타지역 역사"
}

# %%
with open('./data/graph_section_58.json', 'r', encoding='utf-8') as file:
    data = json.load(file)
    books = data.get('@graph', [])

# %%
if not books:
    print("도서 정보를 확인할 수 없습니다.")
else:
    processed_books = []
    korean_regex = re.compile("^[가-힣]")

    for book in books:
        title = book.get("title")
        issuedYear = book.get("issuedYear")
        
        if not title or not korean_regex.match(title):
            continue
        
        if issuedYear == None:
            issuedYear = book.get("issued")
        
        kdc_code = book.get("kdc")
        main_kdc_code = kdc_code[:2] if kdc_code else None 
        main_kdc_description = kdc_categories.get(main_kdc_code)
        
        ddc_code = book.get("ddc")
        main_ddc_code = ddc_code[:2] if ddc_code else None
        main_ddc_description = ddc_categories.get(main_ddc_code)
        
        if main_kdc_description is None and main_ddc_description is None:
            continue

        
        processed_book = {
            "title": book.get("title", "없음"),
            "creator": book.get("creator", "없음"),
            "publisher": book.get("publisher", "없음"),
            "issued": book.get("issued", "없음"),
            "location": kdc_code if kdc_code else ddc_code,
            "mainCategoryDescription": main_kdc_description if main_kdc_description else main_ddc_description,
            "alternative": book.get("alternative", "없음"),
            "keyword": book.get("keyword", "없음"),
            "seeAlso": book.get("seeAlso", "없음"),
        }

        processed_books.append(processed_book)

processed_books
# Out:
# [{'title': '원자력 안전의 논리',
#   'creator': 'Sato Kazuo',
#   'publisher': '한솜미디어',
#   'issued': '2006',
#   'location': '559.126',
#   'mainCategoryDescription': '기계공학',
#   'alternative': '없음',
#   'keyword': '원자력[原子力]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2540230'},
#  {'title': '미술전시 홍보, 이렇게 한다',
#   'creator': '박인권',
#   'publisher': '아트북스',
#   'issued': '2006',
#   'location': '606.3',
#   'mainCategoryDescription': '예술',
#   'alternative': '없음',
#   'keyword': '전시홍보',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2611549'},
#  {'title': '세계에서 가장 아름다운 미술관 100',
#   'creator': '신성림',
#   'publisher': '서강출판사',
#   'issued': '2007',
#   'location': '606.9',
#   'mainCategoryDescription': '예술',
#   'alternative': '100 most beautiful museums of the world',
#   'keyword': '미술관[美術館]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2627658'},
#  {'title': '카프카 작품선',
#   'creator': 'Kafka, Franz',
#   'publisher': '주변인의길',
#   'issued': '2007',
#   'location': '853',
#   'mainCategoryDescription': '독일문학',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2626622'},
#  {'title': '준비된 자녀 교육',
#   'creator': 'Suggs, Rob',
#   'publisher': '생명의말씀사',
#   'issued': '2006',
#   'location': '234.9',
#   'mainCategoryDescription': '기독교',
#   'alternative': '로스캠벨 박사의 보금자리 nest 자녀 교육법',
#   'keyword': '자녀 교육[子女敎育]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2623419'},
#  {'title': '하나님의 뜻을 발견하는 62가지 방법',
#   'creator': '잭슨, 고든 S',
#   'publisher': '규장',
#   'issued': '2006',
#   'location': '234.8',
#   'mainCategoryDescription': '기독교',
#   'alternative': "Compact guide to discovering God's will",
#   'keyword': '개인 신앙 생활[個人信仰生活]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2615175'},
#  {'title': '고당 조만식',
#   'creator': '송삼용',
#   'publisher': '생명의말씀사',
#   'issued': '2006',
#   'location': '230.99',
#   'mainCategoryDescription': '기독교',
#   'alternative': '(하나님이 보낸 사람) 민족지도자 고당 조만식',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2623236'},
#  {'title': '정신병인가 귀신들림인가?',
#   'creator': '김진',
#   'publisher': '생명의말씀사',
#   'issued': '2006',
#   'location': '234.82',
#   'mainCategoryDescription': '기독교',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2621602'},
#  {'title': '풍성한 은혜의 아름다움이여',
#   'creator': '김우생',
#   'publisher': '생명의말씀사',
#   'issued': '2007',
#   'location': '235.2',
#   'mainCategoryDescription': '기독교',
#   'alternative': '46년 목회 인생의 은혜와 감사가 온전히 묻어나는 말씀들',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2623801'},
#  {'title': '겸손',
#   'creator': 'Mahaney, C. J',
#   'publisher': '생명의말씀사',
#   'issued': '2007',
#   'location': '234.8',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Humility : true greatness',
#   'keyword': '기독교 신앙 생활[基督敎信仰生活]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2622439'},
#  {'title': '사회봉사의 성서신학적 이해',
#   'creator': '이재서',
#   'publisher': '세계밀알',
#   'issued': '2006',
#   'location': '235',
#   'mainCategoryDescription': '기독교',
#   'alternative': '봉사신학은 이미 실천신학이다',
#   'keyword': '종교봉사',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2954615'},
#  {'title': '내 남편 역도산',
#   'creator': '한성례',
#   'publisher': '자음과모음',
#   'issued': '2004',
#   'location': '692.099',
#   'mainCategoryDescription': '오락, 운동',
#   'alternative': '없음',
#   'keyword': '김신락',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1479297'},
#  {'title': '시편 어떻게 읽을 것인가',
#   'creator': '이태훈',
#   'publisher': '한국성서유니온선교회',
#   'issued': '2006',
#   'location': '233.32',
#   'mainCategoryDescription': '기독교',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2537101'},
#  {'title': '부처는 행복의 대상이야',
#   'creator': '이종진',
#   'publisher': '원불교출판사',
#   'issued': '2005',
#   'location': '228.955',
#   'mainCategoryDescription': '불교',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2085636'},
#  {'title': '삼국지 바로 읽기',
#   'creator': '김운회',
#   'publisher': '삼인',
#   'issued': '2006',
#   'location': '823.509',
#   'mainCategoryDescription': '중국문학',
#   'alternative': '(김운회 교수의) 삼국지 바로 읽기',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2617106'},
#  {'title': '평화의 어머니와 함께하는 일상기도',
#   'creator': '김승업',
#   'publisher': '성바오로',
#   'issued': '2006',
#   'location': '238.27',
#   'mainCategoryDescription': '기독교',
#   'alternative': '(The)prayer presented with the rosary of peace',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2537009'},
#  {'title': '공백의 그림자',
#   'creator': '박이문',
#   'publisher': '문학동네',
#   'issued': '2006',
#   'location': '811.6',
#   'mainCategoryDescription': '한국문학',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2612732'},
#  {'title': '카프카 작품선',
#   'creator': '강희진',
#   'publisher': '주변인의길',
#   'issued': '2006',
#   'location': '853',
#   'mainCategoryDescription': '독일문학',
#   'alternative': '독신자의 불행',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2534174'},
#  {'title': '지구촌시대 상생의 윤리와 철학',
#   'creator': '없음',
#   'publisher': '백산서당',
#   'issued': '2004',
#   'location': '194',
#   'mainCategoryDescription': '윤리학, 도덕철학',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2083353'},
#  {'title': '그들은 왜 오늘도 산과 싸우는가',
#   'creator': 'Krakauer, Jon',
#   'publisher': '자음과모음',
#   'issued': '2006',
#   'location': '699.104',
#   'mainCategoryDescription': '오락, 운동',
#   'alternative': 'Eiger dreams',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2509881'},
#  {'title': '은사코드',
#   'creator': '홍영기',
#   'publisher': '교회성장연구소',
#   'issued': '2006',
#   'location': '231.413',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Gift code',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2520554'},
#  {'title': '한글의 성서적 의미',
#   'creator': '전택부',
#   'publisher': '땅에쓰신글씨',
#   'issued': '2005',
#   'location': '235.84',
#   'mainCategoryDescription': '기독교',
#   'alternative': '오리 선생의 한글사랑 한글의 성서적 의미',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1933751'},
#  {'title': '운運을 알면 돈을 번다',
#   'creator': '없음',
#   'publisher': '문화마당',
#   'issued': '2006',
#   'location': '188',
#   'mainCategoryDescription': '심리학',
#   'alternative': '책 한권에 1억원 가치를 부여한 실용서, 실제체험의 돈 버는 방법과 성공이야기 ; 1억원짜리 실용서',
#   'keyword': '운수(운)[運數]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2083160'},
#  {'title': '한국대통령학 & 대권시나리오',
#   'creator': '채수명',
#   'publisher': '이유',
#   'issued': '2002',
#   'location': '350.21',
#   'mainCategoryDescription': '행정학',
#   'alternative': '없음',
#   'keyword': '국가경영',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=103831'},
#  {'title': '누드공항',
#   'creator': '김병중',
#   'publisher': '동인랑',
#   'issued': '2005',
#   'location': '814.6',
#   'mainCategoryDescription': '한국문학',
#   'alternative': 'Nude airport',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1602056'},
#  {'title': '최신가요대백과',
#   'creator': '없음',
#   'publisher': '삼호뮤직',
#   'issued': '2006',
#   'location': '673.5',
#   'mainCategoryDescription': '음악',
#   'alternative': 'New hit song best collection',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2514846'},
#  {'title': '말레이 인도네시아어 첫걸음',
#   'creator': '고영훈',
#   'publisher': '한국외국어대학교 출판부',
#   'issued': '2006',
#   'location': '796.72',
#   'mainCategoryDescription': '기타제어',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2533167'},
#  {'title': '아랍어 문법',
#   'creator': '이두선',
#   'publisher': '한국외국어대학교 출판부',
#   'issued': '2006',
#   'location': '797.7',
#   'mainCategoryDescription': '기타제어',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2527342'},
#  {'title': '번역학 비판',
#   'creator': '김진아',
#   'publisher': '한국외국어대학교 출판부',
#   'issued': '2006',
#   'location': '701.7',
#   'mainCategoryDescription': '언어',
#   'alternative': '中西经学批评',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2622802'},
#  {'title': '이탈리아어 40강',
#   'creator': '조문환',
#   'publisher': '한국외국어대학교 출판부',
#   'issued': '2006',
#   'location': '785',
#   'mainCategoryDescription': '이탈리아어',
#   'alternative': "Parlare l'italiano con la grammatica",
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2537872'},
#  {'title': '연극',
#   'creator': '박지애',
#   'publisher': '문학바탕',
#   'issued': '2006',
#   'location': '811.6',
#   'mainCategoryDescription': '한국문학',
#   'alternative': '박지애 시집',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2629491'},
#  {'title': '서계 박세당 연구',
#   'creator': '박병련',
#   'publisher': '집문당',
#   'issued': '2006',
#   'location': '151.58',
#   'mainCategoryDescription': '아시아철학, 사상',
#   'alternative': '없음',
#   'keyword': '박세당',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2686372'},
#  {'title': '이란외교정책론',
#   'creator': '장병옥',
#   'publisher': '한국외국어대학교 출판부',
#   'issued': '2006',
#   'location': '349.183',
#   'mainCategoryDescription': '정치학',
#   'alternative': 'Iran foreign policy',
#   'keyword': '이란외교정세',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2530470'},
#  {'title': '고객충성의 신화',
#   'creator': '바브라, 테리',
#   'publisher': '한국물가정보',
#   'issued': '2006',
#   'location': '326.16',
#   'mainCategoryDescription': '경제학',
#   'alternative': '고객충성도에 관한 오해와 진실',
#   'keyword': '고객 충성도[顧客忠誠度]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2747166'},
#  {'title': '세상을 움직인 명문 vs 명문',
#   'creator': '함규진',
#   'publisher': '포럼',
#   'issued': '2006',
#   'location': '909',
#   'mainCategoryDescription': '역사',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2615216'},
#  {'title': '하나님을 만나는 비결',
#   'creator': '로이드-존스, 마틴',
#   'publisher': '꿈지기',
#   'issued': '2006',
#   'location': '235.2',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Heirs of salvation',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2621600'},
#  {'title': '꿈이 머무는 곳',
#   'creator': '김가영',
#   'publisher': '문예운동',
#   'issued': '2006',
#   'location': '688.04',
#   'mainCategoryDescription': '연극',
#   'alternative': '김가영의 영화이야기',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2537956'},
#  {'title': '슈트라우스 30 가곡집',
#   'creator': '박노경',
#   'publisher': '태림출판사',
#   'issued': '2006',
#   'location': '673.83',
#   'mainCategoryDescription': '음악',
#   'alternative': 'Strauss 30 songs : voice & piano(high)',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1489649'},
#  {'title': '볼프 65 가곡집',
#   'creator': '박노경',
#   'publisher': '태림출판사',
#   'issued': '2006',
#   'location': '673.83',
#   'mainCategoryDescription': '음악',
#   'alternative': 'Wolf 65 songs : voice & piano(high)',
#   'keyword': '없음',
#   'seeAlso': '없음'},
#  {'title': '체르니 50번 연습곡',
#   'creator': '없음',
#   'publisher': '태림출판사',
#   'issued': '2000',
#   'location': '676.28',
#   'mainCategoryDescription': '음악',
#   'alternative': 'Czerny 50: Kunst der Fingerfertigkeit Op. 740(699)',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1468106'},
#  {'title': '슈베르트 200가곡집',
#   'creator': '김청자',
#   'publisher': '태림출판사',
#   'issued': '2006',
#   'location': '673.83',
#   'mainCategoryDescription': '음악',
#   'alternative': 'Schubert 200 songs : voice & piano(low)',
#   'keyword': '없음',
#   'seeAlso': '없음'},
#  {'title': '포레 37 가곡집',
#   'creator': '유태열',
#   'publisher': '태림출판사',
#   'issued': '2006',
#   'location': '673.83',
#   'mainCategoryDescription': '음악',
#   'alternative': 'Fauré 37 songs : voice & piano(high)',
#   'keyword': '없음',
#   'seeAlso': '없음'},
#  {'title': '글쓰기 치료',
#   'creator': 'Pennebaker, James W',
#   'publisher': '학지사',
#   'issued': '2007',
#   'location': '802',
#   'mainCategoryDescription': '문학',
#   'alternative': 'Writing to heal : a guided journal for recovering from trauma & emotional upheaval',
#   'keyword': '글쓰기',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2627418'},
#  {'title': '맛있는 선물요리',
#   'creator': '이지은',
#   'publisher': '리스컴',
#   'issued': '2006',
#   'location': '594.5',
#   'mainCategoryDescription': '가정학 및 가정생활',
#   'alternative': '요리로 마음을 전하세요~',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2617934'},
#  {'title': '서양미술 400년',
#   'creator': '박선아',
#   'publisher': 'SBS: 지엔씨미디어',
#   'issued': '2005',
#   'location': '606.3',
#   'mainCategoryDescription': '예술',
#   'alternative': "Lignes et couleurs : chefs-d' œuvre de la collection du musée des beaux-arts de reims du XVII  au XX  siècle",
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1488313'},
#  {'title': '명심보감',
#   'creator': '이기석',
#   'publisher': '홍신문화사',
#   'issued': '2007',
#   'location': '199.1',
#   'mainCategoryDescription': '윤리학, 도덕철학',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2624847'},
#  {'title': '순수이성비판',
#   'creator': '칸트, I',
#   'publisher': '홍신문화사',
#   'issued': '2006',
#   'location': '165.21',
#   'mainCategoryDescription': '서양철학',
#   'alternative': '서양 철학을 재정립한 위대한 고전',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2614029'},
#  {'title': '캐나다에 사는 소라 엄마의 언어교육 이야기',
#   'creator': '박정은',
#   'publisher': '일지사',
#   'issued': '2007',
#   'location': '707',
#   'mainCategoryDescription': '언어',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2651134'},
#  {'title': '사람들 사이로',
#   'creator': '없음',
#   'publisher': '청어람미디어',
#   'issued': '2006',
#   'location': '660.4',
#   'mainCategoryDescription': '사진술',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2621948'},
#  {'title': '차이와 갈등에 대한 철학적 성찰',
#   'creator': '없음',
#   'publisher': '철학과현실사',
#   'issued': '2007',
#   'location': '100',
#   'mainCategoryDescription': '철학',
#   'alternative': '『철학』제89집의 별책',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2627710'},
#  {'title': '도를 찾아서',
#   'creator': '이규상',
#   'publisher': '범양사',
#   'issued': '2007',
#   'location': '151.7',
#   'mainCategoryDescription': '아시아철학, 사상',
#   'alternative': '도의 근본과 새로운 인식',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2636173'},
#  {'title': '초록색 자전거',
#   'creator': '클레인, 스탠리',
#   'publisher': '청림출판',
#   'issued': '2007',
#   'location': '199.1',
#   'mainCategoryDescription': '윤리학, 도덕철학',
#   'alternative': 'You will dream new dreams',
#   'keyword': '인생훈[人生訓]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2635401'},
#  {'title': '본회퍼의 삶과 신학',
#   'creator': '정은영',
#   'publisher': '한스컨텐츠',
#   'issued': '2007',
#   'location': '230.99',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Bonhoeffer speaks today : following Jesus at all costs',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2635778'},
#  {'title': '나의 DSLR, 꽃을 추억하다',
#   'creator': '다나카 히로시',
#   'publisher': '멘토르',
#   'issued': '2006',
#   'location': '662',
#   'mainCategoryDescription': '사진술',
#   'alternative': '없음',
#   'keyword': '사진 촬영[寫眞撮影]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2117101'},
#  {'title': '왜 예수님을 믿어야하나',
#   'creator': '없음',
#   'publisher': '서울말씀사',
#   'issued': '2001',
#   'location': '234.8',
#   'mainCategoryDescription': '기독교',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=69283'},
#  {'title': '재미있는 영어 속담과 명언',
#   'creator': '박엽',
#   'publisher': '버들미디어',
#   'issued': '2001',
#   'location': '747',
#   'mainCategoryDescription': '영어',
#   'alternative': '영어도 배우고 속담도 익히는 내용별로 분류된 대학 수능 시험 필수 속담집',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=87432'},
#  {'title': '오늘의 만나',
#   'creator': '조용기',
#   'publisher': '서울말씀사',
#   'issued': '2006',
#   'location': '234.2',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Our daily Manna : October ~ December',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2524521'},
#  {'title': '나를 찾아가는 21字의 여정',
#   'creator': '한자경',
#   'publisher': '서광사',
#   'issued': '2006',
#   'location': '104',
#   'mainCategoryDescription': '철학',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2624381'},
#  {'title': '하나님이 주신 독신의 은사',
#   'creator': '임신희',
#   'publisher': '엔크리스토',
#   'issued': '2006',
#   'location': '234.8',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'They were single too : 8 biblical role models',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2624711'},
#  {'title': '하나님, 도대체 왜 그렇게 하셨습니까?',
#   'creator': 'Meyer, Joyce',
#   'publisher': '엔크리스토',
#   'issued': '2006',
#   'location': '234.8',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Why, God, why?',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2540404'},
#  {'title': '지금―여기에서의 전이 분석',
#   'creator': '바우어, 그레고리 P',
#   'publisher': '학지사',
#   'issued': '2007',
#   'location': '186.5',
#   'mainCategoryDescription': '심리학',
#   'alternative': '전이 분석',
#   'keyword': '정신 분석 요법[精神分析療法]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2627415'},
#  {'title': '스포츠 사회심리학',
#   'creator': '김정남',
#   'publisher': '학지사',
#   'issued': '2007',
#   'location': '692.8',
#   'mainCategoryDescription': '오락, 운동',
#   'alternative': 'Sports social psychology',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2627413'},
#  {'title': '인상주의자 연인들',
#   'creator': 'Meyers, Jeffrey',
#   'publisher': '마음산책',
#   'issued': '2007',
#   'location': '653.26',
#   'mainCategoryDescription': '회화, 도화',
#   'alternative': 'Impressionist quartet : the intimate genius of Manet and Morisot, Degas and Cassat',
#   'keyword': '연인',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2624140'},
#  {'title': '하나님의 뜻을 발견해 가는 여행',
#   'creator': '정원',
#   'publisher': '영성의 숲',
#   'issued': '2007',
#   'location': '233.099',
#   'mainCategoryDescription': '기독교',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2636953'},
#  {'title': '한국영화를 말한다',
#   'creator': '없음',
#   'publisher': '異彩',
#   'issued': '2006',
#   'location': '688.0911',
#   'mainCategoryDescription': '연극',
#   'alternative': '없음',
#   'keyword': '한국영화',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2625951'},
#  {'title': '하느님 없이 하느님과 함께',
#   'creator': '송기득',
#   'publisher': '신학비평사',
#   'issued': '2006',
#   'location': '230.99',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Without God, yet with God',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2513897'},
#  {'title': '초벌그림을 그리다',
#   'creator': '이수학',
#   'publisher': '조경',
#   'issued': '2006',
#   'location': '610',
#   'mainCategoryDescription': '건축술',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2620381'},
#  {'title': '사랑의 원자탄',
#   'creator': '없음',
#   'publisher': '성광문화사',
#   'issued': '2007',
#   'location': '230.99',
#   'mainCategoryDescription': '기독교',
#   'alternative': '손양원 목사 순교 일대기',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=29743'},
#  {'title': '그리운 詩, 여행에서 만나다',
#   'creator': '노용무',
#   'publisher': '박이정',
#   'issued': '2006',
#   'location': '811.609',
#   'mainCategoryDescription': '한국문학',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2625993'},
#  {'title': '스페인어',
#   'creator': '없음',
#   'publisher': '동인랑',
#   'issued': '2006',
#   'location': '777.5',
#   'mainCategoryDescription': '스페인어',
#   'alternative': '현지인과 한방에 딱 통한다',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=142209'},
#  {'title': '주님, 감사합니다!',
#   'creator': '신선명',
#   'publisher': '아침영성지도연구원',
#   'issued': '2006',
#   'location': '234.8',
#   'mainCategoryDescription': '기독교',
#   'alternative': '소명을 찾아 떠나는 한 영성지도자의 속깊은 내면탐구',
#   'keyword': '기독교[基督敎]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2613718'},
#  {'title': '마음에서 얻은 正典',
#   'creator': '심정수',
#   'publisher': '불휘',
#   'issued': '2006',
#   'location': '225.2',
#   'mainCategoryDescription': '불교',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2496239'},
#  {'title': '헤겔과 자연',
#   'creator': '없음',
#   'publisher': '제우스',
#   'issued': '2006',
#   'location': '165.4',
#   'mainCategoryDescription': '서양철학',
#   'alternative': '없음',
#   'keyword': '자연 철학[自然哲學]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2532359'},
#  {'title': '바로 떠나는 여행 영어',
#   'creator': '없음',
#   'publisher': '밝은누리',
#   'issued': '2006',
#   'location': '747.5',
#   'mainCategoryDescription': '영어',
#   'alternative': '없음',
#   'keyword': '영어 회화[英語會話]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2485906'},
#  {'title': '신학 실종',
#   'creator': '김재영',
#   'publisher': '부흥과개혁사',
#   'issued': '2006',
#   'location': '231.015',
#   'mainCategoryDescription': '기독교',
#   'alternative': '왜 복음주의가 세속화되었는가?',
#   'keyword': '신학[神學]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2610840'},
#  {'title': '오픈워터 다이버 매뉴얼',
#   'creator': '진신',
#   'publisher': '풍등출판사',
#   'issued': '2006',
#   'location': '696.7',
#   'mainCategoryDescription': '오락, 운동',
#   'alternative': 'Open water diver manual',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2620477'},
#  {'title': '왜, 어떻게 누구와 함께 성지순례를 가야 하나?',
#   'creator': '김성제',
#   'publisher': '가톨릭출판사',
#   'issued': '2007',
#   'location': '233.098',
#   'mainCategoryDescription': '기독교',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2887630'},
#  {'title': '나자렛의 요셉',
#   'creator': '마르틀레, 베르나르',
#   'publisher': '가톨릭출판사',
#   'issued': '2007',
#   'location': '232.88',
#   'mainCategoryDescription': '기독교',
#   'alternative': "Joseph de Nazareth : l'homme de confiance",
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=4666819'},
#  {'title': '하나님을 경험하는 삶',
#   'creator': 'Blackaby, Henry T',
#   'publisher': '요단출판사',
#   'issued': '2006',
#   'location': '235.74',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Experiencing God : knowing and doing the will of God',
#   'keyword': '기독교 교육 교재[基督敎敎育敎材]',
#   'seeAlso': '없음'},
#  {'title': '죄와 세상을 이기는 능력, 십자가',
#   'creator': '매허니, C. J',
#   'publisher': '요단출판사',
#   'issued': '2006',
#   'location': '234.8',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Cross centered life',
#   'keyword': '기독교 신앙 생활[基督敎信仰生活]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2488065'},
#  {'title': '하나님을 경험하는 삶 40일',
#   'creator': 'Blackaby, Richard',
#   'publisher': '요단출판사',
#   'issued': '2006',
#   'location': '235.74',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Reality : 7 truths from experiencing God',
#   'keyword': '기독교 교육 교재[基督敎敎育敎材]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2418677'},
#  {'title': '하늘 문을 여는 사람들',
#   'creator': '김용혁',
#   'publisher': '요단출판사',
#   'issued': '2006',
#   'location': '235.2',
#   'mainCategoryDescription': '기독교',
#   'alternative': '아비목회 철학으로 전하는 설교집',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2500537'},
#  {'title': '과학기술과 전쟁',
#   'creator': '이동욱',
#   'publisher': '황금알',
#   'issued': '2006',
#   'location': '392',
#   'mainCategoryDescription': '국방, 군사학',
#   'alternative': 'Technology and war : from 2000 B.C. to the present',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2536344'},
#  {'title': '계절의 보석',
#   'creator': '신동환',
#   'publisher': '가치창조',
#   'issued': '2006',
#   'location': '594.51',
#   'mainCategoryDescription': '가정학 및 가정생활',
#   'alternative': '건강한 삶을 사는 사람들의 행복한 웰빙 먹거리',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2612169'},
#  {'title': '영어는 self다',
#   'creator': '김필립',
#   'publisher': '디지털북스',
#   'issued': '2006',
#   'location': '740.7',
#   'mainCategoryDescription': '영어',
#   'alternative': '(혼자영어공부하기) 영어는 self다',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2616854'},
#  {'title': '은혜의 각성',
#   'creator': '정진환',
#   'publisher': '죠이선교회',
#   'issued': '2006',
#   'location': '234.8',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Grace awakening',
#   'keyword': '개인 신앙 생활[個人信仰生活]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2620889'},
#  {'title': '성령이 이끄는 교회',
#   'creator': 'Robnett, Timothy',
#   'publisher': '베드로서원',
#   'issued': '2007',
#   'location': '236',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Spirit-driven church',
#   'keyword': '교회[敎會]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2628477'},
#  {'title': '어머니',
#   'creator': '없음',
#   'publisher': '매경출판',
#   'issued': '2007',
#   'location': '818',
#   'mainCategoryDescription': '한국문학',
#   'alternative': '명사 28인이 어머니께 드리는 감사장',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2623747'},
#  {'title': '내 몸에 좋은 야채와 과일즙',
#   'creator': '워커, N. W',
#   'publisher': '새로운사람들',
#   'issued': '2006',
#   'location': '512.54',
#   'mainCategoryDescription': '의학',
#   'alternative': 'Fresh vegetable and fruit juices',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2621004'},
#  {'title': '생명수의 비밀',
#   'creator': '김영귀',
#   'publisher': '서울문화사',
#   'issued': '2005',
#   'location': '517.571',
#   'mainCategoryDescription': '의학',
#   'alternative': 'Secret of life-giving water',
#   'keyword': '전해환원수',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1540094'},
#  {'title': '가야교회이야기',
#   'creator': '없음',
#   'publisher': '크리스챤서적',
#   'issued': '2007',
#   'location': '235.3',
#   'mainCategoryDescription': '기독교',
#   'alternative': '기독교인이 1%밖에 안 되는 지역에서 목회하며 겪은 좌충우돌 목회현장 체험기',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2636795'},
#  {'title': '위대한 만남',
#   'creator': '손민규',
#   'publisher': '비전비엔피·비전코리아',
#   'issued': '2006',
#   'location': '155.9',
#   'mainCategoryDescription': '아시아철학, 사상',
#   'alternative': '(인생에 소중한 가르침을 준 스승과의) 위대한 만남',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2086630'},
#  {'title': '만남',
#   'creator': '김경완',
#   'publisher': '불과구름',
#   'issued': '2006',
#   'location': '811.6',
#   'mainCategoryDescription': '한국문학',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2517773'},
#  {'title': '하나님 나라의 말씀길',
#   'creator': '곽요셉',
#   'publisher': '가치창조',
#   'issued': '2006',
#   'location': '234.2',
#   'mainCategoryDescription': '기독교',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2532440'},
#  {'title': '화 다스리기',
#   'creator': 'Favaro, Peter J',
#   'publisher': '우듬지',
#   'issued': '2007',
#   'location': '181.71',
#   'mainCategoryDescription': '심리학',
#   'alternative': 'Anger management',
#   'keyword': '화(언짢음)[火]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2680896'},
#  {'title': '대학음악 이론',
#   'creator': '백병동',
#   'publisher': '현대음악출판사',
#   'issued': '2007',
#   'location': '671',
#   'mainCategoryDescription': '음악',
#   'alternative': '음악을 깊이있게 감상, 연주, 작곡하는 바탕을 마련하는 책',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2689741'},
#  {'title': '스리마드 바가바드 기타',
#   'creator': '박지명',
#   'publisher': '東文選',
#   'issued': '2007',
#   'location': '273',
#   'mainCategoryDescription': '파라문교, 인도교',
#   'alternative': '없음',
#   'keyword': '바가바드기타[Bhagavadgita]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2682011'},
#  {'title': '영화로 보는 세상',
#   'creator': '전한부',
#   'publisher': '무진미래',
#   'issued': '2006',
#   'location': '688.09',
#   'mainCategoryDescription': '연극',
#   'alternative': 'Cinema zoom in',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2510099'},
#  {'title': '사람아 말하라',
#   'creator': '전경환',
#   'publisher': 'be',
#   'issued': '2007',
#   'location': '660.4',
#   'mainCategoryDescription': '사진술',
#   'alternative': '인간과 사람! 이 둘의 여러 상황에 대해 생각해 보는 작업이다 ; 그리고 사진은 순간포착이면서 장기적인 집착이다',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2629996'},
#  {'title': '하나님 나라를 위해 전력하라',
#   'creator': '이현모',
#   'publisher': '요단출판사',
#   'issued': '2006',
#   'location': '235.6',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'To the ends of the earth : empowering kingdom growth',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2525279'},
#  {'title': '면류관을 갈망하는 인생',
#   'creator': '이동원',
#   'publisher': '요단출판사',
#   'issued': '2006',
#   'location': '234.2',
#   'mainCategoryDescription': '기독교',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2529466'},
#  {'title': '헤븐',
#   'creator': 'Alcorn, Randy C',
#   'publisher': '요단출판사',
#   'issued': '2006',
#   'location': '231.62',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Heaven',
#   'keyword': '천국[天國]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2622367'},
#  {'title': '하나님을 향해 춤을!',
#   'creator': '최신정',
#   'publisher': '요단출판사',
#   'issued': '2006',
#   'location': '235.5',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Body worship dancing',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2503836'},
#  {'title': '출애굽의 아침',
#   'creator': '이동원',
#   'publisher': '요단출판사',
#   'issued': '2006',
#   'location': '233.212',
#   'mainCategoryDescription': '기독교',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2121545'},
#  {'title': '출애굽의 오후',
#   'creator': '이동원',
#   'publisher': '요단출판사',
#   'issued': '2006',
#   'location': '233.212',
#   'mainCategoryDescription': '기독교',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': '없음'},
#  {'title': '침례와 세례 무엇이 다른가?',
#   'creator': '노영식',
#   'publisher': '요단출판사',
#   'issued': '2006',
#   'location': '238.6',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'What is the difference between baptism by immersion and baptism by sprinkling or pouring',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2418632'},
#  {'title': '한국영화라는 낯선 경계',
#   'creator': '김선아',
#   'publisher': '커뮤니케이션북스',
#   'issued': '2006',
#   'location': '688.0911',
#   'mainCategoryDescription': '연극',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2622792'},
#  {'title': '교회는 병원이다',
#   'creator': '최영기',
#   'publisher': '요단출판사',
#   'issued': '2006',
#   'location': '235.2',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'I am the lord, who heals you',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2511519'},
#  {'title': '십자가의 사랑에 사로잡혀',
#   'creator': 'Mahaney, C. J',
#   'publisher': '요단출판사',
#   'issued': '2006',
#   'location': '232.7',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Christ our mediator',
#   'keyword': '기독교 신앙 생활[基督敎信仰生活]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2488064'},
#  {'title': '나의 연인, 주님과의 친밀한 사귐',
#   'creator': 'Tada, Joni Eareckson',
#   'publisher': '요단출판사',
#   'issued': '2006',
#   'location': '234.3',
#   'mainCategoryDescription': '기독교',
#   'alternative': '31 days toward intimacy with God',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2516302'},
#  {'title': '축제가 있는 교회',
#   'creator': '김창주',
#   'publisher': '지성과 실천사',
#   'issued': '2006',
#   'location': '235.2',
#   'mainCategoryDescription': '기독교',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2623416'},
#  {'title': '스파르타 sub note',
#   'creator': '없음',
#   'publisher': '스카이 잉글리시',
#   'issued': '2007',
#   'location': '745',
#   'mainCategoryDescription': '영어',
#   'alternative': '9급공무원 경찰직 공무원 법원·검찰·소방직',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2624919'},
#  {'title': '웨슬리의 갱신운동과 한국교회',
#   'creator': '조종남',
#   'publisher': '대한기독교서회',
#   'issued': '2006',
#   'location': '230.99',
#   'mainCategoryDescription': '기독교',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2623415'},
#  {'title': '하나님이 디자인하신 교회로 가기',
#   'creator': '없음',
#   'publisher': '쿰란출판사',
#   'issued': '2007',
#   'location': '235.74',
#   'mainCategoryDescription': '기독교',
#   'alternative': '없음',
#   'keyword': '기독교 교육 교재[基督敎敎育敎材]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2122428'},
#  {'title': '우리를 사랑하시는 예수님의 지상 사역',
#   'creator': '김병수',
#   'publisher': '쿰란출판사',
#   'issued': '2007',
#   'location': '233.62',
#   'mainCategoryDescription': '기독교',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2651059'},
#  {'title': '하나님이 준비하시리라',
#   'creator': '김동문',
#   'publisher': '쿰란출판사',
#   'issued': '2006',
#   'location': '235.2',
#   'mainCategoryDescription': '기독교',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2624700'},
#  {'title': '강같이 흐르는 하나님의 자유 여정',
#   'creator': '김우영',
#   'publisher': '쿰란출판사',
#   'issued': '2006',
#   'location': '234.2',
#   'mainCategoryDescription': '기독교',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2628560'},
#  {'title': '우리 아이 건강하게, 날씬하게',
#   'creator': 'Bine, Linda',
#   'publisher': '한미의학',
#   'issued': '2005',
#   'location': '513.398',
#   'mainCategoryDescription': '의학',
#   'alternative': 'Helping your child lose weight the healthy way',
#   'keyword': '비만 치료[肥滿治療]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1946419'},
#  {'title': '내심낙원',
#   'creator': '우징숑',
#   'publisher': '바오로딸',
#   'issued': '2007',
#   'location': '234',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Interior carmel : the threefold way of love',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2886093'},
#  {'title': '사람, 사람들',
#   'creator': '없음',
#   'publisher': '눈빛',
#   'issued': '2006',
#   'location': '668.5',
#   'mainCategoryDescription': '사진술',
#   'alternative': '2006 민족사진가협회 기획사진전',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2614199'},
#  {'title': '동아시아학의 모색과 지향',
#   'creator': '김시업',
#   'publisher': '성균관대학교 출판부',
#   'issued': '2005',
#   'location': '150',
#   'mainCategoryDescription': '아시아철학, 사상',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2082783'},
#  {'title': '등반 이야기',
#   'creator': '이훈태',
#   'publisher': '눈빛출판사',
#   'issued': '2007',
#   'location': '699.1',
#   'mainCategoryDescription': '오락, 운동',
#   'alternative': '산이 내게 남겨 준 것들',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2626603'},
#  {'title': '탐史',
#   'creator': '곽차섭',
#   'publisher': '푸른역사',
#   'issued': '2007',
#   'location': '900.99',
#   'mainCategoryDescription': '역사',
#   'alternative': '현대 역사학의 거장 9인의 고백과 대화',
#   'keyword': '인터뷰',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2635668'},
#  {'title': '무예도보통지주해',
#   'creator': '정조',
#   'publisher': '東文選',
#   'issued': '2007',
#   'location': '698.0911',
#   'mainCategoryDescription': '오락, 운동',
#   'alternative': '御定武藝圖譜通志',
#   'keyword': '무예 십팔반[武藝十八般]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2636433'},
#  {'title': '고사성어',
#   'creator': '없음',
#   'publisher': '홍신문화사',
#   'issued': '2007',
#   'location': '713.04',
#   'mainCategoryDescription': '한국어',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2681086'},
#  {'title': '지안스님의 금강경 이야기',
#   'creator': '지안',
#   'publisher': '클리어마인드 지오비스',
#   'issued': '2007',
#   'location': '223.53',
#   'mainCategoryDescription': '불교',
#   'alternative': '머무름 없이 살라',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2537948'},
#  {'title': '문없는 문, 빗장을 열다',
#   'creator': '김성우',
#   'publisher': '클리어마인드 지오비스',
#   'issued': '2007',
#   'location': '228.7',
#   'mainCategoryDescription': '불교',
#   'alternative': 'Great way no gate',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2651399'},
#  {'title': '사람과 이야기',
#   'creator': '없음',
#   'publisher': '현자',
#   'issued': '2006',
#   'location': '668.5',
#   'mainCategoryDescription': '사진술',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3693677'},
#  {'title': '웜우드 파일',
#   'creator': 'Forest, Jim',
#   'publisher': '죠이선교회',
#   'issued': '2006',
#   'location': '231',
#   'mainCategoryDescription': '기독교',
#   'alternative': '지옥에서 온 이메일',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2637363'},
#  {'title': '설교 스피치 커뮤니케이션 총론',
#   'creator': '안종필',
#   'publisher': '쿰란출판사',
#   'issued': '2007',
#   'location': '235.2',
#   'mainCategoryDescription': '기독교',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2693226'},
#  {'title': '우동 목사와 짬뽕 교회',
#   'creator': '우동은',
#   'publisher': '쿰란출판사',
#   'issued': '2007',
#   'location': '235.3',
#   'mainCategoryDescription': '기독교',
#   'alternative': '우동은 목사의 이민목회 이야기 우동 목사와 짬뽕 교회',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2747446'},
#  {'title': '다이어트 불변의 법칙',
#   'creator': 'Diamond, Harvey',
#   'publisher': '사이몬북스',
#   'issued': '2007',
#   'location': '512.54',
#   'mainCategoryDescription': '의학',
#   'alternative': 'Fit for life',
#   'keyword': '다이어트[diet]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2681095'},
#  {'title': '대한민국 20대, 공모전에 미쳐라!',
#   'creator': '이동조',
#   'publisher': '전나무숲',
#   'issued': '2007',
#   'location': '336.24',
#   'mainCategoryDescription': '사회학, 사회문제',
#   'alternative': '원하는 기업에 당당하게 들어가는 공모전 성공전략',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2686191'},
#  {'title': '님은 바람 속에서',
#   'creator': "D'Souza, Valentine L",
#   'publisher': '바오로딸',
#   'issued': '2007',
#   'location': '234.3',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'そよ風のように生きる',
#   'keyword': '명상록[冥想錄]',
#   'seeAlso': '없음'},
#  {'title': '불교의 꽃이야기',
#   'creator': '지연',
#   'publisher': '인아',
#   'issued': '2006',
#   'location': '220',
#   'mainCategoryDescription': '불교',
#   'alternative': '없음',
#   'keyword': '꽃공양',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2628854'},
#  {'title': '아름다운 사람아!',
#   'creator': '노순자',
#   'publisher': '바오로딸',
#   'issued': '2007',
#   'location': '234.82',
#   'mainCategoryDescription': '기독교',
#   'alternative': '감동스런 숨결로 다가오는 9인의 사랑과 삶의 이야기',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=4486363'},
#  {'title': '순수 토종 현진이의 조기영어 성공기',
#   'creator': '유수경',
#   'publisher': '스크린M&B',
#   'issued': '2007',
#   'location': '747',
#   'mainCategoryDescription': '영어',
#   'alternative': '만5살짜리 국내 최초의 이중언어자 현진이의 토종영어학습법',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2690605'},
#  {'title': '소리와 의미의 에크리튀르',
#   'creator': '가와다 준조',
#   'publisher': '논형',
#   'issued': '2006',
#   'location': '730.1',
#   'mainCategoryDescription': '일본어',
#   'alternative': 'コトバ·言葉·ことば',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2620588'},
#  {'title': '클래식 음악 알아듣기',
#   'creator': '김승일',
#   'publisher': '예일출판사',
#   'issued': '2007',
#   'location': '671',
#   'mainCategoryDescription': '음악',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3693416'},
#  {'title': '영어일기',
#   'creator': '강윤혜',
#   'publisher': '길벗 이지톡',
#   'issued': '2007',
#   'location': '746',
#   'mainCategoryDescription': '영어',
#   'alternative': '영작의 기본부터 표현사전까지 한 권으로 ok!',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2636922'},
#  {'title': '내가 다섯 살이 되면',
#   'creator': '이경남',
#   'publisher': '한언',
#   'issued': '2003',
#   'location': '514.48',
#   'mainCategoryDescription': '의학',
#   'alternative': 'If I get to five',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=129356'},
#  {'title': '예수평전',
#   'creator': '김상구',
#   'publisher': '종교와비평',
#   'issued': '2007',
#   'location': '232.8',
#   'mainCategoryDescription': '기독교',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2681018'},
#  {'title': '성공하는 직장인의 건강 365',
#   'creator': '이광연',
#   'publisher': '이유',
#   'issued': '2005',
#   'location': '517.3',
#   'mainCategoryDescription': '의학',
#   'alternative': "'열심히 일하는 당신, 건강한가요?' 언제나 활력 넘치는 직장인 건강법!",
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1926852'},
#  {'title': '부모가 꼭 챙겨야 할 청소년 웰빙 건강',
#   'creator': '박명윤',
#   'publisher': '이유',
#   'issued': '2004',
#   'location': '517.373',
#   'mainCategoryDescription': '의학',
#   'alternative': '21세기를 지키는 청소년의 건강 길라잡이!!',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=150872'},
#  {'title': '가족생활교육',
#   'creator': '정현숙',
#   'publisher': '신정',
#   'issued': '2007',
#   'location': '591.8',
#   'mainCategoryDescription': '가정학 및 가정생활',
#   'alternative': 'Family life education',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2687486'},
#  {'title': '암을 고친 사람들',
#   'creator': '없음',
#   'publisher': '예일비알엠',
#   'issued': '2007',
#   'location': '513.994',
#   'mainCategoryDescription': '의학',
#   'alternative': '통합의학을 통한 암의 치유',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2907314'},
#  {'title': '라인홀드 니버와 사회정의',
#   'creator': '남태욱',
#   'publisher': '국제교육문화원',
#   'issued': '2006',
#   'location': '234.1',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Reinhold niebuhr & social justice',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2749538'},
#  {'title': '예수처럼 생각하라',
#   'creator': 'Barna, George',
#   'publisher': '사랑플러스',
#   'issued': '2005',
#   'location': '234.8',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Think like Jesus',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1917363'},
#  {'title': '노인들도 펄펄뛰는 교회이야기',
#   'creator': '안창천',
#   'publisher': '베다니출판사',
#   'issued': '2006',
#   'location': '235.73',
#   'mainCategoryDescription': '기독교',
#   'alternative': '초대교회가 사용했던 훈련방법으로 평신도들을 훈련시킨 이야기',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2530086'},
#  {'title': '골프규칙 Q&A 150선',
#   'creator': '김광배',
#   'publisher': '대광서림',
#   'issued': '2006',
#   'location': '695.8',
#   'mainCategoryDescription': '오락, 운동',
#   'alternative': 'Golf rule',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2511553'},
#  {'title': '여자, 그녀의 하나님',
#   'creator': '브리스코, 질',
#   'publisher': '사랑플러스',
#   'issued': '2005',
#   'location': '234.8',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Woman and her God',
#   'keyword': '기독교 신앙 생활[基督敎信仰生活]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1996380'},
#  {'title': '현명한 사람의 행복습관',
#   'creator': '신현호',
#   'publisher': '길벗',
#   'issued': '2006',
#   'location': '189',
#   'mainCategoryDescription': '심리학',
#   'alternative': '(The)habits of happy people',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2503909'},
#  {'title': '피부 카리스마',
#   'creator': '시진국',
#   'publisher': '중앙m&b',
#   'issued': '2006',
#   'location': '519.47',
#   'mainCategoryDescription': '의학',
#   'alternative': 'Oriental skin secret',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2613721'},
#  {'title': '기생충 제국',
#   'creator': '짐머, 칼',
#   'publisher': '궁리출판',
#   'issued': '2006',
#   'location': '491.55',
#   'mainCategoryDescription': '동물학',
#   'alternative': '세상에서 가장 위험한 생물의 세계를 탐험하다',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1353714'},
#  {'title': '쇠고기요리 \\"다\\" 모여!',
#   'creator': '없음',
#   'publisher': '동아일보사',
#   'issued': '2006',
#   'location': '594.5',
#   'mainCategoryDescription': '가정학 및 가정생활',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2614431'},
#  {'title': '콩 & 두부요리 \\"다\\" 모여!',
#   'creator': '없음',
#   'publisher': '동아일보사',
#   'issued': '2006',
#   'location': '594.5',
#   'mainCategoryDescription': '가정학 및 가정생활',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2614430'},
#  {'title': '닭고기요리 \\"다\\" 모여!',
#   'creator': '없음',
#   'publisher': '동아일보사',
#   'issued': '2006',
#   'location': '594.5',
#   'mainCategoryDescription': '가정학 및 가정생활',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2614434'},
#  {'title': '현대문학강독',
#   'creator': '없음',
#   'publisher': '에이원플러스출판',
#   'issued': '2006',
#   'location': '810.906',
#   'mainCategoryDescription': '한국문학',
#   'alternative': '국문3',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2116993'},
#  {'title': '하나님의 나라',
#   'creator': '없음',
#   'publisher': '펴내기',
#   'issued': '2007',
#   'location': '234.2',
#   'mainCategoryDescription': '기독교',
#   'alternative': '(The)kingdom of God',
#   'keyword': '성서 묵상[聖書默想]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2686388'},
#  {'title': '성공하는 대화법',
#   'creator': '정백',
#   'publisher': '창경사',
#   'issued': '2006',
#   'location': '802.54',
#   'mainCategoryDescription': '문학',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2115056'},
#  {'title': '내 안의 불교 찾기',
#   'creator': '혜성',
#   'publisher': '해조음',
#   'issued': '2006',
#   'location': '220.4',
#   'mainCategoryDescription': '불교',
#   'alternative': '없음',
#   'keyword': '부처님',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2529377'},
#  {'title': '음악감상을 위하여',
#   'creator': '밀러, 휴 M',
#   'publisher': '태림출판사',
#   'issued': '2006',
#   'location': '670.15',
#   'mainCategoryDescription': '음악',
#   'alternative': 'Introduction to music : a guide to good listening',
#   'keyword': '선율',
#   'seeAlso': '없음'},
#  {'title': '말러 33 가곡집',
#   'creator': '이규순',
#   'publisher': '태림출판사',
#   'issued': '2006',
#   'location': '673.83',
#   'mainCategoryDescription': '음악',
#   'alternative': 'Mahler 33 Songs : voice & piano(high)',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2746907'},
#  {'title': '건반화성과 반주법',
#   'creator': '황철익',
#   'publisher': '태림출판사',
#   'issued': '2005',
#   'location': '671.3',
#   'mainCategoryDescription': '음악',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1227964'},
#  {'title': '요한계시록의 신학',
#   'creator': '송영목',
#   'publisher': '성광문화사',
#   'issued': '2007',
#   'location': '233.8',
#   'mainCategoryDescription': '기독교',
#   'alternative': '(The)theology of the book of revelation',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2690081'},
#  {'title': '실학의 선구자 이수광',
#   'creator': '한영우',
#   'publisher': '경세원',
#   'issued': '2007',
#   'location': '151.58',
#   'mainCategoryDescription': '아시아철학, 사상',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2686258'},
#  {'title': '자녀들아, 돈은 이렇게 벌고 이렇게 써라',
#   'creator': '현용수',
#   'publisher': '동아일보사',
#   'issued': '2007',
#   'location': '598.1',
#   'mainCategoryDescription': '가정학 및 가정생활',
#   'alternative': 'Principles of money managemnet taught by Jewish fathers and Jesus : the theology of fatherhood',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2631074'},
#  {'title': '청바지를 입은 예수 뉴욕에서 만나다',
#   'creator': '나관호',
#   'publisher': '성안당.com',
#   'issued': '2007',
#   'location': '234.8',
#   'mainCategoryDescription': '기독교',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2627509'},
#  {'title': '우리나라 전통종교의 역사',
#   'creator': '김윤환',
#   'publisher': '매일',
#   'issued': '2006',
#   'location': '209.11',
#   'mainCategoryDescription': '종교',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2537048'},
# ...
#   'issued': '2007',
#   'location': '237.2',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Seven prayers : that will change your life forever',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3041695'},
#  {'title': '생태학',
#   'creator': '오인혜',
#   'publisher': '라이프사이언스',
#   'issued': '2007',
#   'location': '472.5',
#   'mainCategoryDescription': '생명과학',
#   'alternative': 'Elements of ecology',
#   'keyword': 'ECOLOGY',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3041335'},
#  {'title': '세계음식문화여행',
#   'creator': '양향자',
#   'publisher': '크로바출판사',
#   'issued': '2006',
#   'location': '381.75',
#   'mainCategoryDescription': '풍속, 민속학',
#   'alternative': '유럽 28개국 대표음식과 특징소개',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2086642'},
#  {'title': '세계음식문화여행',
#   'creator': '양향자',
#   'publisher': '크로바출판사',
#   'issued': '2006',
#   'location': '381.75',
#   'mainCategoryDescription': '풍속, 민속학',
#   'alternative': '아메리카 19개국 대표음식과 특징소개',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2086637'},
#  {'title': '꽃 女人 그리고 세월',
#   'creator': '최승범',
#   'publisher': '지식더미',
#   'issued': '2007',
#   'location': '814.6',
#   'mainCategoryDescription': '한국문학',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2635068'},
#  {'title': '백일홍',
#   'creator': '오양호',
#   'publisher': '수필과비평사',
#   'issued': '2007',
#   'location': '814.6',
#   'mainCategoryDescription': '한국문학',
#   'alternative': '百日紅',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3041319'},
#  {'title': '난, 영화 였다',
#   'creator': '신상옥',
#   'publisher': '랜덤하우스코리아',
#   'issued': '2007',
#   'location': '688.04',
#   'mainCategoryDescription': '연극',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3025415'},
#  {'title': '소중한 친구에게 주고 싶은 책',
#   'creator': '이솝',
#   'publisher': '북앤북',
#   'issued': '2006',
#   'location': '892.1',
#   'mainCategoryDescription': '기타 제문학',
#   'alternative': '이솝우화',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2127099'},
#  {'title': '사랑하는 사람에게 주고 싶은 내 마음의 名詩 모음집',
#   'creator': 'dskimp2004@yahoo.co.kr',
#   'publisher': '북앤북',
#   'issued': '2005',
#   'location': '808.1',
#   'mainCategoryDescription': '문학',
#   'alternative': '내마음의 선물 너무나 그립고 보고싶은 그대여',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=104341'},
#  {'title': '소중한 사람에게 주고 싶은 책',
#   'creator': 'dskimp2004@yahoo.co.kr',
#   'publisher': '북앤북',
#   'issued': '2005',
#   'location': '239.3',
#   'mainCategoryDescription': '기독교',
#   'alternative': '탈무드',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=6381703'},
#  {'title': '한국인이 뽑은 한용운의 名時[실은 詩] 모음집',
#   'creator': '한용운',
#   'publisher': '북앤북',
#   'issued': '2005',
#   'location': '811.6',
#   'mainCategoryDescription': '한국문학',
#   'alternative': '한국인이 뽑은 한용운의 명시 모음집',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1972017'},
#  {'title': '번역인가 반역인가',
#   'creator': '김욱동',
#   'publisher': '문학수첩',
#   'issued': '2007',
#   'location': '747',
#   'mainCategoryDescription': '영어',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3081089'},
#  {'title': '몸만들기 X-파일',
#   'creator': '심현도',
#   'publisher': '씨엔에스',
#   'issued': '2007',
#   'location': '593.5',
#   'mainCategoryDescription': '가정학 및 가정생활',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3095841'},
#  {'title': '왕초짜 여행 베트남어',
#   'creator': '루 투안 안',
#   'publisher': '동인랑',
#   'issued': '2007',
#   'location': '739.827',
#   'mainCategoryDescription': '일본어',
#   'alternative': '없음',
#   'keyword': '베트남어[--語]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3041261'},
#  {'title': '강아지가 궁금해',
#   'creator': 'Becker, Marty',
#   'publisher': '펜타그램',
#   'issued': '2007',
#   'location': '527.41',
#   'mainCategoryDescription': '농업, 농학',
#   'alternative': 'Why do dogs drink out of the toilet?',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3042432'},
#  {'title': '첫사랑',
#   'creator': '투르게네프',
#   'publisher': '어문각',
#   'issued': '2006',
#   'location': '892.8',
#   'mainCategoryDescription': '기타 제문학',
#   'alternative': 'Perbaya lyubov',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2535763'},
#  {'title': '영화배우',
#   'creator': '나카시, 자클린',
#   'publisher': '東文選',
#   'issued': '2007',
#   'location': '688.16',
#   'mainCategoryDescription': '연극',
#   'alternative': 'Acteur de cinéma',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3082230'},
#  {'title': '현대 프랑스어 경제·사회 약어',
#   'creator': '고광진',
#   'publisher': '세종출판사',
#   'issued': '2002',
#   'location': '760',
#   'mainCategoryDescription': '프랑스어',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=114551'},
#  {'title': '사랑을 이루는 연애 풍수 인테리어',
#   'creator': '황종찬',
#   'publisher': '문원북',
#   'issued': '2005',
#   'location': '188.4',
#   'mainCategoryDescription': '심리학',
#   'alternative': '연애를 성공시키는 풍수 인테리어 테크닉',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1874341'},
#  {'title': '꽃으로 부자되는 花풍수 인테리어',
#   'creator': '황종찬',
#   'publisher': '문원북',
#   'issued': '2004',
#   'location': '188.4',
#   'mainCategoryDescription': '심리학',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=152535'},
#  {'title': '일본어 어휘의 달인이 되는 법',
#   'creator': '아키야마 조쿠',
#   'publisher': '사람in',
#   'issued': '2007',
#   'location': '734',
#   'mainCategoryDescription': '일본어',
#   'alternative': '없음',
#   'keyword': '일본어 어휘[日本語語彙]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2618862'},
#  {'title': '하나님의 요새',
#   'creator': '박선규',
#   'publisher': '순전한 나드',
#   'issued': '2004',
#   'location': '231.23',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Stronghold of God',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=157273'},
#  {'title': '사도적 사역',
#   'creator': 'Joyner, Rick',
#   'publisher': '순전한 나드',
#   'issued': '2007',
#   'location': '233.66',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Apostolic ministry',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1896654'},
#  {'title': '예수님을 향한 열정',
#   'creator': '박영진',
#   'publisher': '순전한 나드',
#   'issued': '2007',
#   'location': '234.8',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Passion for Jesus',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1896655'},
#  {'title': '식민주의와 언어',
#   'creator': '김권정',
#   'publisher': '아름나무',
#   'issued': '2007',
#   'location': '701.03',
#   'mainCategoryDescription': '언어',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3082126'},
#  {'title': '육육삼십육',
#   'creator': '김도환',
#   'publisher': '웰브랜드',
#   'issued': '2007',
#   'location': '657.1',
#   'mainCategoryDescription': '회화, 도화',
#   'alternative': '행복에 관한 평범한 가족의 특별한 이야기',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3029928'},
#  {'title': '선승禪僧의 길',
#   'creator': '대현',
#   'publisher': '현대불교신문사 출판부',
#   'issued': '2007',
#   'location': '224.81',
#   'mainCategoryDescription': '불교',
#   'alternative': '선승의 길',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2887581'},
#  {'title': '염불환향곡',
#   'creator': '기성쾌선',
#   'publisher': '현대불교신문사',
#   'issued': '2005',
#   'location': '227.7',
#   'mainCategoryDescription': '불교',
#   'alternative': '念佛還鄕曲',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1562132'},
#  {'title': '불씨',
#   'creator': '지문',
#   'publisher': '현대불교신문사 출판부',
#   'issued': '2006',
#   'location': '224.2',
#   'mainCategoryDescription': '불교',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2624651'},
#  {'title': '철벽을 부수고 벽안을 열다',
#   'creator': '한암대원',
#   'publisher': '현대불교신문사 출판부',
#   'issued': '2006',
#   'location': '224.2',
#   'mainCategoryDescription': '불교',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2896976'},
#  {'title': '하나님과 사람에게 더욱 사랑스러운 자',
#   'creator': 'Vander Klok, Duane',
#   'publisher': '순전한나드',
#   'issued': '2007',
#   'location': '234.8',
#   'mainCategoryDescription': '기독교',
#   'alternative': '하나님의 은총의 권능이 풀어지게 하라!',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3018178'},
#  {'title': '해석과 교육',
#   'creator': '양금희',
#   'publisher': '장로회신학대학교출판부',
#   'issued': '2007',
#   'location': '235.7',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Hermeneutics and Christian education',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3119876'},
#  {'title': '공적실천신학과 세계화시대의 기독교교육',
#   'creator': '장신근',
#   'publisher': '장로회신학대학교출판부',
#   'issued': '2007',
#   'location': '235.7',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Public practical theology globalization Christian education',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3119875'},
#  {'title': '아스토르 피아졸라 피아노 컬렉션',
#   'creator': '없음',
#   'publisher': '모노폴리',
#   'issued': '2006',
#   'location': '676.28',
#   'mainCategoryDescription': '음악',
#   'alternative': 'Astor Piazzolla piano collection',
#   'keyword': '악보집[樂譜集]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3027526'},
#  {'title': '레저스포츠 총론',
#   'creator': '김홍백',
#   'publisher': '형설출판사',
#   'issued': '2007',
#   'location': '692',
#   'mainCategoryDescription': '오락, 운동',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3084780'},
#  {'title': '나의 아버지',
#   'creator': 'Bates, Aaron',
#   'publisher': '자유로운 상상',
#   'issued': '2007',
#   'location': '848',
#   'mainCategoryDescription': '영미문학',
#   'alternative': '없음',
#   'keyword': '미국 문학[美國文學]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3028010'},
#  {'title': '빅팻캣과 100년 만의 폭설',
#   'creator': '김은하',
#   'publisher': '윌북',
#   'issued': '2006',
#   'location': '747',
#   'mainCategoryDescription': '영어',
#   'alternative': 'Big fat cat and the snow of the century',
#   'keyword': '영어(언어)[英語]',
#   'seeAlso': '없음'},
#  {'title': '한국인이 뽑은 세계 명단편선 모음집',
#   'creator': 'Henry, O',
#   'publisher': '북앤북',
#   'issued': '2005',
#   'location': '808.3',
#   'mainCategoryDescription': '문학',
#   'alternative': '마지막수업',
#   'keyword': '단편 소설[短篇小說]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1987448'},
#  {'title': '빅팻캣과 포춘 쿠키',
#   'creator': '향산귀언',
#   'publisher': '윌북',
#   'issued': '2006',
#   'location': '747',
#   'mainCategoryDescription': '영어',
#   'alternative': 'ビッグ・ファット・キャットとフォーチュン・クッキー',
#   'keyword': '영어(언어)[英語]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1989108'},
#  {'title': '빅팻캣과 매직 파이 숍',
#   'creator': '김은하',
#   'publisher': '윌북',
#   'issued': '2007',
#   'location': '747',
#   'mainCategoryDescription': '영어',
#   'alternative': 'Big fat cat and the magic pie shop',
#   'keyword': '영어(언어)[英語]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1947366'},
#  {'title': '빅팻캣과 미스터 존스',
#   'creator': '무코야마 다카히코',
#   'publisher': '윌북',
#   'issued': '2007',
#   'location': '747',
#   'mainCategoryDescription': '영어',
#   'alternative': 'ビッグ・ファット・キャットvsミスター・ジョーンズ',
#   'keyword': '영어(언어)[英語]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3038440'},
#  {'title': '빅팻캣과 머스터드 파이',
#   'creator': '김은하',
#   'publisher': '윌북',
#   'issued': '2007',
#   'location': '747',
#   'mainCategoryDescription': '영어',
#   'alternative': '(An)all-new story',
#   'keyword': '영어(언어)[英語]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3038440'},
#  {'title': '빅팻캣과 고스트 애비뉴',
#   'creator': '향산귀언',
#   'publisher': '윌북',
#   'issued': '2007',
#   'location': '747',
#   'mainCategoryDescription': '영어',
#   'alternative': 'ビッグ・ファット・キャットとゴースト・アベニュー',
#   'keyword': '영어(언어)[英語]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3038440'},
#  {'title': '빅팻캣, 도시로 가다',
#   'creator': '김은하',
#   'publisher': '윌북',
#   'issued': '2007',
#   'location': '747',
#   'mainCategoryDescription': '영어',
#   'alternative': 'Big fat cat goes to town',
#   'keyword': '영어(언어)[英語]',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1912196'},
#  {'title': '네 시작은 미약하였으나',
#   'creator': 'CBMC',
#   'publisher': '웅진씽크빅',
#   'issued': '2007',
#   'location': '235.84',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Though thy beginning was small yet thy latter end should greatly increase',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3038816'},
#  {'title': '부자들의 행복한 가계부',
#   'creator': '제윤경',
#   'publisher': '생각의나무',
#   'issued': '2007',
#   'location': '327.04',
#   'mainCategoryDescription': '경제학',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3025379'},
#  {'title': '진보정치를 위하여',
#   'creator': '허영구',
#   'publisher': '삶이 보이는 창',
#   'issued': '2004',
#   'location': '340.4',
#   'mainCategoryDescription': '정치학',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=1219765'},
#  {'title': '아름다운 시절',
#   'creator': '권태섭',
#   'publisher': '중앙북스',
#   'issued': '2007',
#   'location': '340.4',
#   'mainCategoryDescription': '정치학',
#   'alternative': '30여 년간 함께 울고 웃었던 지인들이 말하는',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3017690'},
#  {'title': '사랑하는 사람에게 주고 싶은 내 마음의 名詩 모음집',
#   'creator': 'dskimp2004@yahoo.co.kr',
#   'publisher': '북앤북',
#   'issued': '2007',
#   'location': '808.1',
#   'mainCategoryDescription': '문학',
#   'alternative': '내마음의 선물 너무나 그립고 보고싶은 그대여',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2691807'},
#  {'title': '그리스도를 본받아',
#   'creator': '김지현',
#   'publisher': '북프렌즈',
#   'issued': '2007',
#   'location': '232',
#   'mainCategoryDescription': '기독교',
#   'alternative': 'Imitation of Christ',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2624024'},
#  {'title': '이민목회 일기',
#   'creator': '이종환',
#   'publisher': '쿰란출판사',
#   'issued': '2007',
#   'location': '230.4',
#   'mainCategoryDescription': '기독교',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3092794'},
#  {'title': '도덕경',
#   'creator': '노태준',
#   'publisher': '홍신문화사',
#   'issued': '2007',
#   'location': '152.222',
#   'mainCategoryDescription': '아시아철학, 사상',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3082733'},
#  {'title': '문학교육론',
#   'creator': '박인기',
#   'publisher': '三知院',
#   'issued': '2007',
#   'location': '807',
#   'mainCategoryDescription': '문학',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3082250'},
#  {'title': '여행영어 무조건 부딪쳐라',
#   'creator': 'Media연구회',
#   'publisher': '고구려미디어',
#   'issued': '2007',
#   'location': '747.5',
#   'mainCategoryDescription': '영어',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3027743'},
#  {'title': '문학과 만난 영화',
#   'creator': '오영미',
#   'publisher': '월인',
#   'issued': '2007',
#   'location': '688.09',
#   'mainCategoryDescription': '연극',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3079782'},
#  {'title': '한국 가면극과 그 주변 문화',
#   'creator': '전경욱',
#   'publisher': '月印',
#   'issued': '2007',
#   'location': '682.11',
#   'mainCategoryDescription': '연극',
#   'alternative': '없음',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=3043132'},
#  {'title': '연기演技된 근대',
#   'creator': '병등유기',
#   'publisher': '연극과인간',
#   'issued': '2007',
#   'location': '680.913',
#   'mainCategoryDescription': '연극',
#   'alternative': '演じられた近代 : 國民の身體とパフォ-マンス',
#   'keyword': '없음',
#   'seeAlso': 'http://book.naver.com/bookdb/book_detail.php?bid=2926660'},
#  ...]

# %%
with open('./processed_data/processed_book58.json', 'w', encoding='utf-8') as file:
    json.dump(processed_books, file, ensure_ascii=False, indent=4)
